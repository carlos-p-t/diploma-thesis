# %% [markdown]
# # Data Subset Creator
#
# _By: Carlos Andres Pizarroso Troncoso_
#
# This notebook contains the code for creating a subset from Mapillary Vistas Dataset.
#
# ## 1. Creating a subset of the main dataset
#
# First, importing the necessary libraries

# %%
# Importing necessary libraries

from __future__ import print_function
import json
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import shutil
import os

# %%
# Defining paths

data_path = 'Data'
train_path = data_path + '/train'
validation_path = data_path + '/validation'
testing_path = data_path + '/testing'
labels_path = '/labels'
images_path = '/images'

# Folders for subdataset (just performed once)

os.mkdir(data_path)
os.mkdir(train_path)
os.mkdir(validation_path)
os.mkdir(testing_path)
os.mkdir(train_path + labels_path)
os.mkdir(validation_path + labels_path)
os.mkdir(train_path + images_path)
os.mkdir(validation_path + images_path)
os.mkdir(testing_path + images_path)

#images_path = "C:/Users/Carlos/Documents/Carlos/Comenius University/Master's Degree/Diploma/Practice/Mapillary-vistas-dataset/mapillary_vistas_v1/training/images"
#labels_path = "C:/Users/Carlos/Documents/Carlos/Comenius University/Master's Degree/Diploma/Practice/Mapillary-vistas-dataset/mapillary_vistas_v1/training/labels"
original_path = "C:/Users/Carlos/Documents/Carlos/Comenius University/Master's Degree/Diploma/Practice/Mapillary-vistas-dataset/mapillary_vistas_v1/"

# %% [markdown]
# ### 1.1 Training
#
# In this section, images which contain only billboards will be first selected.
#
# Mapillary Vistas Dataset contains several classes, including billboards. Billboards have a label ID of 35 (used below).
#
# We increased the size of the training set from **2000** images to **5000** images.

# %%
# Getting the names of the image files from the original training path (Mapillary Vistas)

training_images_names = os.listdir(original_path + "training/images")
n = len(training_images_names)
for i in range(0, n):
    training_images_names[i] = training_images_names[i][0:training_images_names[i].find('.')]
print(training_images_names[25])
print(n)
# Out:
# -4x3QnUx01ZfYnZPVE9DNA
# 18000

# %%
# Getting the ids of images that contain billboards on them

i = 0
size = 5000 # size of the desired subset (due to storage limitations, we start by selecting 5000 images with billboards)
subset_names_train = []
while (len(subset_names_train) < size):
    image_id = training_images_names[i]
    # read in config file
    with open(original_path + 'config.json') as config_file:
        config = json.load(config_file)
        
    labels = config['labels']
    label_dic = {}
    for label_id, label in enumerate(labels):
        label_dic[label['name']] = label_id

    # set up paths for every image
    image_path = original_path + "training/images/{}.jpg".format(image_id)
    panoptic_path = original_path + "training/panoptic/{}.png".format(image_id)

    # load images
    base_image = Image.open(image_path)
    panoptic_image = Image.open(panoptic_path)
        
    # PANOPTIC HANDLING

    # read in panoptic file
    with open(original_path + "training/panoptic/panoptic_2018.json") as panoptic_file:
        panoptic = json.load(panoptic_file)
    
   # convert annotation infos to image_id indexed dictionary
    panoptic_per_image_id = {}
    for annotation in panoptic["annotations"]:
        panoptic_per_image_id[annotation["image_id"]] = annotation
        
    # convert category infos to category_id indexed dictionary
    panoptic_category_per_id = {}
    for category in panoptic["categories"]:
        panoptic_category_per_id[category["id"]] = category
        
    # convert segment infos to segment id indexed dictionary
    example_panoptic = panoptic_per_image_id[image_id]
    example_segments = {}
    for segment_info in example_panoptic["segments_info"]:
        example_segments[segment_info["id"]] = segment_info
    
    panoptic_array = np.array(panoptic_image).astype(np.uint32)
    panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
    panoptic_ids_from_image = np.unique(panoptic_id_array)
    
    for panoptic_id in panoptic_ids_from_image:
        if panoptic_id == 0:
            # void image areas don't have segments
            continue
        segment_info = example_segments[panoptic_id]
        category = panoptic_category_per_id[segment_info["category_id"]]
        
        img_label = label_dic[category['supercategory']]
        if img_label == 35: # <- Billboards label ID, this filters images which contain billboards only
            print(image_id)
            subset_names_train.append(image_id)
            break
        example_segments.pop(panoptic_id)
    i += 1
# Out:
# --vWKSR3Rh8quTfK4AuKOQ
# --WOpVBuHlCygAUADkttpg
# -0C1J9CvgFP4BTVLXNeNZA
# -0GQmYRienNVqEKiQ0Mkyw
# -0Q9X3KqBrhdlGzap-YToQ
# -0QdotcnWZMgDLHELjMeoQ
# -0xySwkm6plG4nznHLQcHg
# -1Z28Rrc91syhk-y8Bp_cg
# -2H8gOJp_LEvus2Y6pCIOA
# -3BbEwDFdZ6kvDrbqhNShw
# -3bnLdeHkonpmCJj3a1X_w
# -3Ce66lOpbY2j4Tgngr-dQ
# -3qDI4rcmarHQRV9FDKfeA
# -3u6bh9pGFOtClGfzvMqqg
# -3WWvMk6i1YgKC9ECG2HEA
# -4Kw4AJqOzZG8q5le7bGlQ
# -4oZ0SAVEd4ijmony0t1Zw
# -4SR45KuNoLQJJMNstPwRg
# -4VHR0_p6lfAJ3Id2RXozg
# -4x3QnUx01ZfYnZPVE9DNA
# -5Bq-gd3iHCFkWdCjjfWlA
# -5g8sem4SFSvxctV9MeyIw
# -5n8RNkx2tWpD7w-ZAZXZA
# -6-WLs7O63-6cwx-8adk7g
# -60QYVrLRufeAjbRN-z79g
# -6ie-JRSyamuIYcRWTWZVw
# -6kI3IofoH9vQ7kM6ake2w
# -6tNQe10dgH3ByWafilXHw
# -6zd1w0cgRgijS2srqkMUA
# -7kDWbpzqmrQkBx39Z_Jgg
# -7njPpiHROkOjrBeSzNiow
# -8d4l3xicTRHZLze9Wuc4g
# -8d9PIE2D6OjzC3Q_fEUmA
# -8EClSWhRM4FuiWdu-kbQg
# -8LfeDEADhyLcKBvhRWrCw
# -9bvNvBWAX3xjKfJzS4vTA
# -9s41VI1tVoMhjTwKUMbnw
# -A3duJBYuHa2VtOTTsG1dQ
# -ahL3qORtev5ZHXrB5NYIA
# -AMluJ4RmAbAN0L9AfwFUg
# -asE-g-kqSEenUxYHbzx_w
# -AUC1oIt8HUa9TmU4bd0Dg
# -aZs4bu6mgdPQs7Xi8xUNQ
# -b3TQ65aEVgNJXjn_RXZmw
# -bagyBBZ-1RbPIwCtqSNlA
# -bb_Ov7jcrXLBUGEjT_Wkw
# -BIXObU5Dbd_RwSUOSQ5WA
# -BjxFCNOKl2jskkYoVBwbA
# -bUoZ462ACyCa1NsP5rnMA
# -bV8SIiLGuc7kFjKNUbJzA
# -C-w9t58ZO5RSefsi061Lw
# -CbEDty6bbpZ2Uc9R9utPA
# -CHPuwsnH7hfEje1O4oqTw
# -CjGcO8hfpC8lzGrYsM8Iw
# -CmpNq7_3_pMhJYNv6wNzg
# -cQgiVzBhjcwQssC4bxxew
# -CZlSrsXBlX6zvIEpCRDrw
# -dAOMfHl0E3yJRnok3UrWw
# -DHEVkd576GS3gT-ucMiig
# -DIQxpmN0Vk7KGxtclWvsA
# -djJHyrkr6dlFwSCFnnerA
# -dN5Y3fw5JFEhe4KSlRbIg
# -DsdPlUt6iih-L9Gy35IMg
# -DyNAUaoopodGXbo_k8RNg
# -e5ywi8g8m7y8CWy5r5l-w
# -E8T1gplOQJq-E_B5V6lfQ
# -ejZD7evLtjfTiluk3Lkpg
# -ERU5nErUqQn3JZ6sSGofA
# -etOqNkYxz0kg8DDX2pVrA
# -eTXSDNHpQddE2ID13I-jA
# -eWxFIP8Kr88-Udk6si_pA
# -EWyNaeId-UrIMVxKmbe-g
# -Fepp6H91z1x7iuaJS9-wQ
# -fmmqGttV1isOGC9nwYxlQ
# -G6ZKGj-TEUy4DFRjCy3yg
# -GDAvC1NBZQsl3wxTxOcIg
# -gJn19I52yYxRqQKHO_3DQ
# -gL037z_iYF2e-RrDEgjew
# -gmH2vOSnm6NBWRa4-UhTg
# -GsIwCvO8Z6tpWUZKE3_1A
# -gSMw1gvzaUryheHPx00Zw
# -GxYFOCn-Xfnljtk30lpIA
# -H9cBUiSMBxs5pm3tCGwAg
# -hDO0PnyRPd984SqgjncIA
# -hE6JisEaq_RlW7YvbZ1bQ
# -hmu1FE9MafhXIYgqW89-A
# -hpHZbw6Jxohec96hWum7A
# -i-C19RhKpUV_em5j3wQwg
# -i3WC4H43BVUh5nZsJgThQ
# -IK_pKkzprAR5XnFgpQ-NQ
# -im5fRIjVI2eM9ca9ASdpA
# -Ior0TCn7mp29k_w-W2Yyw
# -iRB909t8cdNUYvETB3O4A
# -iREwudRY-wjPvhflTghFw
# -ixqBzV6sBiCXQtGn1gyfw
# -IzPhdupoy0gOk6agMcA8Q
# -iZRdojTthvZtH8D1id45Q
# -J0nkDaw7C0woFaCoUKZnQ
# -jcKJthQDRwKdqUMheDRow
# -JdRFz_3ijpW8Xm5LMm3Ww
# -jhqNCQcsRNs88iAUtttpw
# -jPx0CegYq2k204dQ-1JJA
# -jrOR8VoL7405tThwHSneQ
# -k6rwkHs-d2SiQ71OK9j9w
# -kOISu1NOUW937bAk00V9w
# -l29t4vaKyFZWKB1bWLZog
# -lBD1eCq9aXKRPAHUAhP6Q
# -lq--TUNqiNC_SizcDD5fw
# -lsv9582Wjc5TfvD1HO0PQ
# -LtOhSguWQXyerbzUN6HpA
# -LtptowdHwNfuskkQ8aVxA
# -LtQo5edm0gYE_NGNMPdPw
# -lw3mUDZ56348AA7xtiZ6Q
# -mB0TstV0eFGU-qpHbMdDw
# -MUSzy6WUyJynuLLVxq6dw
# -N1xff79vfI_LaL38yTXiA
# -nUni3iuEH0aYf-rzokxtA
# -NyDCssDcCK8bWI4IkGhyQ
# -nzQyv07U66nrpw6senUmw
# -o3m_ncA2zRGvO0Z5gfvOQ
# -o4-dLzOXoOSOdR4P9ZGtA
# -oh2crUz4HFuhwgehbigGw
# -OU4aqp5RDocPOZxvtKlvQ
# -OW9ycbAVx3NHh1Emb8XxA
# -P1z3gM5DlaNUCdPEjgQ8w
# -p8VC0pXkTq06tA1YN4VbA
# -pknlH0DMwa03Y-g2-tcjA
# -pShuVibCqrQgRKRhsJ6nA
# -pVSrIxeKECPZ_q7rQ9m1g
# -QDS0fpsTvKyZBobt2cvbQ
# -qMkh96LJduUGdgXAI3Wkg
# -qv7yT8igffux_xn1j38_g
# -qwVp1yR-2hGkZzCAhnWmw
# -qYuT49E9XwSfZl71BeYGg
# -QZycUbAPJ6CQfGZc1lWrg
# -R1j4dRtU3Sh0q6WlOoSDQ
# -R2IhI2eSfE85UcN4nladg
# -R3RD1Z9fp1iEBJhlyGz_A
# -r5axddH7Eh1QD4pu8J3fg
# -rBa2Lx5doyvnFZgPvsLEg
# -rlM3yr-iudN8OrsY0YkTg
# -RLOns23d2Ca7nv74pQ-jw
# -RvUfordKSu3eFmYIBbt_A
# -sAgfjKL_ny5jdmyxP1p8g
# -sEEaHeGOQcClkpluqufjQ
# -SsGvL43_2NI35jY1UDKyA
# -suLNL-_JE7TUbI_WMqZ9g
# -tCCn5RcwsaOUanj4rZyFQ
# -tRuGgG35QpQjRBw5Gi1RQ
# -TxSLdJjQEqTcTFYFHt7oQ
# -UE2rM7QKcGxp4x69A4RnQ
# -UlfsstfXYaod0HJv7sR_w
# -uoC3nD0zlcDgPOmFVMNhw
# -UQZP8LWXu6TAlTfHLA7Fw
# -URkLEiMdJfozXVvq1lpAA
# -UV1Qnye_oHy_YAsVHFN3w
# -uy7fxqZa_l1SIaMr-TJCA
# -u_rhB80W9EGDzaj3Dh3SQ
# -v-46sgff0iRcARtX0DMZg
# -v-fBBFa9D69F_DaV-z1Tg
# -vH45xt279tI_2_D8R1cXw
# -vJ4x2ERwhXMrsn6CUiTAQ
# -VsXADw9HOhMb2Jj31GIhA
# -vwIVZhBtn7TB3LWgHkwgw
# -vZmlbSsrt2EBaw4ZQ2GfQ
# -WdLeAd4l_47WqMkfTX7bg
# -wFNZYTX4hOZNO2QPDSq1w
# -WGa5idP-_DtlLWE9HzLrA
# -WKNjlyFEhjDccX92Sulcg
# -wUuxz4vMPUdE9Plvb0cSA
# -wWh2jjzLDvLAQck9PfKOQ
# -WYrqjOmcPi4IsimKqUjsg
# -xNV8edrjTh8oBELZFjgCA
# -Xsl7QdtB5Pk4nekx2VqhA
# -xYaOiqtNt8zOx4G9avgwQ
# -yiHX9agSIb2D2ZYivHfWw
# -YiZ4GqumnyXNglwFbFjQw
# -yOAsORJIE_d9DGKngxnGw
# -YPY81fouoG7rXRw8krsSA
# -Yt5ilokytLEj4h6ZQeikQ
# -ZBeLBlH_v3RlDpF5ieAsg
# -Zi744ALiaE14YTHMMzY3w
# -ZIcdGAafZ7wRX3X32vNhA
# -ZMp-jerhSLoh1wsHUd6EQ
# -zPvF4S1w3onLQrDwlV5GQ
# -ZR5Z9Cq3A6Qh2Wa3WNwkA
# -zUs4Y0w8pLVk3n5itWx8w
# -Zvdb_5UjlrZKZiggHPHKg
# -zZvqUIoMscnxGRg_b6AWA
# 0-hGoJIqWHuoCnLS6gMxrQ
# 0-QneLDoQStJZfNAZb29Bg
# 00-QP-J4lW-IMLqGyHb5pQ
# 0035fkbjWljhaftpVM37-g
# 00qclUcInksIYnm19b1Xfw
# 00rKt4pJadETqgb3NYonSA
# 014cEvKoAuTJgL6yJvmZow
# 0155X2oSxdk_osOgaIxUKQ
# 016VfPg9PpAc5JHPN3qEVA
# 01mPjfB0VDVfNBZJOxPLyQ
# 01o9WOzUuaQYUDhLZJ4Tzg
# 01uhObTkhfdvAl7kDEMMZg
# 020TJuYqjCSgDVOypUKc7A
# 020y16qxpuwigmJH05nTjA
# 028jmhAnOFJO1wYDQW9x7Q
# 02Q-qbXsU5Jwq7rqv9Vn-g
# 03AxWTlCct9M0xL-d3uNjQ
# 03PYx6SDV4KgoQHMN8rX0A
# 03U2OOIz3Z6r0VUrl6tBMg
# 042yplKtH0jE2nampnv1kg
# 044yBEge2zNqwR3RwJbuoQ
# 04m4f91ob7I0XpE36ZDFLw
# 04MC8ARpOUnkmJsVToTh-A
# 04qLNUT3T87a-PBiQjbkxA
# 04_G_l3AleUQWBSJ4_R8Hw
# 056PRDIdH73i9SjAk2zT1w
# 05RcARrM8-SJ2PcXKyBuVQ
# 06AoB744tli_OZenq2l_eA
# 06WOk7wNJk9Y-KoCPSsehA
# 073AXI3zoa1avdLKtTiRXQ
# 07hPEC_AsQ1fYR22Sbq-kg
# 08oiTL1h0cNIgdpPFKdp2g
# 09FtYCV0NYtNHIM9ZIkjKg
# 09H7HMDpbjsTx0HPVSq6SA
# 09ptluozQjpYCCDPvVqshg
# 09_28U6xuMmiFwt-NT3Dpg
# 0a5QmgHLgOqpkxexLef5sQ
# 0aAW3UmcBzdYdfWX_Akv0A
# 0abUayZ1uxulmxH41MeOVg
# 0ac-yCaYgJKY-IrKX4p5_A
# 0afBU-MEV1AC9LDuqt3wBw
# 0agl0FVYRkrbsIVPV64NKw
# 0agTvBdoGVCc1mQyQy2ohw
# 0AiPqmOICywixqD4q7UEJA
# 0aTF1hLSc8ZnCGkLRBYNHg
# 0aVKQ2taubF1fJjomZUrcg
# 0AzF67m7ykZZUATHLdl4yg
# 0AZiFqSRZ_2Xn1JfaZmcqw
# 0B4YcA8caHnP1re3YY231Q
# 0bK902h4pHM987MHXAo9Bw
# 0BnTnWw-k6k8n5BtvusKbw
# 0Bt3m_mPk8_jhCdeWzEGLw
# 0bTLLUcpIknkA1K9kMOo7Q
# 0BYZodoqfSIog8Wq_86Pcw
# 0C98nt3G8PyaDX-ZRgoKCw
# 0CmiO_YcF_538D8HPlcnrg
# 0cyDbulAYr8RqYaD9PlK-A
# 0czUDSkQjafUJfweo_s3qw
# 0D-ro0oVG2CtHFrFzdbp8w
# 0d3hkSdKjwAydqxcRi5aJA
# 0D5Jn1i9mtKZqkTRAFrIww
# 0DHB5pgbkoLkPX0Ls_jyRA
# 0DKe67k2U3UQxhLtPASHdA
# 0DNKR4E9tB_w1eHzt0i2nA
# 0dNwZsCHp-Y1LZ-5oFALWw
# 0DONoYEe2FIFr7gzN2nLCg
# 0DU7QyHUj5bae8gEG5UtTQ
# 0e7kk3WleuBcvBaj4G5mQw
# 0eKgiib2JaKj7ek3Voxkpw
# 0EOXPIQu2yrpGeBTyW5NHA
# 0eQAT2Iei3INN8SxMOJGUw
# 0ErcYqUJdsDddTvMplWgEw
# 0et5RoogCQnayE3OcT7y_w
# 0ex5sxSYJs9ymscQOa0QNA
# 0FLsXsliWqAZeYB-YGnTCA
# 0fnoIgmCO-7skSOv7eWlOA
# 0g2zZVKyk4eL0rTtp-yLfQ
# 0G3pseXonpH_cmLxb2B2xw
# 0gfnr1SylZ7gBXY0QKIitQ
# 0gFsMvCekBJRwPYYl_k12Q
# 0GJbXkFk59FiC5xBE-GZUw
# 0gNecUgn1jHcbCwn3i4vIA
# 0GnkCEC-rCqKelmA6QSSnw
# 0GUtL7Pmkz_EiC5hSs8U3w
# 0H93achbX6X9gWnUD5HQ5g
# 0hbGVY5_5674fDF4UReeVQ
# 0hfmiSEJtXFYhxs4XxR7PA
# 0hIfEd8AZ-Dls5sylGFHZg
# 0HjcCSPsX2PVr2n1m5-YMw
# 0HRPUlsKJgTrgM-jhFgXDQ
# 0HsYmv6rT4o58PSUTWwPxQ
# 0HwPe3WZoAV8C31Vp0t2ew
# 0HZ4qlvEyxVJlZ9xBISO_w
# 0I3kpDByFegjQD4598T0Pg
# 0I9TFN42AwpPXZ8TvUyUoA
# 0icaMxV8_mJ8sb892WlhXA
# 0ICmP3lYJ-VyHKdkGRV-DA
# 0IFYdMzj8_tltZPBLjlMhg
# 0IHzZN-4uDgvVJs3FDCBGw
# 0iqciYYgHJQWe_fL-lqVxA
# 0IumC8KoIh3EtYt1HNr6rA
# 0Ja2VJ9WRWA0Yr4gNOoMZg
# 0JGPyw0wF4fUo2Ava5ObQQ
# 0JksQ7KsIeveMWiMJH8rMw
# 0JNIrEXa-gr3SVpHBLmnWA
# 0jsFJM2d60cUsYrhTcUQEw
# 0KI9U--eKDCBa6yGacK31A
# 0KMYb13wIblkq9Moou7yBA
# 0KohgmStOYkLZM6v-Frfew
# 0KpVqkq7BvG-JSp9FL6AGw
# 0KrHv3TUtS-L10NF5jPl7w
# 0kWxfJ2UIjeeVoJP66tMzA
# 0L6Otp1TRiSWIbZI6_ZkGg
# 0LaBA0WzOdw4ZDFK4pFEGQ
# 0LB-tbw_zLCTL3B3RjcBiQ
# 0LG7PemI3-IkulU57vrWlQ
# 0LXen1cHp1oGE1NEOQqcsQ
# 0L_UjLx4hJlMMEHr5jwnhw
# 0mAdv8Pz49ERExTYyPzi9w
# 0MB6iPc35qxiz5rhFDHU2g
# 0MS4Ig8atRTGCuUYGQULFA
# 0Muh2_lOP9YjABoBo9sgwg
# 0N4F16wDY9PArjddtmNvwg
# 0N7ou3NCevSOeowx5gKm5A
# 0NdOjIjPdBWab-VBCMColw
# 0NG5cImskdfupi3EFPxr9g
# 0nhSK5sfpr4i6ZUwHgERGQ
# 0NmuF3AUZtNzq-pR5WoMjw
# 0nt46V-VbEaV81UQ1c_oGg
# 0ntKEMXJpePMcHoYDnScYQ
# 0O7l8-MiAh8LsnokLo0m_g
# 0OePwTpa8F5sqQLfKcEV5A
# 0og1QtK1mXWQCUzLmXIyRQ
# 0OIYyKLSMLl32IVsPBbBqA
# 0Ok3Sz1Dhr5FBUjkoO24xw
# 0OV5WJwXc4gDTLgpHmrW5Q
# 0OXtgeu2dlHylcGb1ShCEA
# 0P8v428cK-c-dHgIAj4HCw
# 0PANX3yaTY1Z11bQ74cNFg
# 0payhcBxl43WlJSdnrbOww
# 0PDg8IEGT1a99C_6Yg85qg
# 0Pe-GrrTTmMp60oA0woJIQ
# 0PGrIiOu64CU2QBTJluuDg
# 0pmSw3W7bqJbR01NgGfZsA
# 0prnIEpc9K52pM85-3ErMw
# 0Psn8CCYZHqsm8JvLmTI-g
# 0pYwuKfHQF1I5NJun09UoA
# 0PYz7SHX2oYseaFxgBkNYQ
# 0p_vNcT_0LvsTKNoNajUSA
# 0q24j4AI3Z3FzPTDgP2Kow
# 0Q892zmFt3ON2aofoH7ASQ
# 0Q9A9fYJmMRPoug5PgoEag
# 0qBy7R2vDFLyiqcZCopZNQ
# 0qeIe3_Pbs3ZKW3_or6hzw
# 0qkwS-X-3Nhc1-mX7NEI7A
# 0QL32KetsMlNkMrDIf1zCw
# 0r4mpR_Dbx_1lqhEfRHPYQ
# 0RbE-oFyNrCzpIJTcKyoQw
# 0RnxUBqLV-4MfR1kW2oPcQ
# 0RR6iWx9tvLcvolhOomcxg
# 0rRF1xbDQFVBDsnrlmJvDA
# 0s68xTBkClaI37EqcgRRaw
# 0SazT9wChzEj_AH9wTChVg
# 0sOTkxuq-V9wFUG9CQbbzg
# 0SPjG7loAzo5lVMCktr8PQ
# 0SwKfhBnc7IP95xNnnjdLw
# 0tA2kRjyiKnhxpc40dH8EQ
# 0tAq2z-y2WgMvq1W1In9Sg
# 0tFtDheFTiIIEPConav6nQ
# 0tKkbIJoljSQK1BoCDtH-Q
# 0tLCUB-LGK4JPmAKS5iIvw
# 0TNpCYNPOo1c5Vq-ztxd0Q
# 0tysbnnKZGOk-SyzweASaA
# 0TZ4wg5QDLO5vBbRV2y3ug
# 0u3FaC5WLGq_mvLKxM14fQ
# 0UFny3cOYkXq9J8RhLRMhw
# 0UH-3IizefRkP7x22udblA
# 0uHsL_U_sFalxsGiVpGwoA
# 0Utp00q-Fbq5qTX3LkOLcA
# 0UTXK-0rPSKXTenLg9ibeg
# 0v2sWrXwmQlJ80vK91Iqig
# 0V8P2kRlDYQWt76HuysCzg
# 0VbycD0Rm50flulLp2K80w
# 0Vfi038p2TdtPQbExh1J8Q
# 0vflPRzTq-FYQ0J3my2vGQ
# 0vp2KPqyqKxmvUR1RwhTmw
# 0Vsc8UPOf6xf-IKjZSG8wA
# 0vtS3t4ny4B2oF_nTfoUKQ
# 0vu-v1EUl7jIOMDsRsVsgA
# 0vVDvzrjPDPRzd2f_3Zl2w
# 0vXBHpB8tyywvQdFZb-1DA
# 0vXrloJm2nLIFA6natO_9w
# 0VZpPpnAb4F5JwCqL8sE5A
# 0w0eYx0kvL01xPxQ7-Zg6Q
# 0wCxQ_bV7onu-MtYzAaNwQ
# 0wNf0XgEMaB3oTOievFmgg
# 0wnu4N1HEvr5YqNPyVppvA
# 0wpMqijLv03vbJxPdaliHA
# 0WsBRyikf-HoBsRxJmgo6g
# 0X9wVunorwSPozpNUsDzYQ
# 0XMa8LJMOIF914PZXxEo9A
# 0XSaKjXc4DVoyPDYZJ-AzQ
# 0xxhqQ5vvmt5LBqDLPoFRw
# 0XzKZQy1Pw7zawsoVWB8vg
# 0xzvBStoXJNcp9Az_lD23Q
# 0Y6iyzSFXrFemKXupjt5Vw
# 0YNU9HxEXdaEf5T-TogA2Q
# 0yW6ODx0kurrFi-Dpe_XfQ
# 0Yx-EqG0Edv2xInd-Tpz1w
# 0yyUNtEVKlqHAuUO35zpHw
# 0Z1IdCkf1TP_7-E1OJSPyg
# 0Z77CZke1w_JGKYtsD_KHA
# 0ZS566T8qq8rsB8azretQQ
# 0ZW0vz3z7UjDOnues4z6Pw
# 0_UhzI6pgmJUsyxjmSsElA
# 0_xJqX3-c-KyTb90oG_8HQ
# 0_y_gT4dm4Edrfge68xCkQ
# 1-45wRNxBtK37rAzDVb8MQ
# 1-vKSjEbE1AHv4uXCYU--A
# 1-yIMfCJ4nJs75LQVI-VSg
# 1-_cMZ7KL3gq3fdGgZsqVQ
# 1011fcZZtMEfjingJy5hmw
# 10Abf6fT0cW5jai5T9TpGg
# 10LozR-r_PnVyUloTy7P_A
# 10rQTVeg4rO8Cewm-HY-JA
# 10Zl09L3wyaQVi2uIZvYPA
# 10_AtKUFPc2yqAtmp5rl3w
# 11e-vVpJTawPN4pN2mDTEA
# 11E2WQmNj3Mo8hlHgmcuTg
# 11NKfv7sx4-XU_lupQ1JhA
# 11sqcQXCzSESawG0ip36cQ
# 11y3PXH6Qm9Nqn8H0MbmrA
# 12B49eIm7PfZD_AaSHor-w
# 12ng94D1YjCpaJUIGbNrsw
# 13eeZJLmHiFWCxZatk3jpA
# 13ues9nPTkIJLf5XeFQtvg
# 14hZnBAYdwjP78yJQ0trTw
# 14tjgQM3-6IJ4jP41Pj5fw
# 15-BER4cL4t0yCKuagjV1w
# 157BEVhqJyffZrOyRBYClw
# 15kwLK0TFGJE_3LB4GHglQ
# 15OmU02A2qvzbEt1Jh4W0g
# 15stPTcTpSOucv7dSmkuZQ
# 15XcuRt7cv3X9p8Z-rIa_g
# 16GbzwFn1zVnp_uSX9z1jA
# 16OssV1fcjC0gUZDriZMLg
# 177UqjbStkQA07PsZQT_XA
# 17ctjXPY63X_0PTCcHwIxA
# 17dgw70l5Tif9E_aDDOvtA
# 18fF9l5GYMwlEOSmidXumg
# 18NxWPQaLK0BqxoOHHBSLA
# 18txoeVv2piuFjNGAkKn4w
# 18UTnNtyNaTlJ7kVcqs1vw
# 18WajeDfAJxDPPrT0qlErA
# 18WJWDHeuWwh8QACYPqA_Q
# 19bnuT_jHRq7hSgEAlcQUA
# 19s9WIcJDCMTKdMQkPB-1A
# 19znw_Whr75ZDOiYkyei8A
# 1a7bEftKKcDagyPMjs1M2w
# 1A7QdPmmlXiILFomp2cIrw
# 1AbsPzH4A9hUm89C2x1JWw
# 1aXG1Nqdsck9EJy7cOrTJA
# 1a_emy4ugPAhR2M2oene4w
# 1ba8rOWCwXUwVQNHQ--1Mg
# 1bBWIlV1g8_iSZpyW_xjVQ
# 1BEWBhw6jIu9IyjNvllaqg
# 1bnoMb-V4RbXFpKaxrJVag
# 1Bq_-kaEH2knAjOPZh6OWw
# 1BrbxQ3e3i-FPpifwOqycg
# 1BvLhmNMa6A3aTiKezxSXA
# 1c0azGbm1pluju5FyaI62Q
# 1CHtM4yh7kdvmeMvb3io1g
# 1cP-224KLxNMUsAQG4usHw
# 1cQ6akmkx8ISdLUfrUGzkQ
# 1cq7p216SlJnvh9s2H-3AA
# 1cWSOsWhN5C3yfM1i6vVTg
# 1D4_jlrlqZ9BT3bcq4VjCg
# 1DAm0Q7sUm9Y0xBiLF39Ag
# 1dBzFU9v8VV-ZH3fjSZDEA
# 1dpJ7hHZtzjF7oz_qIfyDQ
# 1drABlAeHOcDdc0Ui0EAyg
# 1DsoqGLLdUfEJ0fJpf40qQ
# 1DsQ0qOCC5KscbbfRfS07A
# 1dth4MpBQjfH7txDGFPLhA
# 1e4P6AA39xI1SdKN-HC6rw
# 1E71kNzKyl49VCYcBINowA
# 1e85s5_1ZlIyViktPa2pIw
# 1ea4B3Ydvy9Qz3KSVL-Jjg
# 1eBAAJql9_OX1KEP3KfO7A
# 1eDgSArpkpizhy9MYnJDjQ
# 1EDrn8pm-dWdpJB2Oe8NSQ
# 1eTCk8nB3FSM5V7xogVEAA
# 1Ev_2zy8Xq9XpINS8fWcbA
# 1F0eoTK9ykUR2CYhYWKRKg
# 1f5ZrdA7GuSlmODJAgf8MQ
# 1fAB2GxjFZtqlzyQ2A4wGQ
# 1ffGFRuqtcBnV082QifruQ
# 1FFh9tKH_v9dMPUcBu-maA
# 1fFLvWViptKPFliy5oJM8Q
# 1fhI-qv6dVR-1Kc8Oafb3Q
# 1FI_PunaPwbu_zrEQ58K2w
# 1FwR1hFhjrI78RkAFvVm8g
# 1fxvf6HBpeg7Y0oGpqomCw
# 1F_Knn8xFZQK0s4DLZlQqw
# 1F_zIY_6OhgbrlCsSiHeng
# 1gDpsUfmwjf49TN_JnlSAw
# 1gF0e2xydTqAZFSjCtymvg
# 1go5SJFUQKZtWnyJ_MwgAQ
# 1gP3mX4unGrcmH9jDsBDdg
# 1GuqkdMrvVTQEnVtvBU7kw
# 1gvZ18Z3ULICelbMJt7hXw
# 1GWtGdCmm8PdVkWwpGfgfg
# 1GxCF5uzuGdzQ4eTVS-PMg
# 1GyeWFxH_NPIQwgl0onILw
# 1H-hOHU5gSnUvTYDTvorLQ
# 1hanIw9oRr6leGuxwKaJRw
# 1hB6c4PceFLt_x7hz1hsTw
# 1hbWP2jL1XVN1BthB4H3Zw
# 1HDJZC5zSwiMdTeYeoJBWw
# 1HtvzVsT4QsnGbAPhogbrQ
# 1hx9lUyRA9rtqEBWW7dAQQ
# 1iHhuObcEJ3pP3i-MCP7ng
# 1iIZJ0TonnYrhiiu0RjFsw
# 1iNmWb961Hp80zIEZww4Rg
# 1iYZsYuhlHRE69nq5EwgCw
# 1J35_8i6B3GzNLQNxtNlww
# 1j3CPmAeIgDXyRYq70cG0Q
# 1J4FO8TM9gT3SriKTRN-JQ
# 1JAdXW0yh3pWz1T1FxuCCw
# 1jdprMKRSMmQn-M8JV3aeA
# 1jHwftGETz48sqrKKEoYwA
# 1jlRhici26n-gJrKqcz0uQ
# 1jpT7CLVcjgV8dZvDkGykA
# 1JRryoqqxd_SdyekGSt7vw
# 1kArx_6auMg91oaJImFA1g
# 1kbxX8m_KIe7uL0J0QONgQ
# 1kd_w_NIR8fu2wTt0Hq5Rw
# 1Kizhrwj3o9Llk99KorieA
# 1kv-_w6VlwyQ4k6Vblvahw
# 1KwcADlguydHsOH7KNHT3w
# 1kxuJHNIT-PKhzJhREOH9w
# 1lFlfX-xon3dZ-X2meuLeA
# 1lOM7LfDdiQ6XQsphLH98w
# 1Lqp82f5-oivkbB_boG8WQ
# 1lwfCR7TONxkyElKBr_iAA
# 1MA4jQVGe25XXyNneCww0g
# 1MgHEjKuKYF19tOaeiJ5Mg
# 1MIysq7ZB_C6WaZwA9FPUA
# 1N-SJtwhVhjLta1kvKxZjA
# 1naNXhlRIBe2qAvHxQFatg
# 1NBea5GwKg3WUjGV6Cb3Ew
# 1ND-ZX3ydKP_MMc6X0huJg
# 1o7KmMZxgUk__q5vh_dWiQ
# 1obXsQl7rbn-AbxiLCbSGw
# 1obz149JqftmCTeTTRfBcA
# 1oCsPdqOVv1Rsk-0OvcXmw
# 1ofIm0rWrcopyxo-xeRkQQ
# 1OGXmia1HmI-tIqrNOwoPw
# 1ooZEO7QdL1i35WGU26KQg
# 1ornl-emTtdBJvWKtVZddQ
# 1out0_0JTl1tPcnIe3Dbng
# 1p7IgzXRNGFi3uSLg0XO5Q
# 1Pm2J1X_qwxWDDGvDePIMQ
# 1p_QVLbUqHL3wbf-ujzg4g
# 1qEEAcl5uuoZgG1EBWsDlQ
# 1qJmNJLFoHG9iOt3UImZeA
# 1qM-IjPV7zHao9ektPw_eQ
# 1QmrlOMv4yLKnp-3nmIeSw
# 1qNXhBOBkNJkVXn4nOuy5w
# 1RDct-w5-e_J7UdpnTeqtw
# 1riRzRh6e3Xhu3GZxjIYlg
# 1RJHXae9MANqDri9zCjCQA
# 1RjV6tyQCaxsHqqhX2ZXyw
# 1Rk93R1_mnEeFQgPCe4RXw
# 1RQ_LAUW64X_iLHPBXOR2A
# 1rsk9XLm1ywi7XH5hyLazg
# 1RYHMNJAp8x9JexwBgZd1g
# 1sjPqZ5j2k2uU7QYWGwMVQ
# 1sKM1JXP1Zblsb6umObM6g
# 1skwvgCoCsPYI612YdXzHA
# 1sNWfX5AHVco9oou9Legfg
# 1SzcosFr3-q-YtG66UdmEA
# 1t6Vyg-pe_GQeJg5cGaLHA
# 1TaKk2pS1rHB5zMdEnCHpw
# 1Teb9w_ZQXmRtpTBDEYNWQ
# 1tJJPRerMR2FHX1tlBRp_g
# 1tlYbQK6vNJlfIGbZu7ZLw
# 1TM5lGehnc1mAOUn5IJBMg
# 1TRGT_LAe18LSK6SNQr82A
# 1tXBxkzrWqK0qkmEKqh1Qg
# 1UDwLAhDBDzTJKRhE-CFAQ
# 1UeFbvMwir_4ev2g4l0eYQ
# 1UeOqGHXtYS2bdatbMBmSw
# 1UMa4b12-L73JKJ7siJKLw
# 1Us-asHAYFCX79KJaqe-AA
# 1US0OVzdNgjeJJhjXzgLUA
# 1VBvrSJypGKXjxMxjBg6Sg
# 1vEgg61j2fDIfAHrwkhuYQ
# 1vH1e59ztYvtPOlozjpkZQ
# 1vNOWEbcBsz38xR0AkJ-pA
# 1vVNvmrqMc1Ns7aCCAcQGg
# 1VxjwFxjRGXrSA2pOGtfbQ
# 1W0FV37WGMkpOEppnL97pA
# 1W1vLWp-2GVcxWnEiO086A
# 1W5GzHof6gAQP5E03qGEtw
# 1w8C6R9GAVaPerx51W0voA
# 1W98ZRXxFKO44KXxt5HE7A
# 1wblYsMz3S-HDuHFd9YfbQ
# 1WFwBQG8-tm3vWPhLndlxw
# 1wKghQC395ORsyd1ShL0UQ
# 1WSHy5t0S7vTlFDIL1wS_A
# 1WSwqDymMswNRpiwJ0Ugcg
# 1x2rU_0GGfskEMiyB5SDiQ
# 1X4NOCy8KNSWlXPqQ1b08A
# 1X803WHlIxk5Hu5pHM_XIQ
# 1XfO_DPxlSyDj_NBcrIwuA
# 1xFYAWWL1RVJoAGUOwFHbg
# 1XlegCS4uM1tMjj_PFW5vg
# 1xPGBhd6FSUzwgt44_zkXA
# 1xPrLOJACJlZ6AkJiQE_Ug
# 1Y22PXoaKrBh8manH5Lmbw
# 1YbW4V2NzHmzFEKLvwaE3Q
# 1YGxONvFojWaNfhGWVNQfA
# 1YjCK0SG4qhv8KY0-nuRbw
# 1Yl3K81i5nWyAv3Df_s0Kg
# 1ytfBwiWwZammT5P_DyDWw
# 1YXYXrPqo1Enn9hiAMBoOg
# 1Z1TBiOe2uy71FG6FudlxA
# 1z7UaOdjJ0E9CTK2i5zsOg
# 1zbg4TGpt5MQKtylWQq3gA
# 1ZD84ue-YuW5SIGPaC4LlQ
# 1zdke078CiC4sh29v2ykIQ
# 1zFv4abtHDjGjpBNS7odjQ
# 1ZHUITm7qKMJXv7zbkhEMA
# 1znRtfv5h3gJjDa3oVy5Lw
# 1zr5U5fq9TwwFATItp_1Qw
# 1zv2FqTfWflBHI6nZZtz7Q
# 1zvkxjmamHqFE9ENuCTOmg
# 1ZVr4WwP3wSKYu16SLIvDg
# 1ZwjyA0scakZQWkzy8M7Fg
# 1_AkQUGa28HClogj7CSvuw
# 1_akUsq2Hs5BNsfT5IzrlQ
# 1_T2uWDqVXyZVLKuoPQAeQ
# 1_wVzEv_cTx9P00b62WOGg
# 2-0fS-4QCcSAwLmtAvR3tA
# 2-BUkTjOeHojz31qPeAuMw
# 2-CkLq8O-FDPSzxodmBCiQ
# 2-KPynm68uB4zMaqFN71Dg
# 2-y16x3UxCb_lLiaInnF5w
# 20BsB-D5zARt1GyskDL9Tw
# 20hKoGvGKHAxORWCbvq8Yw
# 20kAtGQEOgK8GbTTblPgYA
# 20OzjZOWplOdX2a2P2-m-g
# 2178B0tL8tGHpyKJvYxekw
# 21ADdIF5lwohAofWxbBy3w
# 21oInImRbkimylaXajOadw
# 21tTX-49zQ_AgE37ZvjDMQ
# 2261t0fvDDlLnpZ82RWKYQ
# 22789SNJIlG7P_ewHZbf-w
# 22bzlXv-2uiiRRU6YKzgJw
# 22nwITWPX0Nqocv2QA3fVQ
# 22UfuNvUV5FAbwpm2whCsg
# 236Va6kAUWR3Q5kd0ih76g
# 23JpgDRedNSy47d_h0o86A
# 23KkRFsnHIuI-oIZgH0qHw
# 23oLXhOgtTT5A7DfnsLI7g
# 23wnrFSG6SX1nM3dGff4iA
# 23XmaoV5DjMUzfB3SzPUFg
# 2441jtFKVqAaPWCP0DJOwQ
# 24Bp4v4-mlvwroqrX56RuA
# 24cmAhf_Hb5xITbuQZyq4w
# 24duBNzA49DVh3dHIyRpcQ
# 24h7SycBps6P4wAm7QP5QA
# 25133qqcDN39InBk1KdTmQ
# 25fFskEyrv3kM1UC2g8k5g
# 25GDM98s1oi8MtXZZ1P5jA
# 25gMHYKgRpmpFf6TQ59t-g
# 25tRkikVLxdhRlpD9Oua7Q
# 25YXytXytU968gs_H_fk-w
# 265ny7421s0Fy2omlykpjQ
# 26bqKSHaRBBtlDPZx5ykCw
# 26cV4_2YRG8FlDCSP-DruA
# 26g0gJZzajaXvdmTTPsyxQ
# 26IzRqMCIftgnPnRAg9GDQ
# 27dlk4ebVrho0_FRFBD_jg
# 27Merowr2-uCOafWvX_MLQ
# 27NXx9t9BNfAS6z7umXxnA
# 27V-pagGSWsTGBuyQF6bpQ
# 27vIp8l4Z0R_9wah5ccieQ
# 27yvtlnGIEzPMifVnY-LMg
# 283a_QGtFXez4YokiIQz3g
# 28K3IJBKqkjYsmZuLmT9QA
# 295RwBQdfZZlmhRNNiBfcw
# 29CkP83EqqbM53Csu9bRFw
# 29dUxlLqBUPnAtH8fxvPGw
# 29Kwey4TTRKPTxSXZLsi-Q
# 2aBbxIy4NV6neWE77xgtnA
# 2afswsOBR05I_Mp3gDLfRw
# 2aggH7f4XkR-1i8Z16DgRQ
# 2aovwlhDcoCmfhTvTLuTsw
# 2aRJss8N0OFe1B2U3vWOJA
# 2ATIzyAviHdsZZLCA-Xm5A
# 2AVKj89OFVpKnd46JF6SWQ
# 2avKZZ-CcNQjtiU4835Y_w
# 2AYGzAX8Gg93yIpNfoYnZg
# 2b2pOUtfsFR4APujYXR3lg
# 2b3Z0b0MJ2asv3THhHp_bA
# 2B59bmWbu5WZq9nJW2b7Jw
# 2b5dZXyXulzwww03AYLPAA
# 2bA_oGj_RJLagRcIbsud5g
# 2BIAOvVUFUB0dmFwxBXFwQ
# 2bMj97OTH8v84BdLDflT_A
# 2BPT64PaqzXqV0BCPbJNlA
# 2BUkdEKMCf429sEcQYGGfw
# 2c-wCzSnBDxcY1b_qwWjTg
# 2CA_QxSmNqrfk8qvpPPyBg
# 2CLntOlwaJBIIch4v4szQA
# 2CO7OHUipHDzNKWBP-_wlw
# 2CPEIwtFJzmijjeNodW-eQ
# 2cr8OB_E63mRn3oThfjO1Q
# 2CSsnU7bZBgpwfvVc0xpNg
# 2cyOZN1qSZb3YLsUetNerQ
# 2cZKRjxsiJRO8A4yY38-tw
# 2d3pJS3MjEjFZG0G2mbuow
# 2Dg63ok8grDtUAkHWjNbjw
# 2dH-WFUdE2s7TjgxYqN3ZQ
# 2dm06RRLp8igUCkWodhW9w
# 2dNZiSKr5SImVwNDq7-ZcA
# 2dP8ZTMC_fopdAWuhleNeg
# 2DTFX41vHqR1hwLy8kO6-A
# 2dZYhGkK9HVUmsZXneiR1w
# 2E23KMd-54oA6o3tge6eog
# 2EG-9qqAB81t0bjWF0iS9Q
# 2eipfatrXp3SeFPFGmhnLQ
# 2ELdGHsj7plRZEdkTH-dtQ
# 2el_nfBOJUFx-AC3gar0Iw
# 2emRJGyu96_oBCPKjlSTjg
# 2F347mUCp7cpMquLeeszGw
# 2Fcdo9pR7WbzOzCjr2Y5tg
# 2FDHorKcw2iwa3tR4dAFaQ
# 2FFtGtDdKPVRrJ-etecCcw
# 2FGOx9Neauy6D6w3uaAHJw
# 2fMA2H6ACjBh46FSPNyc8Q
# 2Fw7WgweQu75FnLVpR3qUA
# 2g6hVFDKFYpuGbK-QDmeew
# 2g73-N2IfHBYbLtoV4zn2w
# 2GIn2wFcMnSBTHH-zgBCng
# 2GJpm7rF-G1JY-p8CbQelg
# 2gKghFDkHSkJ9Gt7xqCH_Q
# 2GLKEXlO1JWyVfUDVoPMmA
# 2gLRdpU0HWZRxMywQMopjw
# 2GvDoNykO_gquJwWxR6Txw
# 2h2jSQz0moHv1g4oeLjzxQ
# 2HgOY0lgFzgDVwvvXjizGw
# 2HI5pi-fthAKQ-ZG59HYAA
# 2HIgWImJ7NbfGCbpPc5p-g
# 2hjcrGPPRq8irEsY2u-z5Q
# 2HoDIGydEeVC4d_8SOZw_Q
# 2hTjd8A8-e_ddWYG95SEzg
# 2hVkch2_vnjRn7GCbqWL6g
# 2hvoNWKlQkfrC7_jNx80FQ
# 2HZrl6WfgOhiSOMNYIo-UQ
# 2I62jcKbCg-mKJSuUZw7tw
# 2ICzaJfCybFCijETv1SJSw
# 2Ih7LIsjKQcXnwrOLyA6_A
# 2IHA_OHJ7mCnyk9d0831ew
# 2IjYPj2FSw2E3cdW3s65fQ
# 2IlOKz52L9UVIXvFW46OKg
# 2IozVYfLo74uMDrBVkt1_w
# 2IqgVMxUH1pMUk0L6ag2ZA
# 2Ix3yvNJY9fwQdZWum3t9g
# 2iY20K2OFF9spU6893DzAg
# 2IzM1YPmFp_wuGFjAyzLmA
# 2J5ZseyWiBvItPV25vMYKg
# 2JaGX_LUJ58blPDwVgkA-w
# 2jRdpOvh7HV3bm29m0zAlQ
# 2ju0KxL41gIHPdHopYgpsg
# 2JX3tK1gr1a4Ml-8nycZgg
# 2jZ0EwBgGpAae2O-z-UL8w
# 2J_PWeEiGEgP3R8RM85j2w
# 2k31qhSialfcJXK1EJMFRQ
# 2K8S0ZRvSHjfm1PwtXl01Q
# 2KLYFjRKEH0TlZsz45o6Ww
# 2KMFcpPcGm18m4K8r4UTHQ
# 2Kq1vbKQmTiLAdYKXTjkdQ
# 2kuS27CVgolRlxmOBZ7Phw
# 2kYJZWPIBROJQe4tgSJzIg
# 2l5qMGuXc1Zew3yxdzfrwA
# 2lAJSfczHj9-rcHEQ36WEg
# 2LBy8QW5xYD-ogFsWtSmQQ
# 2lf9virxBnBT6vD3nStoZg
# 2LHkNHa8OVYbHgunfFbMoA
# 2lR0G8Med8cnZVHJGOgh2A
# 2lRB40TtVgPL1_lLQQevsg
# 2LWMX6sNaGcHtcuYIVr4Jw
# 2lwuVfLZV3VuPEGfs1ic9w
# 2m8oUwbLGG17Itg85h6zLw
# 2MALMTpbQbrQAwyOCcwZPw
# 2mK_8vt03xpGTiglsuZNbA
# 2mV1XwuPgGM2XnndYaRx7A
# 2mzcK-Y1IRG2saTSj-ivsg
# 2n2pXT0udgw0LqOiAQlsUw
# 2N7qGdE7VKR4nCdB1bfjAA
# 2N9kqM9cIddfMGh_08kW2A
# 2Ngre3iNIrll-cTM1gGDPA
# 2nHr4FoBgTtGDZbfaG6x0Q
# 2nK_i1wHGjie-ZnI0GrktQ
# 2nou_pzpJlPPTnEFuGptlg
# 2NuqJw73AwuJZvNNUA26WA
# 2Nvhp5duIvb-OYY7xAMwZw
# 2nWa6gaRL1XtQzgCSI7oDA
# 2NxkY7sX1-IvkdCHav5thg
# 2OaIO2GUbcrEOl_qD04VWQ
# 2OeI10NxZQA1s6Krg4sNsA
# 2oKbkw5mOHN3K2WEiggzDQ
# 2on1Qjj3ki-gD4BriP3ZRg
# 2oSCjYCsLWDJLstGIp4usg
# 2oUobrupvVMXmtrJEhIkrA
# 2OWWW6-gfAuHXQnbjF2ibg
# 2p1LhpFFsNep-KLi7Sih_Q
# 2PG6ZknoxEQnh4F5eelUQg
# 2pGl210yU11AQofpaokrBg
# 2pK7CmrWVmXT4yAd17SPCg
# 2pmaIXtg1MOV51QhnOD2Bg
# 2poL2Jo5e8R5mYy9aKoOKg
# 2polSOH6adr7o5AC0KfpJA
# 2Pt-id-PlQ22cLTowQcgww
# 2pu8ow8i1b4EctWDleEp6A
# 2pXygrs8Amug8WEyShQb2Q
# 2Q-ZVh_wKAYGWtyyOkLxWA
# 2Q5HKg1VOaCEXQt1Q1M_xA
# 2qhLc6lfG56O_1eQX4RBlw
# 2qLGoiManAZgyyx0XSnj9w
# 2QoFlbxaInpTaL9t0O8CXA
# 2qVy3gI-eAfwUaCo6AGfow
# 2R0Z2bMNBWq0wRc4K027Cw
# 2RaBQl9vrWPvZ67FPpwmpw
# 2ReF5M2akq7Ff9ptN1Z-4g
# 2Rg4Lmr_Zw3C6c62x3tCeg
# 2rHQq95tI7tr3B34qxdshQ
# 2Rk-LQHL0tEH23hf10s7yQ
# 2RubMZGgTVfmB0WQCsmDsQ
# 2RuLAjqPnojRoffOmyHkUg
# 2S5RJ650snwQ_QjKZfd5FA
# 2S61TVgn-mmWxFnNCQhIhA
# 2sEWroMIicOwRyEE91c9GA
# 2sjuGKVUrK3MOEKjPXRjIw
# 2SkcSZ8lr1G-3qaN6eQ8tA
# 2SYXukg_XcwH7F-6qHAXDg
# 2t2CB7SvSjamp8y6PMJ1lw
# 2T8whq-xxHa5T30ZxLlOTA
# 2t9a84w3wgg4QFPFBmNOUA
# 2t9tTkHpuYf5AVIfRH2GFQ
# 2taV5obPb56PZWx8nkAWyg
# 2TiZsqCZhPSwtEaR8BFTLA
# 2Tj3whkGqEPoveO5_EXFLw
# 2TO2iMOw9H4m112M_i-yQw
# 2tPcwf6kEf7QkKDiYKbITg
# 2tzeW8gb39yIyf2VzoBVDw
# 2U2Scbs4Ctqfpi_Vo0elqw
# 2u2SgFmuG65aesBSj4f2rw
# 2uHj4q4FDbiQjZWBwO2D0g
# 2uKr3S8lkv4FCZa-mEcXaA
# 2UL96m9cLMRvvvZTDDx7BA
# 2ULLTLA3-1_pOTELRgbNmw
# 2Unw_unY74FVUbGVpdrEeg
# 2UPKaZYSjsQN3mBk4FWqyQ
# 2uqHxN-CD4rkEus_1DXQjA
# 2UygZpPzJlUxIQKJ-2gjcw
# 2v5FCzu5DfZfU-CI4zmqfg
# 2v8L6lQEtRJx8wS0OJBsgA
# 2v8UaxCSylVsnIsOmcf1HQ
# 2VeIoqAllFztG4eeGBA5Zw
# 2vIHR6tgu8XobZV0UMjMZA
# 2VJL2W6sFAho6Ei86isZjQ
# 2vKOHm8XC6zt7e59aocQdw
# 2VocUH1rhqljMer4lhI9zA
# 2vV6G5p83lk0xmQWhmivqg
# 2w2KTS0mPibZ7HFzMBLE9g
# 2W533tZXMbsCv6cSnSHu-g
# 2w53hOPKQQ21vHeKNsZBlw
# 2WcZDAQEaA7krV-_1Xfdwg
# 2wDcFSrON-q7gPjzDfOw2Q
# 2wDFHUSUHHGdCt7x6fOZVg
# 2wi7Z9mTtSxSUx8N26w-hw
# 2WQQJQfF1MbnCFnmnjyqfA
# 2WT8iV62bGIO40M0jiiFsQ
# 2wwbf7-WNT4KuRIIknzk1A
# 2wXTVpLSmzBBOj8R0JgKlQ
# 2x2HRtU-3IHEbeCOF6Zccw
# 2X3lWzNKn9wqQ-WTs53kdQ
# 2X8INgE2OYi72WQpNjwiYw
# 2xbDXt0TQFxYOx6TgrdoXQ
# 2XfnUDVnl8MWf-UPVnAkng
# 2XiTnudcI6UyedUs4dwEDQ
# 2XiYf_iEn5kOJgKLgk-ydQ
# 2xM1XIppErsw5GfJAvsKZw
# 2xompMqJUF2-JxF7ulpytw
# 2xtmBggdqMe8TlfkcKSBLw
# 2Y3141GieyCKewGbQ5grWw
# 2y4VLmSZ3MHP7Q0RX9GUaw
# 2yj6GIvwBUNOQtgLg0MJ-g
# 2yVteAetxq65_SSQOwSdwg
# 2z4tSV3V3DKSIuc2P9ueXA
# 2z7CNCJ1UaJ2sJtIx51SPw
# 2ZD-VONUfTtFhJQt4HAxGg
# 2ZDxgp-IRnPCEcuI0WawrQ
# 2ZeZjP62a73fm3UuBGiAfw
# 2zFjWpLOyZlWl2tFkwZa-w
# 2zGS_RjDAnR2hfk-_h3kHQ
# 2ZM-TdQpG7SL4bEZvZC8NA
# 2zSHGPUJ7UqgZ2N4qazgqQ
# 2ZsmdatqWfBUViG25_XJJg
# 2zvLDLPqBLiVzc6sPnTbtg
# 2zXaKwac2qNIeF8m2rEPlA
# 2zyf3N7fhaotUCu9AafssQ
# 2_dZ9P81wzOA7aGYpTeO2Q
# 2_np39s0c0Zub2Wl91QuJQ
# 2_Zg1yxyif0VkvjnMk-Efg
# 3-51D0Hlv2YtsNeJ9jKYWQ
# 3-k1We9T9EJQInYoeqGvvw
# 3-ZizFQ1WDvxfgAUkDvcWw
# 302vjjxdx4WXhkIkRGogxA
# 30CS2x6vK5c5J0NaN_KkdA
# 30EphRDs0NmbbOhk6ua5IA
# 30rD9jhMxbnw4mqGcTDHnA
# 30uYs1pnMpNILXecHLmeQA
# 30W9bfoKOezx7rW4jA0QoQ
# 31nY1GG0MnMJO-8aWKvbig
# 31Zsg5NV_i9JEXjqjpoHkA
# 32eEAOHpvNLMBZIJ2ksHAg
# 32f9wP5EUyv8r40FAcN1FA
# 32Ix18sApICaU-piP0NJbg
# 32MIzf7UCxwAVB62g8JTJw
# 32UIr4YRx6_OXkMzJIA-gA
# 32xrqCT0JaOr0z_gtds9IA
# 34jlRcOwl7j-7vRLlJ9rdw
# 35jA096pDsQv5q_XxXNu_Q
# 35u5aZRGdPZRGDO54FEwuA
# 36iNN_5lKC_CrOiFjmcF9w
# 37T7kJK8yJa28XpaccQ1VQ
# 382xH63TSC82w2TY-JlikA
# 38BHIqG7S0dSc2BlNZgmmw
# 38jtMsr4GW3DCAhB55EUTg
# 38JVJ7r_jAV-Apm5TIS3Wg
# 38n-79YV0FhNphE70QzQIA
# 38ooFDyrR1r80H2-K1jTlA
# 38wKcOT4w3arZT4O_WWpDw
# 38yvbwEPPc2k1gxUhdwh9Q
# 39Ai02yOQ6REP0hcha5Alg
# 39bQJF94TrvebfWApuZujA
# 39Cmc_DBHOjJi6Igc8SsIg
# 39Dx1Wr20B89sMSKhU-Y9A
# 39lpA8KNVpIcORPTVzrS2w
# 39Mqbzo33aMZqWBsE6xTKQ
# 39V1K6zXZ_lOmq4WFxDSmA
# 39VnQn9n7L2naNBzU0fLfA
# 3A3n3uUtzCveD_yBkTVYwQ
# 3A452NVpPcw-j4yxVkiSEA
# 3aiFaK3Qn-G3dK5lvpDvFQ
# 3aIjBtppymy8pGEoNFPlQw
# 3aKx1Hv2Tr1YBhMYR1yrRA
# 3Apcl0sXXue3aGygK0ezug
# 3AuAg6rHqhpIe-v85wSMrQ
# 3AZ-QMxJE1WYOpjfnk6Ymg
# 3B1MX1Yog7i8PbEvA60CyQ
# 3baI0T_WrvOTQCshwjJDkw
# 3bBuGYQ2bkE5T0SyhXzQHw
# 3BCoezKKoOIM-9gjmxqr4w
# 3BD0-c6fFk_4SMt9is2XZw
# 3bIwxMtmoX4gaHi2iZlSDg
# 3Bm4_u-QI4QEKAS1SW2-Bg
# 3c-WuEahGld3kd3UhDu5Eg
# 3CB-ixZxDaQFzEJumu9Qow
# 3cducotekaGlF5Fg1UZpGg
# 3CfTVaTn1-K_LbpP421khQ
# 3CgY3cuFhqMvD0vavDTlcQ
# 3Ck_JXxad_zhHKoQHC92oQ
# 3CN5QaL5sQ1ZmGhA7yPi2w
# 3CoL4GM2GqGWo-jygUJ5ig
# 3cw3yFRo0suyVyObuKdEPw
# 3D3ydCw4pXtgnWGo3OK1dA
# 3dE5L453XCGGaPVlFjw9Kg
# 3DMuwfxNwfu7Sb-sE4muIA
# 3DnCVgkDhJR_lvvNUzHF7A
# 3DSbhz52_scrbnemn2dqEA
# 3DTnqnLTFT4V8NA6ZML7LA
# 3dUnbhALXoECpAI1PZ3gqA
# 3DzRQi6eFW3zaMc8pJKgkQ
# 3E5tyDviDeBXjAC0X_AcVA
# 3e7otPlM1Fe9K4YenCagLQ
# 3efJ5xObaAXhChm1WMuGyw
# 3EKtrWaMKotijmZ1-fRw5g
# 3eO-DMDBb23wQckPAbXgrw
# 3eodkoH2NtePTDEpraGktg
# 3ErseJOHCZS5WWg5SlW_-g
# 3EWHj43W0X2R3jhexgrh5A
# 3F1RmC24S5T_D9nj2aA5xg
# 3f8I-GGqV7Mb8lV78n6xOg
# 3FA7cjtTNNMdm5em0kLyIA
# 3fcvSycO-SU5HTQAYWTJeA
# 3feShvtc8Q-seocwPXA98g
# 3fg_BOVkDurpu03ib9SmYA
# 3fKxUjVHruZchmRASd80ZQ
# 3FoNC9ECZ04UbBL0d3jQbA
# 3fpFqzsf3xF5drMPTeJyAQ
# 3FXO4pgrnP3hqCCw4A8kZQ
# 3g5IuSVFdbqbKqlSsrpj9A
# 3G7d57oechZo56nzLgp2lA
# 3g8ho4TYKtinTRc4knm_3g
# 3gCgVvC71bPTb4KjTzHKmQ
# 3gEHBKJipEZZNpHotzi6-g
# 3gp7fQM95pCcMLisEUou-Q
# 3GRfiCoy9vDUs2hDJMp7iQ
# 3grI1eb_m-ySECt-mjaUkA
# 3gZbVaAIHpumtt-_v9gUUg
# 3H-M6UGDv2zAbnU0NqqS7w
# 3H4TCb1_YrnepXZNbNBHdw
# 3hepwiMnt7QQoLr-JfUn2A
# 3hii2_FJulc1rCA_tyu_wg
# 3HipILLiorEPR4nUmO6kqA
# 3HSNacmSxWTFq3GwTuhhew
# 3HZSbWkwgTXg_1EprI6qNQ
# 3H_k4V8DmFUNVfU5rEfteg
# 3i1lgNamE8w92_7hv_GK7g
# 3i39JRv2KbXWNscgwxrGxQ
# 3IB-95Cm7SjcydpeBy5SZg
# 3iccLjJIeZ8DQj6JyBYISg
# 3IcXcZ8ALbDORz43UWst2w
# 3IDS3Uu1CZpGxWg1WGznAg
# 3ifXVNK8WDWCk-Nsk2PzqA
# 3IgDxpZltEd-WKPPZgmspA
# 3ILU0AG4xNhLzRcqPaka7A
# 3imW83bhRVpZucwt65wqKA
# 3inAsQexYzBp8693FNk0rQ
# 3IRIRpk_TO1w1f1r1yltqQ
# 3IxutmQyVK7x8goSjci5xg
# 3j1KVXoC4MyHrjms3B-PfQ
# 3j2tX_w6kC-xcfTZzS8I8Q
# 3JH9KIqbb79iHKHd8Isqqw
# 3jIkfUufFZcQEb5siHOPtA
# 3jIStyTxl02e1FOWTWX7Rw
# 3jm_TnxLf8RaNMONLLxnbA
# 3jOSBSdEYQxGqqUpWDC73Q
# 3JpIM7mtMNEi9Wl1X8DXmQ
# 3jRuE3FdxJ8oKF7VUm-u7g
# 3jx_zT_SNnPdlMmeWc6Y0A
# 3k3WkwuLLcrCNDMCxSntGw
# 3kcqZK7_FBZnAhq-lE4U4Q
# 3Kg70UKtLQbI68k-Pkw4tQ
# 3KioqG-m6ccBaosn8arfXA
# 3KOQ_2NvTgnJktkHAOtoPg
# 3KqBQPLmZ7ay_iBxXLs6uA
# 3KvgCOd-p_grLJ4na8Ib4A
# 3L1kUL1mySeJJjuYuBhAQA
# 3l8l9iYc_rNkw4gIhSYn9w
# 3lcywMrNk9025ZsU70O6mw
# 3leD7jkuT9qAkf1Imi1lCA
# 3lkcZwb8RMADcuxllEPqYA
# 3Lp3REISPtP4NyiNru5kYg
# 3LWx4UvZpb-UxHRqAcepGQ
# 3M2VX3JXCOMcVLXj16ot2A
# 3MQCIj6RFHDPTmsAcx8DVw
# 3mU1_MNshrtk_q7bwqBm0w
# 3mWs5lgojkrUkbq5qUfJyg
# 3N3i0Gl1dUPGX64rTi0LQw
# 3nCk7wFTsmbLcDpjRnkuoQ
# 3ns9j1AWybu9CW0Qk-gp1A
# 3NwVbwOEUyJUwP0Dwk-FLw
# 3NyBnBf5SU2TO_YWcbUp7g
# 3nzvHwwJkbYqfFhG9u12TA
# 3n_IyXOmDJ42uZtXzbScrA
# 3obBBYuP4fYqKOh_fnekgQ
# 3OdeVtOrSNbzrsBW5TZwZw
# 3OfGNbezz0EuDJkTV-XyZQ
# 3Oif-d3v4vV8vTHzkwjs5Q
# 3oN99zip6L-TXjxLPAK9aA
# 3OOHPpFFEgjuKcWcr_zy1A
# 3oWukY3raGE6QAQgJ1Cp1g
# 3oxQ_B5XoN5PLBR9zUREgg
# 3P4LEb8iy0EF-QWD6DDtiQ
# 3p4UmGTA34bUzn-EZFd5Cg
# 3PaYhRUNqal4Pg2cyiLbXQ
# 3pBA_SQM-qTVgOxwZEYNjg
# 3pcgY0nCOwr1tTrR5qhkhA
# 3piTjXPqVrA8pFv7WWUwMg
# 3pi_x7iQstaNiev1mDfFdg
# 3PPsZLcDWI_RLNYvaAtEdw
# 3PsrujMDDYMve_hS_McRmA
# 3pwWY1hStuDHu5LLKD-NIw
# 3PZpBha4oNlwpGbc_HwDNA
# 3qFTJUNuDEfMPkOL7nZM0w
# 3QI-3YMMVE8rrwSc6rzx9A
# 3qiuZjdkbF76ip_MuKDlDg
# 3Qj_yZ-DBfidchtenHRdqQ
# 3qmDcHvPMvvQKOayYzCQCA
# 3qorfjHSLAvcN-dGaweMeg
# 3qPIV_9Sw1G42o-9qWLp1Q
# 3Q_o5LxVvmF6dRKT6VoyzQ
# 3r-t5ES3YalN8XU3yIfAzw
# 3r1bF3zTxw0RxJi4rNEfXA
# 3R4ZN_vA1qb5vjUhhcNGuQ
# 3r6xrzVrFaFMIDhT-gA-jw
# 3RB7MwMIeBcNusnU5bdl-g
# 3RClcfxHI27-nboPlHFuyA
# 3ReL18otnnfil5iLO1Ik7g
# 3Rl1pqh2OPUxVgCCp1zTjg
# 3RmIGRw0ClOYNaBo6dqGsw
# 3rmyf6PCGxW_Th64v8Q7Jg
# 3rPZ5klezNiUzS17X1BNAA
# 3Rqwl0WUBMW_hjj8wrunBg
# 3RRB6_YQbPmCWUJyPfIg-A
# 3RYJup1xVWPIMOk0TmvOyg
# 3s-Yt-qSl_P8vFcHLOAvFg
# 3S08KTAe8c4mFPnLWNhCeg
# 3S7_XWRmw5UFHxJKsLxA9A
# 3SdHpC8nwI4yCwF0Punhgg
# 3SgnxEl1WNYZqEJBV5E7gg
# 3shL_96xI949QC_g3ZYjSQ
# 3sJQM2GyHjsTOwmGgwhMTQ
# 3sOrQHMIeF9O0iSK7tPSuQ
# 3sQQEQLp5RZH1__X10Tk_A
# 3SYDZNRQyfi_8GiDa-6mig
# 3syXRsVTxpQKJ3bnGvTJyg
# 3TBbRZaM4Fssc5bu5lIGmg
# 3tC7ocA9XDG25f8vnDWa1g
# 3tDFQejz4vmd-iUCHg3eGw
# 3teol3A9u3t21-Fhua2WHA
# 3tKKuwKSRkT7xsa67_2OLA
# 3Tk_6s8LMc8Zl5uhIxJLOg
# 3toU5qyLrb6cchJKYBZf_w
# 3TsEG2euKkkik2OMv1GniQ
# 3TvtvMNqejjY7Gc5qZgFYA
# 3ua1DHzsDdPbynTZ9utxgA
# 3UdQ-mTV6RxPTmUIVA7tqQ
# 3UGJMqvLUNh7ELSv28dYEg
# 3UkqtJg7y8itou1zpJs1ZQ
# 3urMhkj0YQ-W8O9JUOa3eA
# 3UTkl8opuwdk8UJdrRjryQ
# 3uY00spjCX2PmSeS3JK4Fg
# 3U_IgmfyqzefQjQiOCD8QA
# 3VbIzy6x1-5iOVEXwdOarw
# 3VdeVi9lWfCFZQLhigWQyg
# 3Vf5KlaoepGJGCqxROycJw
# 3Vfy5S_NMEUD5QeInLnfKQ
# 3Vkb0BuEMrrsFnmaj6yobg
# 3Vmx7rfvzDWpPrk0cagksw
# 3vNJR2zJBeOH7YollsTnKA
# 3vpEdqkJcWQaEy2-zCXbyA
# 3vVxeqgiiW6QLggM8TpyDg
# 3vzA6uc0d1s6AplbyYlkqw
# 3W5k03eqCA7xgfnA-AWuSA
# 3WCnGyax9ljo7NFJQ9ssEg
# 3wg5bslMRxT5NFq_iEOC9A
# 3widlgin58obNSOUgqh-aA
# 3WjebJrUQOM4T8eRSiLW5g
# 3WJ_2Jvf3ymIiJJNNIjqYA
# 3WLXx68ASTgNLcYWQBG8QQ
# 3wqV9Pyoxt9CGOygZErH8A
# 3WU5czgLnEc8KCda80WkfA
# 3wxOHEEuKh5mu1S5rl9AIA
# 3Wz2X8hEgharCwPII0_7bQ
# 3X-hF1CjvT38C7dfUSzgsA
# 3x5ZgN9exAY1Le_CHGoOtA
# 3xfYMOzWo9WtUhqjj9a_KQ
# 3XHCQhVjMASzFi0K-HdX6A
# 3Xmflsiu_ik4VICmnzzKOg
# 3XQROa0gvt2BzBu1kQNTEA
# 3XydshlX5HxF-30r9ZlYRA
# 3Xz_KMaj8JpV_eIZb3AZ7Q
# 3YCs8PaSOgGoIzapXaOY1w
# 3YFRPmjahgVSjtDTbtAWBQ
# 3yHi_BV3Dn3TLxkPQnHyiA
# 3YJL6VRyFm-sCuY_0HIgjg
# 3Yr7sYFO6Lx6DVDamgt1sg
# 3YwsM8izaRSXfCj2A7YhBg
# 3yXw0529G9Nh77q7x9QjeQ
# 3YyiXZ6N8Hx7CdWhNYdr9w
# 3Z3F245REaeMrGHL97sCYg
# 3zcZjpvjm19DBYD21Dx6kQ
# 3ZerKYgnTfZMLILJM-M5yw
# 3Zl9XTmpfim-gUm7QQBMJg
# 3ZPTcv8gsujL1Gh3HwDBcg
# 3Zq7s8ZSqkyo3hZ2eaYuxQ
# 3ztPI4rIMI_qmfm_JI3OVg
# 3ZvRHD297edmrNMY0tjszA
# 3ZVu3Ozb2oJhDQ5mXOrVXw
# 3zxGaV92D97WHtrRpc-L2w
# 3zzVwxQIuYzX-9FVu6MKAg
# 3_7OqxqDr664Rzp1OlrOAA
# 3_8rnXk9KnloiAExBR326g
# 3_Xvx1M1hA16iw9i9z7duA
# 4-5jeZaPBsUpbfwfaSBOLw
# 4-JeN-tOFfwIrMM03oGMHQ
# 4-Misron4_kc5rQ1WophrA
# 4-Vi6yBQey7SGYN1PA2rcw
# 4-Ysiq6AlVbWjm5c5_5KgA
# 4-Z9ccQtdUCDk3EvLqZM0Q
# 40-xCObP8WPWscCbGCQLOA
# 404uHxLZj_uJzdiJQWjpjw
# 404yl4qrd_IQb9qxcHPH3A
# 40t6Um7akgt4ChtMSNBp8g
# 41ajMXn0xsi93AEi6ew5ug
# 41MeNiLklCoamMQtjYX1-g
# 41q0zAOiXoAjmxgBLRQK5w
# 41ZXS4tlXbHqKqry44Z1aw
# 42An0WlCDI7uMvTamNJsVg
# 42bwZjC-9IMQZavHSthXSA
# 42d4z6xRrySkXJXoxutfMg
# 42FZy0HQfk3Rcs-wvMBqAw
# 42tigCsglAnf2zWHKU_PQQ
# 42TXbFRsuSRQo8cSyyVwRQ
# 42yJZ3QMmQtR-LTO8C3H2A
# 42_s6bc6KPMg--ovX2T4hQ
# 43gsTYpptp1FHD-YNGDzZQ
# 43QUYniyvEQaxiJHyurX5Q
# 440WiF6NbXCXS1GrzzNi4A
# 441vNwUSCr3snBpafct2mg
# 44hbtj5aYLL9MHkUi1Eqbw
# 44ItqbYjhaG7HvGLu7NSsQ
# 44Nu3_Cer6ckIoW1MiBDuQ
# 45NvJWmIDWlNW9CPE8L01A
# 45wVw1GV_0OUI4cjk5rJhg
# 46cG5n9hdXbsMiOhFKFZ2A
# 46LT5g0BZhU3KuG2VXOK5Q
# 46YesX3UyZfmgG9g881xRQ
# 47DFfFBKmeZHceae3Y49xA
# 47rv_nX9aNbpNAjD289cHA
# 47s5-_j-1OVg_oYvOZb29g
# 47yDC2IeDHcYjmx84kySNg
# 481_PNb39ix_Cg90Bcct2Q
# 486FW6XjHMNsVyayB1vuCA
# 48peSPR5l03D4xhjm9UT_Q
# 49hCxE8Vr9E0WJiK3o141w
# 49lv1c5f22VoWJ0Rq5oPXQ
# 49yrqxpf5jzgaG0nvRs2Dg
# 4A-hiJxtjUQcKJh1AGOCvQ
# 4A4hF8Pvnat-zey_OYychg
# 4a5BcYXETqUb9hgzIPga1Q
# 4a5Vllppovph_vTZL1S-3g
# 4AAu20gor6sdLqwYfgkS4Q
# 4agwnwdppqfZTQmreVz5pw
# 4AhW8sM3bvbwOvzy7juyFQ
# 4aQ3KWAYytAVWK8dOkSt2Q
# 4aRgTTcopTftJL9mwbPOZg
# 4atLGsbJCV4uMq_otBbO3Q
# 4Axb5bvivFxNWNjSqGjwaA
# 4B0WVCVgMYhKJZ224jxLHQ
# 4baBo-xVAO-6rZWBI4kF_g
# 4bBGvwRJetAFzYjxKIx8OA
# 4BBm3OA5ApXEG3wtYCcu6A
# 4BIBtcpIAJI-GkOagAjw2w
# 4BjBgRSNm4s0i-Ivdyiy9A
# 4BkzGCwVXy77yFE4vO50oA
# 4BsOt4wZmB2CIXDyNwAOBw
# 4Bw74lKT05XiX9rVfiNC-Q
# 4b_djKcxmHBO3acuE0pRww
# 4C7Kycv1sujqEmeFFeuhpQ
# 4C9b-DvmF66Z2qcwvTOESQ
# 4cauwb3CNKjcz4eVsGdpVQ
# 4CBUyOxh4nvmfyio3dVBlA
# 4ch-DaBL5AoTDOzTuJLBGA
# 4ChKY7fNv5ulu5BNoxQAdA
# 4CO00pCAZELnIh8bmb23ig
# 4CW8SD7jlWCVHAXSlSR99A
# 4D8o1rEfLcLuH5qa5dyU9w
# 4DdqJkB217IefAutGGr6uQ
# 4DkS5tSm2nBlHTwLjkAsNg
# 4DLPcWYKAD1OLPfId8b2sA
# 4dPhb9XwXToVyf-ogoevnA
# 4DWysMnNdCDPoFoIlp_Q9g
# 4eBz4z6YAV4rBMr1owju3A
# 4edQdkRCpaSbyDuYrQMKZg
# 4eEw9WL5LoqCxfOFhWaSUQ
# 4Ef8UK4R4RF80ae0RzVEzw
# 4EM8qZ29UyhjD9WJodIlcg
# 4emWamskCn5R795lBnAKqQ
# 4EwfbzhskHDz9HvPxBBrOA
# 4f17hPsIAovnvp9HAJBh0w
# 4F2nCiLRAtOqSyCTMMOJDQ
# 4F8NEi2w5s8V5T9bKweBmQ
# 4fC9r4lWHhuUpT4js-3uaQ
# 4fiDjwjhwpGNz-LTG1wbpA
# 4fSZuK9Ix_fzwBFoLxaSnQ
# 4FwKcFy5ESPPZPeDWXT6GQ
# 4FyvuhN4gErUnqa9n3rwQQ
# 4fZwhBNwAnbmVsmLi3d_2w
# 4g795RPBQqgR-kv7Fu4mjw
# 4GdeOv1AuIMzHL30ATjHPw
# 4gFntUHznVsgo_gC3UOCNQ
# 4GnoTfmbaw0OC7eXW5dpXA
# 4GqS-lHfeI5-qHY9i8Hi5A
# 4h4XFWjbFhKNsHcpNnESbg
# 4H4zNW-Cbd4B22wvpGUxYA
# 4H5OSbphGi7j0QtYJgNXIg
# 4h7VKgW-mHWMzyZ_WpNa3Q
# 4HeAbRiugZSMvDi3021Oqg
# 4hh5s_o4QSLutGrqVsNfQw
# 4HIDeL4UjRMnL9M7j5sYrw
# 4hrNsihJVJlQ8EwvbWdjhw
# 4HwmiDGVjAa6XJhMVVvafQ
# 4I1POpErpuzXkgPk0RQSdQ
# 4iCVzNF1zWyk5Ojdqwxbgg
# 4IG7uDVmwu-JCrZ9eXPhBQ
# 4IMdOrlMZiYIEH7a8OWf0A
# 4INDoY2LY7dGYBP4jdhN-g
# 4iqCEvjIZKJBc_Ke090jUA
# 4iWA8IKPvs-ekZlIbZKNuQ
# 4Iw_psRdMZ3sNDLJ7-xn6w
# 4J-Jv4o1qgBvXirqZ12wdA
# 4j8k_B-GOphNfsJzU2cywQ
# 4JbfYGlqClgtyM4-kW89KA
# 4JeeUs0EFETa_bGCGi3PMA
# 4jU1FrdjWqGFxBrMFXvXjw
# 4jw6t5KQ5R5xGndUHqdgGQ
# 4K-HlUbCmCqWNPH5fC9y5w
# 4k3cqXZNBWMee-B4uC06gg
# 4K5xEZ2HS4KDuLN2dRPC2w
# 4KaBhokiBsseNu45xjRvzA
# 4KBfxSlwaO6VICDrBHnmXA
# 4KKDPhTQyLnmYz3XpWOJog
# 4kShFJ7l6S0HCGuIIVj8ZA
# 4kSPlOdF_oX5Quyy7BTXRw
# 4kuThM4icGuONZH4_ZQ6ow
# 4l999G71y19q7Y8LWBdy3A
# 4La28UVXDubTzitzAOpXsA
# 4LjjJT9HVf2y9RVs62Vjhw
# 4ljoO-TsbA-jHgkNsmC6pA
# 4lmKD8XHZBfptBzkg5HdXA
# 4LpuW2Oo6EwmhokBR3d6IA
# 4lus7CkNWZTaVw7IQfDwHQ
# 4lw0pWrlGUzsN7URPqLDQw
# 4M4fUQQWV0sklAf4ntUe5Q
# 4m4IeMXtsLn6fPmEWKIyMQ
# 4MlwXVsvTVFs_6z4YUTPAg
# 4MOAAW-MwmBVcoJbBcF4oA
# 4MZ1KqmPmHpPNdofuKhT5A
# 4N0EmnsHpEuToFqgL5xvFw
# 4nBNmkRXrsQoSSqS-GbABA
# 4Nh4VMi1mpwtnsVRFsy-ug
# 4nKNJwmk60VWerggdiPfJg
# 4NMOr3ypcRD5vduwnsVeWQ
# 4nMW9AM88M0yZaoOJyEmvg
# 4NSezjlNeWv-Ec9r5swvig
# 4nwhXaqbkc0CQSnONaecGg
# 4nxjvwiN2GgfVNPXONcQ1A
# 4NyyLeSiGBRM1QouE7VqfQ
# 4OfPXolmcJcwXujSvMtdqg
# 4okrvwZu7gESGjralvcPrw
# 4onbz35inLjQyC5yZWZe0A
# 4oQLqyfF31fcVdFc4JQlsw
# 4ORM4PlY5oqj87ldaS3i8Q
# 4OtKVZooyjmodF60E-UNvQ
# 4P-O_FtWuP0yBBKP2YlPkg
# 4P4yDqWQaDkJmVBsERvWFQ
# 4P7-cFyh2PeFqlbHBQ-Z4g
# 4pFkhDE71kHaFY1NriyEuw
# 4PI5_75RrOGXUl8C2pwvzQ
# 4pI_dz_m9mLruky4TVk-YA
# 4PlRIX5ITtHod7cCW_eJug
# 4poBDlA_HvslN7BF-aFyLQ
# 4pPdYIAmfvbBqBOc0DmZFw
# 4pQ8rQ9p0c4oZIlKwSrpLg
# 4pw46FqcI03rsNVbpVNCig
# 4P_CW4dnuaoNKC4g-_XnzA
# 4Q12AnC-jE_enclOwX7wHQ
# 4Q6MQc2iGlx5EZ0eClueeA
# 4qidlaadCZP8BRb5VTd3RQ
# 4qLmy0JQ1iqgooA1mNqOcg
# 4QnX1QLSCUjjKHVN2m80dw
# 4qSTGfc8q45Cl2tx72US3g
# 4qU10zqfCPayKi_0Ai_Vtg
# 4QzLuxE4sDjZpYeqKbEscw
# 4r0tL6FnMedPdr61QEvWHA
# 4RcG8jJ5Mx-qbhaywC-pBQ
# 4rM2L_0Wlxs8s9ec-BoK9A
# 4RwYHGs0dwqJ0qXd5DG-Kw
# 4RxcR1rIegsNNFP5_f_WZQ
# 4s5PDRH9fNrbOJTOQlwiJg
# 4sEU2swvTqxhN2VLxGyD1g
# 4sji6q06rDD3fbXaYuA7LA
# 4sm4Z2YcFLmfsyXdPqOJfQ
# 4SMO24JJ04I1BGWIlfWinQ
# 4SOhLdRtZvd4yu0OW7eI2w
# 4SOUJlWq6zwQtmRm2EYCAg
# 4SQP6U7jimbGl1XwltUyLA
# 4SUJ-7NBxri8N-9qmhL8aQ
# 4TeI3hsrGEqfrhhVDgvBCw
# 4TGG_yIYTqd_bhBvaeA9pw
# 4THUIryTtewpoRGuyEoNog
# 4TPLUiukcNDxybMVFin-2g
# 4tw0PETye4KXO6lmSaSytg
# 4uJf8Fyob9f_gvRu0IsmIg
# 4uln7WeYFutx8_esxtX8MA
# 4uPKJ6435QDk9gwdo11g1A
# 4uyYIzCqJiDOHE3VuBCzTg
# 4UzMhPG5qnd_cbOAJ3tBEA
# 4VAWnbTiEUMJDIRv3dm-Ew
# 4vNZZasW4SqsdQoHIAJtMQ
# 4VwfkhmTM0cL_22fJ_JHZQ
# 4w1ZCaQAjf2JLWCYGVcIjA
# 4w26uzbhHULXRqgAhKPFfg
# 4WelUTSV2D1USS-NuLCA-A
# 4WILfjXTlpjrvi77BNG7wQ
# 4wlm2-m9bQR9C8AT8bSkUw
# 4WPDRRqCOniejQPC9MXJyg
# 4WS8awckumPbQ9TesutFZA
# 4wzRVZIO8BqNp9Gt8WTNoA
# 4W_ZJN7QQX7YXpX1ir_O3A
# 4xdqPrlCiTDWGXN0OaAnWQ
# 4XF6jWKX7MOfqda5WMP3ww
# 4xtDsW5azDgoDRyT6GY3Nw
# 4XTrwjGESCFzhgx22TOT9g
# 4XUE_Sj2X2gNElAMDY70zA
# 4XwNJtG8OyveUKn0kLz83g
# 4xwYixJ39YbYp-Ra8QoEUQ
# 4y5tiyJLwEpwnP3Rw0KtoA
# 4Y5U2biFo4uWNWJdKOMxDg
# 4ygxx3xbJmUBdbD0v9MRZw
# 4YISglmn0u7c1FCHhQdpbQ
# 4Ylkt_d6FxVKaiWphYOyag
# 4YW5EFkeoDiiTl2bOrMhAA
# 4Z1lsB0bMRsHVJHM9n2ZdQ
# 4ZbKRtCx6_FF7mW3sJn5hw
# 4zCwUlhrBRDqcwF7OcOV1A
# 4Zh0tmUDqUeIiJxjwGvLnA
# 4ZjLVNJ59tPFosHwWGkdxA
# 4ZkKAPVap5iy4-IaIz6jCg
# 4ZLMmsChurvCyNRZ3U-Edw
# 4ZOXwUeCDKobJ5lxRImYHw
# 4ZwZf2kXjRV4xhand7AENA
# 4ZyZJTiU6xhZCBKQ_8ZYzg
# 4zZ8t0XLI0ad_i3lXYqLcQ
# 4_80TxY6yf1Go1QeY6QDHQ
# 4_jKZfOz7FkXMJuaaK_RFQ
# 4_VCIqmZEFd1VQk7MZWTXA
# 5-boOaEhbEWW1c1shfokGw
# 5-c8RAFQovjJS6TeKV2ANA
# 5-vEx3LLdH4QVE0E8ZMe0w
# 506DEiUGGGkkY_QyDFV1MQ
# 50PDhqRBboi82elhfCVYpw
# 50sRa7oqsEktFfkYlgKqlg
# 50wFrzYFHPLEayIFOB41uw
# 50x-R_qN8J9h8b71yoM_vA
# 51FxR5AqweU7bDomEFtcnQ
# 51KV0T1-9jl58vOEF31ABQ
# 51lsQzsi_NiI739C6u96QQ
# 51RM_N9F5gGELxTCClEtOQ
# 528c0WcpfM2xC5DoWIFpeg
# 528ttqLd_waG2cttM0IBiQ
# 52D7w0tsSfAINI7TID-a5A
# 52Oz_LGAb1gZdTu1iqV4RA
# 52zdGPUoerz3Y_9t1ug1Ew
# 53-TnzoH9sgBc2W4hBRJGw
# 537QZnJ61xU2owhY_QHH-w
# 53MKAlSpzaumE4mpiVqT3g
# 53MQp-LugqqwMg7MER8Mpg
# 53OusFiU9k3FCSUAVBfHXg
# 5403CnaMPUprlWt5cWcf0A
# 54A7HnuGOYCmBE2RJpVszQ
# 54d1oFGJ_NC3asYhDlNt1g
# 54D_2MR3IgKLTXq-svf53Q
# 54EY5nrMZeICC8YxJL7qgQ
# 54jYr5Ea2hkTM3q6FWSWlg
# 54QyQsDeYSViz4vtiZydXA
# 54Y1KPMEBFrypvsOTr2Uag
# 54_7Yd8MSLVWOPaHXwpmOA
# 55ZXMxAYliqO-e41Kab6vw
# 569h5Li65AXmuBfzPgJ8jg
# 56hHEZ4hVzCtLF8yc8PqYw
# 56V3O7uBwUAx-I5nuMmfIg
# 57B36cWTm2AVpS28KnRO2A
# 57J-AmMRKjixLOT14FJnpA
# 57M3kL9OEN8BTE_d1TNCbA
# 57o5zE24ib1ZM41bte7qmg
# 57ROFdTxrsiNWEsUwCPpeA
# 57wlV1bx42C0sqxIx3OVpg
# 58NFVbyl6eejkjuAgt3RPQ
# 58Og4VJX--hFy92YZnqBzA
# 58tPSYNWxKth0J-dWsWxAg
# 59-5LWsN8M_ldUPzXT7vdg
# 596O8-JFviUWCSkBoJTEbg
# 5983SP4pi6fLz4R3VtrXAw
# 59KakKxK3LOrgQiNar_rZw
# 59MSBxZpSDmrDZrTW3eB5w
# 59SoRxi3j3PYxp9PQMxNWw
# 59tZvw0v2QNG2Bc71R-SoQ
# 5A1unZiVhLSgNXzcS3aCQg
# 5AgpHD3TGT47Pv0QvnhSrQ
# 5aItyLZ2aOCFlCObD7poig
# 5aiYTGwFluxDqf0Nb8veTQ
# 5ajhpjS7WKNs1N6Ql-vLxQ
# 5Ap-NDby96JEVOvN3E4ogg
# 5AuULwzDZ0qabMiDHJb93g
# 5b62PYfZBE_xOJ1eUrK_jg
# 5b6n5KG863ljKNve3zU4lg
# 5bIpd4WMBxjsghc4FN8I_A
# 5Ch4ZXyGsdwj7vVjkzV-7w
# 5CJhiC5otd9rpQ9XYyzoTA
# 5CJYMxoMTg-hPzb4UL6e2Q
# 5CzcwmVX6jqOdvUI2--6xw
# 5czVlTJKYlVqjoB58Mz0Pg
# 5d6VhLpoMZ1NFxf6pEnRqg
# 5DAFdRQRR0OGIr-z0W1ZDw
# 5dBAWnMTnnKpobN42Y6lTQ
# 5DD6zcG3lkHmc1iOLgnZHw
# 5dDIWi7JP6u_MFChxq-m_g
# 5DdXMg_tQu4IBwQpDHuHCw
# 5drYBXojsH2yL5ULCFgAGg
# 5dvZls2wnDa4nbQ4rg-IIQ
# 5dWjYSSEqHntqXw9kEpRMQ
# 5EBWtatWPcRKG13fkeB2nw
# 5eFKVBXaLMTnC60NL9_BbA
# 5EKVcRR3IJjyyscseEQJpQ
# 5eptXkXM3PZBZDaZqP7m_A
# 5EWbQOzNF0smjHHcLPN-jA
# 5EX3KqG0Vuzom_5FKtryhA
# 5EZp4B59m4LuUEhkkA82Ow
# 5F3GkvWHknzbw6i5bF6ixg
# 5F6gNj45yJzJhClHjWUX6g
# 5faiV0rFpkAzI2HDufA65A
# 5fgETlKRXKwpHennRKAyjA
# 5fIooPZ5bg_B9EfRQRvLUA
# 5fQkWpYgmd0AoG4TL3oQdw
# 5fSA5UKkF9HS9vKJ3YagoQ
# 5FuaZ25Kw2DgfWNtTehL8w
# 5G41hI6sLgvBo4Hdz-qoGw
# 5G4T4hlktDuEKee3wzFjMQ
# 5gak-Nw7quDIPHVGURBV_A
# 5GGAcRS782S64I5amICEbA
# 5GggSIG9PGLoWBhuY1ZCOw
# 5gK0HyiPpznlQXWpAClJzA
# 5H9shsQ7DolzFb_PyCOOdw
# 5HncZr_XnwspyAuEppYzLQ
# 5HNTiYarzb8iRR9tVuDzHg
# 5Hoi6KHdtFkzPA6dQ6ocgA
# 5HovZm4iE0uuWAIo3MpcPQ
# 5hpAHzgz5hoOQiL1Nm1Cwg
# 5HR7vIjdceqWoCaLczYPJg
# 5i3mFOt92fEkvrsgCUFp5A
# 5i5IFpn95VmOwDCmVpuIlw
# 5I6xq0DJrO292riRxHqMww
# 5i9qEqPya01LmgzMK1knzA
# 5IhYhJ_vNenuEUsHIx-2TA
# 5iMBYXx4bFrhxOqWKiaK4A
# 5imzxooC8fPY1g68xbXaCg
# 5IqAUirN1ZqVTTtPDrjy9w
# 5ItSau5dZiggFXeNspRJ3A
# 5ixuSH7aeYKo7Q-2SRRsww
# 5IzPIQxQWAf8i5eOuuCVKw
# 5J7I1z4fW_tx1g76dFOjlQ
# 5j7xu2G3wnPs85Gc5WdnXQ
# 5jCRlfJWNj918qb3u7YABA
# 5joo7CJYNHFD1JnUcYoe2Q
# 5jr5IcHbiBezTzixgfxmvg
# 5jyCUnk3dcEMcKAZetHw1g
# 5jzrxpxQ2gBZILZwYzpNLQ
# 5Ke9eY8ELtI--cLy8wIBjQ
# 5kKsE268WFwenIhPZxpGcQ
# 5kQQuT9kR0h74us4rGNLFA
# 5kr4AQLMGf2ROo_33-iF-w
# 5kRvwkgi_7VpFAcJbLkIZg
# 5KywishsJMo4xvRpws6akA
# 5l080b23WBaQgDrghr7-4Q
# 5Ldp4pRt60zCMHsN2L9ICw
# 5LdW_9_Mci8KnW-djzKyUw
# 5LgGmrclsdrWuSKSLaa-uw
# 5lI-20B37VkaUp1VR3vEyg
# 5LvAoFLkkKMDYme601DlwQ
# 5LvOQZ-KYU_4ORJrPWQFwA
# 5lXYKjNP6LXn3haiQxaPPA
# 5LY6UG0mfn_-M8UA2xxKag
# 5l_u7RYS6W_1nralBTin2g
# 5m9QoGIFwsotyOAw6mq-wA
# 5MkgNxwQA0oWCG5N4FRIzQ
# 5MPryyYx3zBgf1dCH-UQLg
# 5MT-HiEpp3drjikyoICtzg
# 5mt_kNtN4_GBYqc8oCsuXg
# 5mU_hJnXn7wrFJseDSSxcg
# 5Nfsrt_IyPtMxGP35JsquQ
# 5nJdQjFJ-mGMjS23zb8WPA
# 5NLGvpfHS3z-F_ezXoVC4A
# 5nreWuxNYaY9nqAlUxowMQ
# 5NRtkU219muas5qb_5yBZQ
# 5NYjBzj0OaRy4RlB4MTbxQ
# 5o9aHdaSouQjV0A8g4CPHA
# 5oe9pXjMS9GWwsgqJt7EqQ
# 5oFaVvMiVrece2YDzeA2Sg
# 5oqKxoX5a_WGHtpFdPxvlw
# 5OXJSK-J8MgoFgO7jLbpHg
# 5p4IIq1jatiu2esTcZdXiQ
# 5pfLq-nBycXj8MCXiSFiRA
# 5PM6na3seYIc5JEiTQCf7Q
# 5pPMWciz94vZb1DNbkedxw
# 5pprS3KqzT2TuMiRm2UPZQ
# 5pUOeiupA2GliY_1IDcdIg
# 5pvf6oLlicbPTHXjanplZA
# 5PWfNGYNXgvbX8Wfmo30Jw
# 5qdqeNxeyTfR4onve5PJBg
# 5qhwxLrv8RAII-VbNLwtvg
# 5qjUMIbaeGkdCwWLRSBhNA
# 5qozOoCIVpxWAJ9BKrAn_g
# 5QRKkjGq5RxOWaAbOxTPvw
# 5R-_ansIvfL9bOBMVS5keg
# 5R0csfphhchg7Xt7Krb5ZA
# 5rGIljVgv1jKdShLRyuZlw
# 5s8Up3AcS6OwBr6a0re3yA
# 5SAAi_OKphs6imsNe8f2hw
# 5sE6sHJCA_baC7V3DNWDZw
# 5sHreDBHkYHcjbE9NEHOBg
# 5SQgQw1tHc56bMZWzwTTcQ
# 5SQwIvPZrXblh6wtLc8j4g
# 5SUS7FBwD-tH5W9VlG25nQ
# 5SWXCBV6czef0iYLBcBh5g
# 5sXIPU5rLuGWHE1BHX0JvQ
# 5SYX7i4qJFPfmWGbrUznFQ
# 5T2RlQp69lvsFF9iD3rJ8Q
# 5T7PuvQs526xUGQSXVbKrg
# 5TSnqdPArjqiDqeij13lXw
# 5u5WJPPmf9WVAf7atNDYyQ
# 5UB5WjZEaPSDCpCWUazT7w
# 5UCYB4P7whakqCvvr7qFLg
# 5UIDjjCd-ZX6kIIlUIqY-A
# 5Uos-OqbBriIv-b6Orxs2A
# 5uQuMy5kfp9N48p0ZjJYCA
# 5URIWoNohQVPfkvtWB6FEA
# 5UtKWmdI14S0vuekjcATMA
# 5UvlEgel4PP5JUDxsddrgQ
# 5uzaqI32ZNjiGSLfodmlMg
# 5vH7bvOMCAtbsEAeOfE77Q
# 5VHr0vC5_HGuHaVILWA7fw
# 5vM9kKwlEjUs9CHRhpDyaw
# 5VxfxAjVzGRbT5DC1mpJgA
# 5W22B7wNjDsqkdIyVOCkYw
# 5w6YX9gchbupxgNey0QcXw
# 5wAypJZTUNmnwsLnzZLVLA
# 5WBCF2aQTmdrjl93p7icfg
# 5wC6UNWpI53KI4vDoCQwAA
# 5WdJ9xeQtpWcc0XuYKBPNA
# 5wgs8GhgiK4aFOiLPnwYkg
# 5WJmc3Sr2tm9Yt7SeB6lOg
# 5Wnh21pNvbBlUxJuCZIhTQ
# 5wwj78egPVgy3oc_ynA9HA
# 5WxTmBEmbImsffs6iMeqpQ
# 5W_ST75fbJxYYabnNPRowQ
# 5XB8w32K9RLahAg4AMWMrw
# 5XHIphKGTQ2UquRZViByrg
# 5XMCOBaY75r-s_FyZtobfA
# 5xxMoLHbXm2s51bVVPuY3w
# 5xX_cHrjK3vZkjdmVSsr5A
# 5X_nZuTXZlLoh9VXWjzVqA
# 5yGxY73Dnrio1sRtQCQ9OA
# 5yheevQIFF1F1YVdv9zzOA
# 5YHv_s5hjLoDDlO3Ua0ndw
# 5YqLVBCtOtA8ieT2ncQPiw
# 5yzmP_zO0ENzsDybzH9haQ
# 5yzNeAKe9oueKbYOd-mWBg
# 5Z13SjW6v3EzFhoVP7XWmg
# 5Zcf3vUcs_o59pPN3CkjbA
# 5ZF07xNB9dJwn7TeFkY_0Q
# 5ZlKdDxPtia8S3rvJij53g
# 5ZlsvgSW53jsFAW6okOk5Q
# 5zVvcOJf80a7oYVy-Y4Bog
# 5zWB52W8BrGRfKCSfIeJ8Q
# 5_F5b_-epqLuU6SRVZZM0Q
# 5_n62UYKs2jtdQmQS5eD5A
# 5_qVWg8LKiXOaNiO8mQmjw
# 6-17EQFccAm7NANVO4RNgA
# 6-DqJ83NOSThFmR5VcAxsQ
# 6-J9R7VrWRYdKWqBM0Grlw
# 6-JN82oUGsmjWgd4GufU8Q
# 602D9N9DybpcxLtG9_m33g
# 6054Yg_dX5gfrN4otSr66A
# 60MdkTfmioz_KKedT3ccfg
# 618YueOy5vbZ0KXwtYfwdQ
# 61Ae19VoJGVSIxRU9hXxAw
# 61F0KAXFhRKImCjQ9_WYYw
# 61fx41YIe9DNfASzq5A0aQ
# 61khEaqzv18vRLpkpxn8qw
# 61Ptilwk11hi8E8MIdahWg
# 62a3imvjFV6OFgwa21B92w
# 630R_r2tSsx5psiy0M6eCg
# 63P62YovTsN4mMTxQsDTfA
# 645n-Hr2m6fkgS9uaqhJlg
# 64iCWzwvPY_Z9JriwuGO1g
# 64IkA4MYecfSuuZeh7_aRQ
# 64QzuFEtkWyO8CU37YYXMQ
# 64W091V_Z8bxkphyrXP8sg
# 656sRQCtFZV9P1uUxjcNFQ
# 65asDqGz7fy9JSjIfNCoVw
# 65M4Z9gY-KF8v9-KuLk23A
# 65VciXc6WFYAA3SdFaQEGA
# 65vhtv19pOrsEIqRORQ5cQ
# 65zi762Q79FjQxqRuMsQ2A
# 66cR3Dk1cp3DxLvXwheg_Q
# 66IVU5xKoGOibtPMsMrhGA
# 66JzYaF0o2V3v8OLwnpaVA
# 67QYMGk0rBZZPRMyUeCKtA
# 67S6_HDBKbVLbFnVLeAXHg
# 67vCk9fhmG_00bDpsh7x5w
# 683KKESbU3ZVH1QziJfJbw
# 68elaQ3l4nd3WuBj7xQ86A
# 68Ifrdr6d5CO88kYytaIzw
# 68XYas1ADxW1lQfC_j3F0Q
# 69J_45GMksItOneWmmqXIw
# 69kVT3xGWr4-30eP-YfZ3A
# 69wZlDSYcEQFja2xOoNbHw
# 69XrQgxtNCOl8h1Ya033EQ
# 6A7ULdaxcZ5BrH4xcNwE5w
# 6AA4NvhsZtlZCri39rF1XQ
# 6AfHPvw3nxdAApuGavwslg
# 6AJn0n3YlgYwFWlB_-JUjg
# 6aMOa43EtbNeCYw6xSIEeA
# 6arUEaL7xkq_yfDz6xyy8Q
# 6As191fZ8RN7cZxeE5jVsg
# 6aVUB_LppLCO1UeRWGrgtA
# 6b5mMizByhnSRFxtRdj8_g
# 6B8tDQPfZ_bBM8TQF4q7Dg
# 6bIBK-MFfLbUUR_JQFkBcg
# 6bJlU6-y6LYJ7P9tz5HwxA
# 6brVQmNm4efka9DGJ5u5VQ
# 6BsjFSnSub58WLHWe90cZQ
# 6bwD3BSbAIBhv6UsuqDMQw
# 6bx_Z1UL47sI4Eg9vzBnAw
# 6C-qPgODabbqnpcmKuKyMg
# 6CF8jUio3vI2qY7BBcIUBQ
# 6cGuicSc256_d48GLeSWgw
# 6cnA1Bv7AyIjAJwJMu6yqw
# 6CnAjsC0aE8hb24fZfz0rw
# 6crlKAhPiMKnu8QeAUyqVQ
# 6c_pLzgWQ_L2t3yFNCYP9Q
# 6d6LN47k8MCzkgcvFsNwXw
# 6dcqghr90ne-ZKdQpmnNKw
# 6dgYlzZAd09CYP2cNXL_yg
# 6dkCm1gv3c3F8NhlsZqSGg
# 6dPUgcSYEhwNe4aGAHxFlg
# 6DRZAoWes2q50XBRTz8dcQ
# 6DStJrHktwh-wT6o8EWJsg
# 6DUm6rXVLB62A9IL7dmEbg
# 6DvaUiyC1DbAnxIhY_MQyQ
# 6dxQ_B5ZkP8ksYkdD51uwQ
# 6d_in2mivJduzURikG0O-g
# 6EdoKaqsNpNizfUX5kD1Jg
# 6EE8OAst7ZTqBccVucq4DQ
# 6Ef1tJEoB9cZdUEKrED9wA
# 6Et2ZIjy5eAzyUe_3nOdPQ
# 6EYmjXmzGaj2D4BCbnChxA
# 6F9XOr00pwUSJKoRiCjnvQ
# 6fb7XUsMxpffoYhuyG8u4g
# 6fZNJ87qJWKz7SdJYHytaA
# 6GCdlCxpCAkmW6YwFM_Jsg
# 6GMFfc0nTwA9W7DFlc1u2Q
# 6GoqtNl-m7eA8mFCMDZlNg
# 6guh2PolrwaHDZjWIebpYA
# 6GYb-4P6hZJBujPoB_YHSQ
# 6gzWLq2FWdjhd9rQccW6Nw
# 6h-aByB9JpgT0RcEsaGn4w
# 6H19o6qjbgSH6L4Vbi5naA
# 6H4QCQgkBiarjFVnFHPUJg
# 6h5lPMVTiwKWeDaZJujh0A
# 6harj8HtXBRLbZIciATOtg
# 6HBYelx3JwXSFk1nhwo7og
# 6HE3mzs15tECWRqAklrikw
# 6HlOh4hXTzJpjN-rOj7jTA
# 6HNq0SGhF03prETn60zrhA
# 6HWHyGi1oGvHBzWrAv2wkw
# 6hYfLI8e-dsIH32GlHC9tg
# 6i3E1ggNBTC2E-HPGM8HXw
# 6iBK0K7qk2nkpeP7-zwqKg
# 6IDHIFwtYJtzw9riin-TJQ
# 6ije-6x9201ukzGoG-G1sw
# 6JBmbjkF2ciQuWZi0_jPPQ
# 6jhm5ZgtHTnWZmL6_8XOSw
# 6Jil2w3-SQcXrTtY3nAofA
# 6jqjx_arTDXI11ZzogGLTQ
# 6jtyZ208GRW_C4kGvfQgvA
# 6JzS_7zqNpEHhPOXKQJuLQ
# 6K9C7KHR8b3YAFYpNUXXUw
# 6kL_A70rCVYl50qtcO79Dg
# 6kT-_TTvkewnHCGvhiWqqw
# 6kuCsJq5zSEfHRlrWY41bQ
# 6kXUNX0szERWmwt6YLYAPg
# 6L1GAt6k-bSvf-oUnGZBQQ
# 6l374X0E4ro8lQ1_wO2t7Q
# 6lEpQmsI660B20qSgC6RTg
# 6LIwpzIhgvw6aXxNRvR7jg
# 6lLxPhe4A1XtaFNscJuN2A
# 6LvOUw25-niti_naYQCgNQ
# 6Lw32OIkA_SQZJQy2uFiMQ
# 6M0zvoZIkEHm4UVQOdJXnw
# 6M1cWrjdz2brIE2l3OxuWg
# 6m75SxGyH1KPKOek7LzetQ
# 6mhjvIlzVCplTwSZplBtRg
# 6mlTHzDsv69RDAVp7bMNbA
# 6mwXF-pNNj5YJUJIkdHsQA
# 6n09mMX38hvgxTIZR-qItA
# 6N1SQ9w4KsDngHylqcIM4A
# 6ndFjZGI0uNvokIyFc-K9A
# 6Nm-4-p-KhwwDVmeyDYgUg
# 6nM2h_LiRGGAB7Yb9ewo9w
# 6N_TYV6p4lgNoUp_lOXQOw
# 6obAf9CRQh_dBFHPAIiRFQ
# 6omcYu73eKatDdWUviP6mA
# 6ou-7BD9Cq9VRN0y-EOtdA
# 6OvQ8DLz41jJKPYq-NIQYw
# 6P1drkbxytYGuq5LhNh1dw
# 6P22LnbXgSdRVlt_VPmRiQ
# 6p7vJ6Xf0oozl6W3tmvhlg
# 6pdjvVg41IkkOUiLBw5P8Q
# 6pntMpLo0belhyeJHK6LXQ
# 6pzEsL3jT2ouoXED2Vevjw
# 6pZNlBC8S77punWJcm-zcg
# 6P_OPXDkbfpYhn9mtlcCsQ
# 6q2_pdsbQVHreaGouefyTQ
# 6Qm6I1uXA5Y8jgBdD9K_4w
# 6QNvFFRyuUhUBiWUgNoObw
# 6Qu86KUPbdWzNH4UqGO4Ww
# 6qZs4lf1XSGKNL280sSTVw
# 6R0B7xfXbebdlzkTtmR3QA
# 6R3QO9IiEEOd3CBLLTMu3Q
# 6r9vmmFcsBRrsItv7ZZXjg
# 6rdT6Mvh4bPMy7yZH6nlHg
# 6RfJZ9pqbkODziho1qMD7w
# 6RGRki5dig4GsiVuuH1VEg
# 6RhFKAOYs-izRGlWKQ6wXQ
# 6RNBI2GrQnZ22GpKqJdJUg
# 6rsAJDpNbB_VmH71qo9riQ
# 6rsnJyxDTX9haI0tO5HzMA
# 6RuBccaC0aJiS8xjUMJQGw
# 6RVeJGEfsDzlPd_RrmrLAQ
# 6RyBQgl2JLmdTmBvOZLo9g
# 6s6ZY0HhjfDHX3vWswBgaA
# 6SbeUsOescgM_QOcrkrNcw
# 6sbUWtSxM-oDXmPQJLYDOQ
# 6SdtUh7zE5LVvhs0FhXk9Q
# 6seYSUojTBUcvZJeHL2L2g
# 6SKcZ1Xpf5-nmLw5joBPYQ
# 6somCp4u7IZC2et7T_zcqA
# 6sOPn6bzqBZOAdzJcdJgRQ
# 6TzJlesX5OLSS7CxPTLH7w
# 6ufGKCZbMhxrSa1ql5PXpQ
# 6uN1KpRBO_-JKWUqovKBAg
# 6Uw5dZuHwqxJ-G5_imrKhA
# 6vjnUWOZ72hk0oEPrnYN8g
# 6VkYPjyuybFcNduf_AKYRA
# 6VmQv7eJ7lM2U9-_0Zobtw
# 6VuZXFoe7cwZqYQeSCYK2A
# 6wlRAcyxa4lw4Hg4_cn0Sw
# 6WmSX-n63zVXXEiFwikTYw
# 6wynGjBxFEVdhZ9_juR0XQ
# 6xnzKJBqQYaWGQbY0-ly4Q
# 6xQgIyV90Cj_K_aX8yE01w
# 6Y0ATS7cz1ZwjPyM8JYOFQ
# 6y2lTz2tTbVDMXsMxntw1w
# 6y9-iJBjyx0dVy-mrWYnxA
# 6YECZ-qPvAW4npkf0f6GCw
# 6yGi_KePGkVQesMOvUZ82g
# 6yHx1R-PBjnb2GK0p5LZEg
# 6YJ5okVdCRRlVvNejHVPtQ
# 6yOCU9jsfdffbULdftckEQ
# 6YQN9uYxQWnevcb2jXGN6A
# 6yUTRFMNSpcHuQ8p9jBy6Q
# 6yxlZpH4W6wX-O0BagkEEQ
# 6Z6SSf10MSi7aCZGbHThbw
# 6Zh0suYlpaee9oupW-mnJA
# 6ZHbuLEsOx6PwbYmlGGHXA
# 6ZHWl0vKFTaDntEZK_dSjQ
# 6zKKX27qFcLO5710vJx64w
# 6zmgRcZ-1pAbcQYPs3SpgQ
# 6zn9F6TQy2c_kEuvTIzJjg
# 6_LCFsYppRcFv-4chGzaNA
# 6_YpfI83VP7YF2DCI5fNVQ
# 7-m-p2b2zUfr3LYCMQTF4Q
# 700Ud5Q3LknOc54CkOzQlQ
# 70vSMBAeglOhIzvDduFBJw
# 70Z79SZy-ayPcBhEVvlmXw
# 71CnMgj5duOQd4XdDcHfRg
# 72RzrqcpiINLm6JHYh8bug
# 72VhsRnGaNP1XbKJnBFuPg
# 72Wo9HN5dPgyniYMmzPmZw
# 73ZmL00hZbhjWkZ02rVkcQ
# 7402WyUTna4BRuU5RUmeEg
# 740qLpmnmg0wvMTVrA2KpQ
# 74csAe3r-KSiEFCEL9jy1Q
# 74GIBVpaYFUwRQ5MxDhoQw
# 74gnp77A1WauQWtXLu_NwQ
# 74HYQPJNuSqMQXxWyMl96w
# 74lm3VQlEl_teyikqk0mRA
# 74TUDq6_cqo1W3VPyi4HUA
# 76h5HU_1MQVr_0dmgLRUrw
# 76kC49fg8FaW4-DHjMrWnw
# 76OZEQ6zopaRCrWkKAXoVw
# 76Qbjc33UET8TQ1S1Iikpw
# 77TNsaYi7EKsW2oJf1VWFg
# 77tT6j30ks_LggUGYRpPWQ
# 78l3szqOqKnPl-jLWKZTQw
# 78lOUUzfw4yD1NhmoNNqeg
# 79P6_GJh4uPay1OykEyVig
# 79QpYMz6OC6mIPR1zBO_qg
# 79Xy5yPfi212nuzSYu1gwA
# 79YI0cAP3hU_YjnxabEoZQ
# 79Z2zV2nk2GeSVzHE8lvYQ
# 7A2vrIZ95hPw34HOsITDbA
# 7a311SyoyAJVQdSaIrJhRw
# 7a5465U-V7Yyq8OCRYJORg
# 7aAFB1DtWeD-GyAmvWytDg
# 7Abgn3eQT7xuhljzlRCLSA
# 7aDkEUJmMM4joC8C9Np41g
# 7AgOyHo8HVOSAZ8YyKD4Bw
# 7aJWili0O8See4sl21VArw
# 7AtLlr_xSjx73lfa0VOgmw
# 7b3_ODjZjnBxtqNEZOQxuQ
# 7Be2JeIczvR7wzm1Q6Pgww
# 7bEs3nR8zcstE-hOc9t8ug
# 7BGD7nehxXr5Vs1yQQztnA
# 7Bqo1OG0NzbCq4czMGypKg
# 7BSPjkZyL3PYOC55RhCx5A
# 7BTeQI902vbTnfpgVbGGng
# 7bvvPB8XdMfh7dwOtH49_w
# 7ByXhRODTKKFDcsiZ-wihQ
# 7BzadvL6tPeGotqEMW6-tA
# 7C2WKocreBwVc5zj6H6Ipw
# 7C4pLLP-tVa1lr6GsnPSqg
# 7cBqInFopI3cIvk_vO02vw
# 7cBZeXPL6H3T7sk7vEKqEA
# 7cEVNvXwR5loJZwJvbdvLQ
# 7cGH1s5AK1DNPR-8s-D3Dw
# 7CgTC5v7XzdyZnAI4dju5Q
# 7cMkYa-odoyQnTno4tmYYw
# 7cRXJ_9ndgHqDN72n1TmJw
# 7CULcCD0ciKKlS-0grDhHg
# 7CwF-J84LYPQDm1WDXyO-A
# 7D1ORHCKhCPgtdY81jszzQ
# 7dDjWst_gHkoNV-CuJl9mA
# 7Df7gOFFANvrqcDQbHI0VA
# 7DLS-Meq7NhE3qnW7BckDQ
# 7DpXzcreClT71WIPanzD3A
# 7dr4Cszty20X3mTRLtiWrA
# 7dXcyg9oCu8A0mJ8-fqfqQ
# 7DYUDoVwoXIUf4t2n1zhFw
# 7EiBpD0BkSL6TAPlJDcVPg
# 7eiKvR4hR311K2qrWxdRbQ
# 7ENXa9HYInblv5eNCeFTmw
# 7eTlu-Q3HnKGz2eh26gebQ
# 7EtTuBhjaBGGLvJwhmXb3g
# 7eVt5IkCxGZm-K6RaANjvA
# 7fA8aFnfhZ2tOh_nsk7e5A
# 7FD9JXwpQZhDmN7h7Etyjg
# 7FEpBlRYyDDyFK1t3jeIHg
# 7fF3qknptanuJn_eMiEciw
# 7FNvh4Ya_3aIYDCSVMUKNQ
# 7FoA_I4DtLKxuVA4ZcEZ2g
# 7FP2L2bJMmkYSNXM_nh5Dg
# 7fYbnbLxoOySlPp2tPYv0Q
# 7g7BtzZ9mC570nsTy3L1qg
# 7gD0tETG6fqp6k8aBaVHUQ
# 7Gk3b1Al1pBN_qNmTkHUXw
# 7gpMkgKIYmZ2xj_RIYPo1A
# 7gsWdahIWSYgrwe_ElqMHA
# 7GVOb8InQqPraAahZNtQqg
# 7GWhhLfphJsyVtwCtXSkfQ
# 7gyVm28lLp18X7Sm-vMfzg
# 7gYygne_kXxoLHg7I8dYuA
# 7H0_I7GxJAUQqLAwqVee2w
# 7H9o3RpqMDUa8o4l4chdGg
# 7HAZ7GqOH1Q8_4kCzDpdjw
# 7HbkLxmEnWsbxqrNRZ_Elw
# 7HC65-VgS0ZCZZb8XgBJZA
# 7hCXTtQh_iAO4Gshhb3BXQ
# 7hToYrWCg8ojYTWGCX-H1A
# 7Hv4Rwgm0SkJnW_LgzXxxA
# 7hyE5fSuPAD_H5nREI5PBQ
# 7I127edsvniksPv5slsoGQ
# 7I1i-KJyxONKd7tGL8Dw-g
# 7i2B0ZVoX1sAMZwp4mghQw
# 7i2ZIIr5iLuT9PPtq-6k9g
# 7i5Q0dTCf9gHKd-zHETyug
# 7IDaWTITgKctCrkI5_jxXA
# 7IGYVwmxe4pnqvBj_tLThQ
# 7ii3PIVvlsByj7QLE-T55A
# 7iLJd1k-aVxKUiLj8apnHw
# 7iLW8hthyuSepRvFQjWHlg
# 7iohJnt9bL3572q-p-jItQ
# 7Iu4f8TjdkTLcgncFSwubA
# 7J2ZI7tkUsWDWrEuU3IgBQ
# 7jaBRR7fjBS2VuO-y-YnGg
# 7jbwn0s8FlqJO1wnEV6xrw
# 7JCYDni8fKg-z0UVxvOysg
# 7jftBbP7AUjfGs_Dl7bqAA
# 7Jjf6wYb4z--B_v_id62Vg
# 7jn9s8JfZIIbhlTVW2SUmw
# 7jnm8yJvsndKX03z6h5YpQ
# 7JnUammN2kJT6lOG14DBog
# 7JqGalD2liCVwwOWqteNzw
# 7jtwAV09fnlpfsWdQFr-PQ
# 7jYU5td7Gj03IZKO4zaALg
# 7k1EvXn7ogmsHnZpmsv-gw
# 7kftjfDxxkVqBSDeNHkCzA
# 7kLBtcmGfXrVc6DzthnNPA
# 7KOArAIBpY4DpHwmklcrBg
# 7KQTOD_LVnAjtCX79oysug
# 7kTyzpCrvgRPRszCbgYNCg
# 7Kv1AqjlbU2VEbr1h_ywCA
# 7L3NIlXDURzXih51PHTneg
# 7losYbsLi-8J6WpNTO7WTA
# 7ltHD-MwRLosQOeb79Uypw
# 7l_bJSUIC1PB2dTSyUcA2w
# 7m0rru6SVvAre3gIlb6k1A
# 7M7uIsR2wSlntIY0Qsr4lg
# 7mIfFYjWwU4nN1Pa6-8cqw
# 7MkuEA89IUhYHYbNaZnzHw
# 7moWr3vF9amZmOm-snS-Qw
# 7MTa045h1xXB1qw6YEdCrg
# 7N1qpPmOWfaAayDL07tJnw
# 7n2rmcvEcG7B2edctEJsmQ
# 7NfJwqQWgoq0c-4Zxl8Q4A
# 7ni0vy6c0mLWVKevcVp6FA
# 7NkRV3ZMDSdj5wbyy3Bfzw
# 7NMmN6NHa9kEiILf288yWg
# 7nnCxM1H7gheU2j_jNUGsQ
# 7nu2G-YoriDL6UB9zuipmw
# 7O2YDjOdTmKHvBjwR9td7A
# 7o729ZnJHBE8gF4zWyWCeg
# 7o8eJ1h-tpOG3AFM9U7Ufw
# 7O9ZcNisFY29bSj8mKNk1A
# 7OjRM6lYxSy2HJuIUv47bg
# 7OK5KrFd9Ve9Fs5amqcQhg
# 7oQBbJh4gWXcB_0iywKfPg
# 7OQlhZtHelDCrtEsCh31AQ
# 7oyQWIbkhBj7Y27B5RDN9Q
# 7p0ziO38ZJLDan_RoEgxIQ
# 7pEXa6abCfKKnHL2yLFlHw
# 7pfny2r-I5nptvJD3wivrw
# 7ps5qvPjJwwIWzLFat0OFQ
# 7pWY6dVVowKFG7-TWZPB7A
# 7PxngU4bpWmXmRA4PVyH-Q
# 7Q-AtJP9qe8ObaXmuRdmKQ
# 7q1AcC_e-A5YN93BGklQrA
# 7Q5Ezwy4UpIIsq6jrG6WWg
# 7q8nFhpVPn9gFeWzTjlUbQ
# 7QDXMNdtennNhUuWffiHNA
# 7qF3bNFyWLjGJzl5SxzJ9g
# 7Qn2WzDgiamBnzn_omscDw
# 7qNFD7jxHoDYTN0lxBTBeg
# 7qSTNlukSR27RY49VYAjdA
# 7qy6gbJ7VYvBIMtOUBpYIA
# 7qZmnpQxUKhAzCphB7tdng
# 7r-QRQmX3h7Uzk9E58zjog
# 7R-zJWxj5NbdBDSFtX4HLw
# 7RHoBy_fJuT1MyL_5mYpBA
# 7RPLmig-L2_vJ2CP8iBYHQ
# 7rwkXN_RdhJR_ei6wFCqmA
# 7rYc0KvLn_QkJXgVBHbYwQ
# 7S0ke3muFLi7XM3ecQLXWg
# 7sbOJONjVO8cwOdVQ-lJrQ
# 7se4rim71P6NmHUAinfJqw
# 7sjfHFjh3D3i7XOw5Ocpzg
# 7SK_rHF-c99JwZopyLEjRg
# 7SPMOtVBWPy0SEJu7Jq5gA
# 7SYK4xyAE8Rdz4xeQj2E3Q
# 7SzRYoj7v_y8LLm8O8POeA
# 7t-OcoH3QmoK2sB3aFq0aQ
# 7t8kiVQJhyVJz9s0AbALuA
# 7T8oMowBrxtLZm9iYzFpJw
# 7TB7I77TULYgXZg0Rl9rGA
# 7Td-IRHe0HLMiXbVIQCoWQ
# 7ThdXnN-2FjK05PiPo7Ung
# 7tpbb3x-sa296Vy41JCAZg
# 7UfpwqjWdgIjXnDN6qk-OQ
# 7ukrffgtGSxa2DTSakbcsg
# 7UMhfNug0SSVHRUs7Ihmig
# 7UN79GaUQkCcbgerXSMqZQ
# 7uNlwBM1Ab_S3iL0JiQJ1A
# 7uWlNJS6XpBeiQyKOSU90A
# 7VaROcJBfnaKaQpyiifLgA
# 7VO4YmFT8qN1UW5S-y_7EQ
# 7vQlmvpGy0_gOdckJ86n3A
# 7Vs6RGxD2yuS00CpTlpg-g
# 7VXOlkcJ11C0ladZc3CJCw
# 7wCBL6QoxJZtgvArBbrOow
# 7wD8HgoYeJIOn9EizYGoOA
# 7wPWrvtZk0r0oi5k8naSPA
# 7WSVPOLdl7_6xeJj4NKRpg
# 7Xb7JMZp6YmSR-nECcWDew
# 7XEfPqcafRbYstwwT4jzuA
# 7xHdNvK5JlwQmTpQwQkoQg
# 7xhVO_zyr9JDGz_P-EXPhQ
# 7xKvRIFzFLfnmwMPGFjZfQ
# 7xOxvDbXnzR36gqbpGbFpA
# 7XRBKlnJgggfcvNYOgD35w
# 7XwoDk6FcFEu9Jqcu5ibug
# 7xzC_ruY31RD6TWnpMzEvw
# 7xzeXkwAT8928zKHTp8b2g
# 7x_AlX-xKY2r393hI2qozA
# 7y0dUNyHtdsFugn0uASWpw
# 7Y5MP3RlFLHOG5xecE8ovQ
# 7YiDuGhneHaBQfyHDr-mSQ
# ...
# EcngvT0KSg3JIof8PSU63A
# ECPRr-iuEj7xwQNiY5zmog
# ecT4B8cmA2E0PwIqMS8Q6Q
# ECx2AvhcDEgFFcc4HXghgA
# ed0xne1O1fGwEaO0lC1iag
# ed1TbXwBAsdj9w9oSqsXuw
# Ed2TH-LNgWEwWZuuXcX16A
# ED5PFTJNJmmEY0U-tcyHIg
# ED92LBTvz6LeSIwbbOyS8A
# eDc-YzabrhA-qT4c-wIl_g
# EdDEASrPMjWoBl7aXcP0aA
# EDfKrruEc1HO4gtbBczEkw
# EDjCJyPuZyxlN-Ps5GtUJw
# eDJTMYz9ipTXeYYf_JphEA
# edKIjD7-091MD40nE8NN4g
# eDLXGB6vYtAyV71JIv6JdQ
# edM3qTnV14YmyaoM89GNjw
# eDP0JrbQgx7DDdByoC2bgw
# EDpdFHm_LAo74abVUHxJrQ
# edq_RqUdLZ72eLzI3njFaw
# EdRo8u-DBmTItvJGRp4RUA
# EdXF_SI6QuD2FhydMGL3wg
# EDxtbKjClM_9SMA5ySfO7Q
# ee1wsrzPYZj2qUu-UwT3Qg
# EEBcxHxOjlg7t2GuVyen-A
# EEbywDzeiF2u0GtI4389ww
# eEdV7XIvgBLXkghAvHd6vw
# Eehe3sZvSjWKXCT2YnZrYA
# eEJzMQv1rbt9WyiPpJrXtg
# eEQ3dQ0UU1Kf14z81WknqA
# EeTA5iKS-DVj9z2aFtcPOg
# EeTCGgwdmhvQr4kAhHUoKg
# EEUtaYHSvg0ELD8ZUeG53g
# eEx6QEGme5OkX82B0HupKg
# Ef-0ExiNDffSm-I-smeeOQ
# eF-YmV7jlH9Z6A1lzIFYpw
# eF4HsEn0cbDC9xnpdqpong
# efAisgt16E25r1oMC-I7kg
# efaRzwG7SZ1UobrgTrHuew
# eFClu4CdGi6UQYqNjeE-4w
# Efd6cmXVAahxacPbdG8_FA
# efEaoa4z_aJEy84zdbAuHg
# EFEiySG6JQ8hL9UCNQca5Q
# efeMXgszJdVZLrKYPNKHOA
# EFEX5zj0s6gqPNdfoOu64Q
# EFEyefjgikxmGGdukRV5sQ
# EFGuBmxvP6Q3-3f7q74xZQ
# efLFy9MER8DDP7nYezi5qQ
# EfPbpllAWJDpxNyE3eDKzw
# eFtEKRecnSN2UAzKjtPkbg
# efU7wBTSKZgUs_F1NjLtTQ
# EFUy1yzKmk0ZvySqKG9DdQ
# efwM294fu576YzMPMfbToA
# efWR31vM8_uFR_OZ2s3qqw
# Efzgj-6ZmEOuJxJ9RMUcGg
# eFzSCi9T4kBJm1rja7fbgw
# Ef_c9-VSIoFG9YnsN9da0g
# Eg0vFdxkx8_-sz829xF_yA
# Eg4axT9Z1QrJGTWrJqgCIA
# EG5EGPI3vgjxu3oi3scl1g
# EGaAiN5Vm6scu5VbfHrx8Q
# EgCFwjZguLbkKdlfl8s0BQ
# eGd3bxhugmDv0Yw3Rl5nhg
# EGf-_cSBfNZl_ochjdwjvw
# egfyxxomIcp7ysfr5Qwjug
# egirvP7Xj9nn56oRO5myhQ
# EgKb4aX42k71H5PTJVjpdQ
# EgmnkXUf1dg-3iyLaO511A
# EgnI3uqMZYC-KCq8_oNDSw
# egPR9RSU9ZOmOBxmLOemrg
# egse-KEn8ASy0blTauecFA
# eGt1_BdBjoIScVS1mAawDg
# egXi-QQIaYxq6sf4Azdh8A
# eGZK2kAIdrXUZf-4iRhRNQ
# Eh4fWhKFv7NosQPVHJhHCA
# EH5tPAzpqAtjuBj9IS_xPA
# eH6OpFo-O3phNEgtBS8MqQ
# EH6RIvvQTrmS1WC-l6fYiQ
# eHfrh0ioqhfvyym-ZVJOkA
# ehIH2DPf1NwcN_sgzEAKWw
# EhlhbninjPL5WWcLcWXm-w
# EHLNvLcSe3SbQmegsU0wmg
# eHlsWp8Kb5mEQDJkWPaTHg
# eHLyBFC92sZOf9Y-ePwdxw
# EHmpMofwWrxedxLc_Fhxbw
# EHPZov9qtaHhQJo6sDiHsA
# eHQX2aAMhT2woT73QTokoA
# eH_VnLpzQMc4IP3x0Ro2nQ
# ei8-8Mgq0dHFu5okmUQWJA
# EIcL8TgEgpxXd03ZV7gPuw
# EiHiqmknTsr_RgXqm-995g
# eIiZd5kUsOYHtv23FgRMCg
# eimM2R3SbR19N9hFPUIaOQ
# eiQwBgvtgMOG4hXnvDhZZQ
# EiTRcBruiNzE_dXetzWeVg
# EIULzOgZNIh5ldGVf6w42Q
# EiuM5_4blAdGUD_sQRuPVQ
# EI_3HgdKM2VrztNCLKsZsw
# ej67DCOzMATKbvyRTkB3qw
# eJ6GW7-h9DLQvbwa72m2Ig
# Ejb8sR0t4g90bK7RTyEr1Q
# ejbCWT4sHo9y6vQ6p2aABw
# ejbPJTKkMa02TtRufoeVYQ
# EJCc7cFLrVjdP1yFW3v4og
# EJDylABDjFh-cYtCyE0N3A
# eJeSz37nXVLGdiUtPmWR6g
# eJg6idPOZhsK7Z9css7geA
# ejh4iNLrUQTV-l6bxU4d1g
# EjI7xRTuqrTKRUt1QUbGnQ
# EjIlK5dzdmapcbbsDrLXAw
# EjJ6_ER5s3WOak_vOiQBEw
# eJkOm0fnjHehkvfamd9MKw
# EjuQePCWpZ0VfYmBUxaKww
# EJvsdS1GwEFjpF7P7Eryrw
# eJWJcf46oQmIlHfr88Ep9A
# EJY3sZPxjeKRmOpw9KSLhw
# EjYIBzR0DHl2r9BcuSmM2A
# eJYnfwhqL5EvCoYYl6YuXw
# Ek7fyqmcKRDBamaUF3_sVg
# ek7MhNCEjHMpboQoEzib4Q
# ekDDzUGOuQK5woHHAUFFZg
# eKEcfInHfXYjhHLadyKzgQ
# EkgGJWComWScAEkRTqI-mg
# ekJjpTb_dZtaiPzML7tF7w
# EKvv01EU8ZMcNqPbdBRwpg
# eKX0EGxYq29PgosErnVJ_g
# eKYAy79n1TdqfI8HHYXg4A
# eL9bRrYHGI56iauYUnuA3A
# El9OyyIoLPz6Cc5G84yxhQ
# ELb_HkzttrpBz5FKhptnhQ
# elc9cZ4oseV2_US7Tw7x5A
# eLe2Xd5RLdx6zzmjUX3bYA
# ElhkI7ukMRe6W_rNYkCCOw
# eLLJULD0sAGD9B6C-w2a7w
# elLznlsKR5cF70lA6LuQFA
# elpNtgxrZnJyxkPY1nzaeg
# eLqCl6IOs81pOt2jbiqo-A
# eLtgYDVPMiefImvl5vVQVw
# ElubxZ7N_cYw1JycPHMigQ
# elVo0Pn5UIWXixrHVYMAPw
# Em-H4FxI_FvA-bmibMJHBQ
# EM22McmU3T575IDwk9m1ew
# eM7l__6hAYpUCyKleC9UEA
# Emc8s-GNQY0twWZJuJKIcQ
# emcKvuQPh1EB2jJIZUJcYw
# emDDhQLtRuuVUhmrkxsOJw
# emE9vfFLH_cZ85EDhBYrYA
# EMFVnI762MCyMgdX0OGDdg
# EMjEkM3XUVQQHltBxqvuUQ
# EMkwZZGKIPdo60jgNCS6ag
# EMLFSaSxyIJtarzJwNfokQ
# emqKwu-4fymcsxnoV1PBLg
# EmtUyEo_Z7B8_C8PaiZ5Qw
# EMVi9-OjkBwt6BTvg29k0g
# EmXVRDo6KIMcpqM0gfl40w
# emY04KyV7gG6ukXYQS6z0w
# eM_w3fYJwrrmF4DNn4jhvg
# eN45sGkH4r1fII_rFB-U0A
# en9861O4V6o9hF1mpN7Hfg
# enebs6MSt_PmDCKkldbLSQ
# enGK25CtXb-vUMAIoUAbUA
# eNMCPef69NiyPz9i28RrOQ
# eno1yZZ3O9oa51bs3TaSIQ
# EnS-GAWD6N2_zGsnZtJv2g
# ENsEtDdta0pFFqQq3ZVnGA
# EnSITkukhw4EZu597keJsg
# enw2llgwHSpd07oj01Aygw
# EnYNYUH4I79LSmGH_kjypQ
# EO4TBwCEeCTOjTQAXpn29w
# eOaHLvUa0paMCnufosopkw
# eOeDnCacMp-41NVHZprBXg
# EOFvKMB8ql58xBull-wU6Q
# eohcKfqD4U5ooSRII52okw
# EOi7BV-1a2WKEymI1XVanQ
# EOJzAbsH_k32pmO-8B_0Gw
# eokgp0uhJfa8Cn80Kza4jg
# eOLVqOAYDULaiC26Vbq17w
# EOPBKjWpe0b4c8pgUkpphg
# eoPl9aMGTrgSi4KiNsG6zQ
# eOQVsX0x2pbLOsIISz7BqQ
# EOTEPcvmdwEV5bOztEgqbA
# EOVrsHLqIcby3m7LbNnong
# eoXWjNqTWVcKCNM2x-piHw
# eP3lNBVNp66Yefzrf4eQoA
# ep5Nv_sTsAEH8gIFxKSprA
# ep9rupiSWuabBJT8VF3H2Q
# EPGfAM_OMiNo6m4lBmQTnQ
# eph1f9XigP8-vCXvAA1OCQ
# ePIyjvh3agiC3jfGkaIrCg
# EpI_tYkpjahIC6Hj4MiEwg
# EPLKLe6EdMVJIxArXUC50Q
# EpnkZVwZBUwHuGXgfO9DZQ
# epVujcTbXIEwJq3TQpiAjw
# EqA6zC0TTXS4BGwEB5qBlg
# eqBRayZgU2P4QW20wxRjXg
# EqbsxfpwYVcslCD0aGt9pw
# eqfoNipsE5w43hVs5DVMaw
# Eqg7pcazwXIRDoKIN08LUQ
# EQjzhx2ZXF4KSQ87U2iRGA
# eqKuxoTru5W31JyVcyr4VQ
# eqNpKf6d7CHmjRTaWXs4nQ
# eQNYHM172H9hYa5Z9sMN7Q
# EqpT4rUYa6IlUUxIgOIDKA
# eQQWshQ2RFdV1h09wGA-0Q
# EqroY8yyIysvqIZBi1CGDw
# EQUemIfLcYx5pyOCx6sZ8g
# erayixrY4unpTsc0jij3Cg
# eRdZjyNXqxUVQQCCD5b46Q
# eRGvIQbD4AoMNLWDS8bGFA
# ermsC5h4ga5ZyRFPeTNFCg
# eRn7ek_siMgolNU3JHwhtQ
# eRxN4VS8vk9u6Q8wyN8OBw
# ERZoG5PkqeQOseznFar3xw
# es-1cnyIjq0MFQ7dOCMOhQ
# Es0brb2LmF4dKWoGsqx9tw
# esaM00cWnOAgYC1NqY29dQ
# esbAyH7qerREten8PGdq3Q
# eSDm6cI1oV-jYAABh-ZwOQ
# eSeVnxZWh0jwdFJqj1jYzg
# eSIk6U-vYXu162apxqIY2A
# ESKPFe5aCrXj8bJ_GIQgmw
# eSL8Mc4g4lTAjabYmy67DA
# EspYRFZxprgTNWQ-fc7kzQ
# Esr5ymM-PhVGCv9MMexq0A
# ESsWoh2HDO-azxxIC-VwdQ
# EsUArNge6858JFj-7cf1EA
# EtAJ54fNC1e6EzmQAaGV5g
# ETCS-UmHvGYEPP4f_lu5VQ
# Ete67TpJLrTlrG29pmP_Gg
# EtgSxlb_i9iVBytIRHG7Kg
# etGv9K4hXN0APk5eAB1aJQ
# eTlwMXy2gFxMYjDhWV78sQ
# EtN8fluv8FEpEMz9FAJ0jQ
# EtobqglMr0IjgYL1zdS3oQ
# etRnJqJTy78BOFRIZ9_RfA
# eTsiJ1TjOTo46U_6G18c-w
# ettE7wJ3L40w_OoC1q41TA
# etvpaN2q8ygwxCxpkiVfrQ
# EtwjF3nWZHee5gY0gK3gfQ
# eTxbZsfehkGF6NKVRjXWbg
# etZT2tMAt4x3Qmy1O930lg
# EU11bJwsxHZKYQCmTCBq_Q
# eu52ajo98qgVME_32AA-SA
# Eu7Npo1slLXz02ywJDiE7Q
# EU9z9jPQf31PNNdh2uYs4A
# EUcMnJs7mgODilYXx-SJ6Q
# EuF6L2Jlq7MB2IxhLrNWSA
# EUFkXIYzkPdMrGiuZOdlrg
# euh1r6piGLtyfO3LrE4wTQ
# EUQX8RUc3zYuXoABCROvyw
# EuQzRWgOidqksKDOI86gvg
# EUUwkGaLGMiKLfVMKTugiw
# eU_7lkvEPERjbbRIh2VLfw
# EV0rj7sPBZtvNAayOsBMRQ
# EvaT9kdH5kAKR_7D0arj7g
# eVaVadmcFUp6kjl5bg0Lag
# eVbrQidtkeWugNivc2QEQA
# EVBXEgyxzRALxUbG3BMFxQ
# evc3P6INU6LiksoQo7vvPg
# evClkEDgIz66orLLhrY6Ig
# eVcUndlE5z91rioGiqCGNg
# EVcXSt9GTk2UQpIHAC3HoQ
# evflqQ8k3SZlq6BM_TH5Dg
# eVgL2a2LnixVKrp90TJlfg
# evSG0SN_cGwM9bo76dH4uQ
# EVsRhBgZXWRvpWWlEOlx0A
# EVtKhKSFzMkTq4Ful1eglA
# Ew4B0U5DSlzhLg7As_TH9g
# eW6iHUHROaHQZewZzBjqaA
# ewBSwnRuCC_Xkg64eHOnhQ
# Ewd-sDy9Pl-R_5JSq0KnrQ
# EwGYWSfpXuE7SHsmtsA_tw
# EWIPT3lDw2mz-V5M1iRn7Q
# EWLp_LvaOkjaeYns3v31pw
# EWN0SpL77XY03BdvK6pJjA
# ewN1PkrickJK6UA9pGBCQw
# EWn24Hacuzjr9RJcWNnyGA
# ewn2aup4y_Kd755fg-MB8g
# eWn40wY5lh9thMQTS3846w
# eWn9uwcrnGgFXiSqVMDi2Q
# ewNCiHkcV_72yeGFx3MFuA
# EWNEpQQEClE5Q_BIDpt1mg
# eWOchDL33vSBxtHy0bR4yg
# EwoCJHQyYHgWkc1PJGKjgg
# EWoe1Hw0rKiuWHRFM476nw
# EwPa_DDl6b4JHsoEZP8Vqw
# Ewqlnje0VNPtKib0j-6EIw
# EWTGiqJdLaeFEgOcy-hrHA
# EwuAUS30SydeFT1hjZf_4A
# EX3KM8Z-IZpo7TfRyEI3SQ
# Ex8bcYOEs_kO5eAMam6TFQ
# EXblnHA2G27C4miy25Td7g
# Exc-FKYM1bTBCuxnU3mCPg
# ExDloQ_sEyMbqrrclkmSnA
# eXIH-ZZLMrMz1aaFVjlLGw
# EXIuldUog9EoUsYdK80sLA
# ExLHhgquNytwtU5vbFPGfQ
# ExNmhQK2CAGq0vlS8_ePqQ
# eXTMQ2zrYX0b7Kyp0os3JA
# Exy-KlPVTtFaxbpbrCiJug
# EXyipbeCeaOaENcabVeMAg
# exzAEvyU1_mId8fjCEEpRA
# exzpRE6LTtw5WrxeZb4gBA
# ex_8MFLD4h-tmQB3PNQvGQ
# EY7M2EKiA4M44Yl1mzBJPQ
# EY8--_Fp4DrdSuEDJ2TnNg
# EygagscXIXI6lLMJnX8isg
# EyhDE5YBopxbZmfz2SzmUg
# EYpKwMQW6aQJOocT7GhfSQ
# EYR72WxtIknuqORNZS6UYA
# eyt6a9_zIugbXuQR5WUl2w
# eYtwRv8BisZZU6exhl_HCw
# eYuFrCPd-Qn24iHjuqnoXg
# eyv0ioNKTcxOwao7SDz8YA
# EyvCGSN0gdu8n1EcugRv6A
# eYZY4l-9Ibo0UV5x_wr-Gg
# Ez1vdUOhSTwvOCfz2jRqig
# eZ1yakG8RSg9B2X9KyQslw
# ezbK43ubWpgxadtO66SUEw
# eZgNIWldNIGFjAKKf-klhw
# ezgpbGcYo9_BNGWDbMyEPw
# eZhWcONrUdPNh5KEk5uJ7g
# ezKv_CCDj8SibFClgM8_eA
# eznhfOKyobEzwfWKhtYMJA
# eZNwR_8tDGbRCzk8l7VMdw
# EZrTycX7FcA9VryErm3hlg
# ezSrR-3ZD2XPhRkijoaJFw
# E_nRHLbvmxt7uHbEg6OMCg
# e_SHakR3zUILMtQzhakY_Q
# e_UER4mrcSVrB2hGEWtKyA
# E_vD_WhYGQ_dm1x8czS5Gg
# E_z0G4QhkOQp1ce_mvxoPQ
# F-c9KNmxw0PaC1qbpzVkpQ
# F-CaFWIY1ICn5tlcSalMyQ
# F-H4xeMwsmg4exHLqtw1oA
# f-hKvbgkKqsje09ONg7yoQ
# F-tYSSw3YDjb-hArun1-1A
# f-vPm48j9yCMHM0O0ryvHQ
# F-_Ez-SuI-97FpaRsyxnbA
# F0LaqyNyCre6AQFYrS9dfw
# f0n5BiuCYMlqiIFCEo3VbQ
# f0tKTPlygersQsU1Q4lf3w
# F0y_iE2cZYplZANVWKe4Bg
# f1199rDyMYgQDxBxX0HiXw
# f19kDiGBHv_6sTXLFjQu5g
# F1ath8-JIZ0qr37Tfeblxg
# F1CgafYoE2jK-TP_xCzhbg
# F1d2q65r7BPf1Mjy5yoLMQ
# F1rqUxU2_ZNBkwggl0eolA
# F1ui0Dm0geoqk4JkZ0HmOA
# f1w74sD4ieFanWaymgk8Qg
# F1XLWMKpdXjOwgBpa2NonA
# f1_v0AeaoESYtPw8G4CmYw
# F2-1NJIoI43fjYOV3cVl2g
# F2gqN1RG2zxcpgAAnWQ3Aw
# F2si--Dy5rcVY-mVN8GwIg
# f3cxMjBr4fwLN2eNAAOyeg
# f3pML85cJdKUFh7UKfbGJA
# f40s3laPNoi-mZu5nE4zHg
# f476k_cROcKVEDFwRiGyxg
# F4CJsRWrULArpkRo-Etdcg
# F4NV_urEoflu_g_vZg3WCA
# f4oQotrOBQVbymAaoM5QYQ
# f4Q-Ok9SgvVZ7ZjnGuct1Q
# f4RxHBE_BFQOC4rBG2fbog
# f4VgqWwV6wBSevf8R4cqBw
# F4YJG30T7khe8rKPShnS0A
# F5-Yf5q_S3koPWOCr7M_Wg
# F5J0KgxlghzLrgYR2RonwA
# F5rDJzWNXvVhPj5NK04KzQ
# f5veV4Uiq-iTvhI0mpgeUg
# f63Hb1Q4WMYRErIByNfLfA
# f6Cd1P_iqaj8GCn4_YlVOA
# f6G3zfqLuGEgPKNbajljiw
# F6jVmKzuJGPNNJKjcj5XpA
# F6R87FvEHPd7EHqy_QRoGg
# F6S47YW5gTmcVFRum7g-Nw
# f6sEHMZ6rJORzUYJ6Jle9A
# f7-J3RlgPlU3SiCncVQdEQ
# F7FmWx5SlwVgRB9Twn3x0Q
# f7g99sOArXNC8fzk6K79CA
# F7uhGb2pKA8dwU0xmyQIKw
# F8hWogmkavHkcHtw-8VeJQ
# f8kGeOqV12n8kwkhyEiXFQ
# f8Veg7Vjb54ryTmgaZruyw
# F917Cdm3Bn1T8fkhJizEsw
# f91bGeMF-nJSjUcWcUCsAQ
# f939PrG-s2aD5EKYkpfq_A
# F9GvWERTx85MvZzLKNN_wA
# f9kXPetNAUWVSFAskVwfFA
# F9oISlokYIcsADOYZZS0kg
# f9qx2BI1w57XWzaelCQM-Q
# F9Y7Me_ABFPYSpleXL7eew
# F9ZPy_2gJ-elCTUbYp-hTA
# fA-jNnuEpwijZOBC_pRF2w
# fA-xj3HaKBPxJXqNTJsQSA
# fA5p4PwEI6WnV8kbMuSyFw
# FA6WExqW5qbWUOhqTVm55Q
# fa8fZ6r9uQYvGuvh-9mCSg
# fa9zKiceAUomXlu19I-ilA
# FaANE0y2QxdJxHJBSWLNHg
# faC6SxBytoDV4UnPbtbGfw
# Fac7ifwvV8GNH3g-aLg64A
# FAEoH1cyXHTJPPvZZlRcBQ
# fAF3ChRMAtKhwRcd_7b8hg
# FAfoQhB5gcS8y9mPVfTRhQ
# fAkdjZXEHYCl78SgcW1LqQ
# FAlPdEzGtbSpLrMXvmqrwg
# fAmFtQEdcFLZdLilvebzKQ
# FaPCKGCgpSm_WTsVPiUPEw
# FapP64gJOkr6vE1TCxD-wg
# faSyXYD6n2HJhWJ6iQmAzw
# Fau3ybaTE-9u5jxbutbgoA
# FAxQgC7GYGXh9WGbMbXHYA
# fb0nM-Z3MpuDnttR4VXjjg
# FB6rsWFOPYMUm4C1vWQZfA
# fB7z9XSYjd7hos51qWeqlw
# fBc2dF9mQScmWVgb5zOZNQ
# fbckn1XfsWVR7P_1KzIbsA
# FBgmb5iq7oN_76PQ5o87Jg
# fbhgoz638HlccalSZ4axfA
# FBIuqQkc946J0VPp3-uMOg
# fbJ4ApnPHPGh_9XI3ecrrQ
# FblzQaJ99XaqFUta4-_dKw
# fBMOoLgbLf-nnoNkYc5VWA
# FBO6WyD8dqa07opcIzznOw
# fbPHdkEdKk9u2esbtjTL8Q
# FBpxtpFM0rRZUYkx9G5T8w
# FbRPYDhzNBSeh-VtrlzVWg
# fbt19BhqhQITnH9ewnceZg
# FbtO3CdtzAXhaGnNC6K7aA
# FbTyKN3B1eSwxmXmIrYX0Q
# FBwTL6bNlP1zyvM9TPxeTQ
# fc0LVY4x327aKmFq5qmuoA
# fc6mmnwy-ZNW0K9hoNhu_Q
# fCbif3PJpVjrhJeRYXb9lA
# FcdG8zxQIavlG61uoTjtfw
# fce93elKIbPct9pqb9IPPQ
# fCgjx54UcoSuGHzk6JclBA
# FChq3MKp8Z2ikeu2LyxLGA
# fCjpcqkUMVdBKL9jNcaQmQ
# fcKp5QO-HB9Qqjpuj5FCKA
# FckpJfUxCPmqaQCm8VfAZA
# FClk8ypaKQbRyKttMWflyQ
# FCO9KWTax2mDa7ZrjnzqZA
# fcpRXDcLXahiKn-INz59cQ
# fCs7UAYwyabzZarrRVZ7gA
# fCsAgM2KUKzp18ZaPeQm3g
# FCxkPDCkcorJwaz2FnopFw
# fDFDv0vIzYd4_3NMYbhOGA
# fdHxNJ2iISRmE5lY6O1L4w
# fDJC2AJR6cjXG2oadXaxAg
# FDJWcfumlQAgLyfzrR3C-w
# fdjxsHqwW50fTd5MIQnndA
# fdlMX5KWyXAYRhLoSbSydw
# fDM9wwLf5cXnbXLLmdaRQw
# fdPpXg6-9xOBP_tmDmKzhA
# fdq9JSpBj1ZMhBFFjVpA3A
# FdSXIY9bGz0laZzdH4sVxQ
# FDXfbkjQQFlS0MxptzzW5w
# fD_2MBCYdzCt7qGHV9OUIA
# fe-gkA9bVpqIBXAlgW4VKw
# FE2T7-0ZSuA3kZcWgkp-Hg
# Fe31A2YF-9rapgWSJN0rpg
# FebSHeiTTqHZgHJX6MqqCw
# FEFMSpLpiqxEDbOgk834og
# FegzSDKmJmZoNc1i7Ic6Gg
# fehrOlUwIB8Zmy8G93xPnQ
# fekW4aHeZ8C9OqkRCHmAng
# FElhBbNQ7Uq2mORDWFdgaA
# feNFBb7O30-eoGWBnWxw0g
# FEQCj8VtlZrFG2k8C2hsPA
# FEqIa615LAo3vPsxsfG2_Q
# feTgvrPfAQcytoWkVKSDUg
# FETsRE873YLT_cEpgxE30Q
# FeZcz9umCXe1HC6YiNrpAg
# ff5r8YIDQ5tR-5nX6CMtxg
# FF8zEfJOCjUc6DHmHof4Sw
# ffcJdzDPKH9fCNAZyDOYtw
# FFd-2PPpqLY8vCmO_twabw
# ffdaA2l3TKDqm1xNoyEJzQ
# ffJrqZo3A9rlW6cHEu6qIw
# ffk9t-ftQ_OsWwSzxFbjtg
# fFQ713P_P091RkZEp10dHw
# fFqJcN5XHzCcxW1rtAsTvw
# FFqNMvCarxUdOutH_ERD7Q
# fFQ_oIUq0CHTDtUtWwEKdw
# FfrCy-nAnnzjriGTWgVuew
# ffrvHyLJq1Ftffaoy2vHnA
# FFSyN5Bl7LPQ_6GLXROphA
# FfV59vJ1rdC5sGtMcr372g
# fFvTYb7D7sukSlGojvyBeA
# ffWfYcSCDu4RXpaBxEDpyA
# FFwkAElQT-heeWEoBnwobg
# ffXW9ygc_-ZuMAyMulN-Xw
# fG1XiWwwhPeT7HT9cDICdw
# Fg4xUrykn7uMZ6lp7WONmQ
# FG62nkTs2BXMUot017076w
# Fg7evxBv-6qT48ibbE3sTA
# FG7W-pY4GyYN1qF4CmivUw
# fGAeCogLR0H3eax9wCd-wQ
# FgAFDCPXzeP3Q_Pu_tZtcw
# fgd4l6LrBbz6er7-HkkCRg
# fgeT1fcn3EloDwKB8HdOwg
# fgHQU9iN55POf3TfjnpuZA
# fgoFSo19hUa_arOlylX0XQ
# FGO_VQ9Tg_QtqdOgZRjBJw
# FGRMHxrdSIy2rwmvEOTeGA
# fGUtaIBjHSXh3wDBVAFF3w
# fgWQxvZF52S7B3eRFf5BIw
# fh6Xd43Mj2ayEMBsObsoCQ
# fH9dZFg0d3-5ghlJTbKI0A
# Fh9MERA3sVcnG66JP_vJSA
# fHcPXx19pmGEbqTM1nJdyA
# FhdD7dGaOCGwNrEFr60K_A
# fheHIJjlkkez9yy7-QTusg
# FHLuS-PmY02wMOAViQxQwA
# FhXff1Pxh8UEpx56LKe0xw
# FhxhXi_1iy6R5vYi3l2dyQ
# fHyFWvarLC9qPuyMCz2trA
# fI66Er3LH5XsmnGEMwevhw
# fiak7BuGnSqtLYDYCg4W-w
# FIb8R0-5jMSsQQhd6U1agw
# FiBH3zmdR4X36jz2UlG1tA
# FIcXL_SIVe4l8-fHE1G0mA
# fIiDYl7CFlCnx0Bew2WswQ
# fiLYngaOFcePZL-FMzhJrw
# FinJ_tJXHo-nQ0M7zZeyzA
# FIQyjAB2JX_hEEMbmT_oNg
# fis7hd2ykCWZjYwXdFolfA
# fIuggIKaTokXTBFNNnOO3A
# fiURRrN8gEP7QLSY1LjPTw
# Fiyb3CoycY5mwzCChNBNjw
# FiYLLGBDDDRfdDnPtLWT0Q
# fJ8Gm2D__sfG3XIVROpzXA
# Fj9UHmSp7QOXg4a6PWl2mw
# fjdJSVKRhCaUwx7dYSUQRw
# FJiw731eyFrrX6q1BfVPAA
# FJkEhvPN_CxR-yEUHGhwJg
# Fjw9pMQNPQ0FhOKDKQyjvQ
# fJzW4t0Tu-jxPpeEjIWR-Q
# Fk048OrzrBZRyJgjsnlL8w
# FkFfxCfwVuYNB4zsfmCF2w
# FKFJwLPuDL-tE702oluY9A
# fKJbOr9TM3imYSRqt4YPSQ
# fkOmXbJzQ5Uhhi-CWM9urw
# FKoQ17hDOwhUq78J6u65Nw
# fKsPE6p8GvwUYecIGGhsjg
# FkXsotz9XDGU_YbPmMpVTg
# Fl-okxNF6JUXZAb29x2LfQ
# fL2lf5H88C_Rat8Qa-rxNg
# FL7bQzuphiyTJyQeFuEXNw
# fLbSBkcdOnTOGZAJw3SmDA
# flC5MOIX92hTeQ_cM5KVQg
# fLiWKEPAnFJblBjbZ1q-Ag
# FLJaprNEVZLecT8B3UnLoQ
# fLk0VtoR4d-gxg4_WTXKqQ
# FlNhaN2ay4YaffuKSxcBEQ
# flvDOlJYaui1bYrj-JnHew
# FLzuuLo8p13XX6fYwWo8Bg
# fm3Papj65RgGnwpMuzo-PQ
# fm5CcMviDw-roaBUExm3ZQ
# fm5tZZd-Kfhx16KtUy_QVg
# fmAt3PPNPFH2wDB2r-GPPA
# FmAWkFvjn_Kp7uSqBCO6fQ
# fMDOliLCHcHFTvVU8gw1Hg
# fmHpin6HqmL3KkSSLo-dew
# fMksMggOzVucsN8Fg4TITQ
# fMmfq-3UN6wVt7bOJ9eZSg
# FmOe0ovzTRKwR20RYq6-Og
# FMP6iWblgcWBujBA4o9nqw
# fMR8iZKfo3c3qs7iKlM1Sw
# FMTnYQ9sprv0ZXguDGVlHA
# Fmu5lb1TkG13hgUTLv5GIg
# fMWISdiSSvUP0fpRRWr9rw
# fmzchmRXEYntg-LLxjmejw
# fn4i3VGJQAU_yT-PbUt0vQ
# FnC0rYLggWl8jyDMDsfhnA
# fNCGPXT9VUgmiempV5mPRA
# FnI1BO0UYUe-qd76iE1XPQ
# fnISe7CNyWnBPO61T-jrGw
# FNJ5WAw4wC1SX9Gfky5U7g
# FNl-kzrnj-lDgP2rsDdRlQ
# fNlFltjhh7-AxxIV5ehOxQ
# fNLJ710X74vbTJK13BBshg
# fNqn9h8-8AcmmhtwfHVvBw
# FnSSfoQ37HoWuur4lMmDHA
# FNxPcteP4ZscdVefg9v_1Q
# fo-WMqP_7XenRikGAFSveA
# fO4bApJxHP3nqwifbgXBcg
# fO4WxUgUSRxSBJ_Y0rX6_w
# Foc5KuKDb8j-AoL5rhk1oQ
# foFUVAuCZbmB-aeNnnTTVg
# FOI-yqURNPNq5YlVFfe5Mg
# FOk5ffYhYgQbJBawL3jkBQ
# foMsnUE69H1rV54_CPXwug
# FOpTKxPRPvGLK236OdqQAg
# fos3-HXZWv7Q2ISkw1oOCQ
# fOwJZD2bAIGVsYdG993pmw
# fowtyMewZhX9mF5NoCDGew
# FOy3VP_eMcljoEuU7pENbQ
# FP0c2b32RQ-8EnWBPpzFJw
# Fp7K0-fjEkuRML-gIX_OCw
# Fpaa9T91jnhIk00MpTsrgw
# FPF7aU2gr7IOR9O5QSlylQ
# fPgMcGjLVnKfUeE_xCV88w
# fPHIcJbFgfK_rTma0qFypQ
# fpJEfY019ce4NcG8vV4cGg
# fPK_Rj5meKkecFwcLt9ghA
# FpMfbDRbIc8PsFvBKHTjrw
# fpONfeIpiJH0DReummBthg
# fPPRkC61fPR2i6TTRJHsAg
# FPqCEtU-y5Q1Lhd2mHgONQ
# fPtj7nE1d6Pgp3X5a1sOWA
# fpuXwdBAUHjnzXmm0Fv7Nw
# fPyDJF-X4JEOZy6JQ-xHQA
# FpzR-a05KAnXkttHjdOsUw
# fq6TSIm0YhGIlKMVmin3WQ
# fQ78vssCts19HRl6VKyMWg
# fq7fD4iBCsCj25QkE_4XbQ
# fqd6UANZNQnVs2qKkZgL6A
# fQeltMFSc4PSV6Q0sCjNng
# FQFvVttE5P5ypLm5iGDgUQ
# fqiN2YG79ujvYuOXQoe_gA
# fQKSuuEg5PgAh3RCNDoJvw
# fQmntbwnGi-wiafj3vt4SA
# Fqof1yVki4f0VIb2F4vXvQ
# fQoSHlRKUQFTQ2owxJDW7w
# FqqD66t0GeYjgyIYtME86A
# FQu8HnIzucqNGnNnv6r-6A
# fQUuD5w4Lk4Kn0GhjFoU0Q
# fqWMM6gmDje46eUy7QaE2Q
# Fr1s8LJZ3MaRLDRhbIIdXg
# FRBQhDlsWV081PlhhrtIVA
# frBVJ1ZuHfmWgSGSEG7xbw
# fRBwWAuHumomy6Pr2uQsTw
# frc8CdwQgZU1Lsiud2KLpQ
# FrCZURXQc4ItFAtnkjqcJQ
# FrdcOdlroAXqwBAK1I8lUw
# FrdeEzVu5ypVXzlAQl9xyQ
# frNhqCQIYSbrfyeVEmcnLg
# FRSpMfprDgpHdmlx4O5Xgg
# FRT4dsQSr8ElgBMXOsERlg
# fRTbbfBOmrZ9ivdP7qvKLg
# fRV3jUDpDgX6UpqOPvYN7Q
# FRxPzjEYMiZARMdyCjaZng
# Fs1jqcQxQpjrYH6UquoFRw
# fS2NjonoWotbpOJhU4dxUA
# fS64Ltw2cQMORiMsraTVvg
# fs6aGD0nJ96iLTla5gb4Bg
# FSEhWUA2-OhaWxmbT-bCGQ
# fsi7j8PamJSLXPGkzwvLig
# fsmRbf4zTYjsXxAUgzQv_Q
# fSpa9fEp3r3ZG39BOlWSxg
# fsqdwqxNS2RSJV_eFDNK7g
# fT01NC4tdGvghI9R5I11uw
# FT0lKZ21IVVGmyVFanfzAw
# FTgVV0PTkkSH10__ITkCxQ
# fTh43_HDIPrtMn2sWr0KnQ
# FtMtDpNdU-l9nZEsQcE2Cw
# FTQ8rkqdqi4K9-_CbNQW-w
# FtWZLZlMTmVi79JHRIuBvQ
# ftx4CeyKVdikSKX7VfhgsQ
# ftZvRm2mwxu1TClCnZccoA
# fuF45xOah_X4u6YD2xn7zQ
# fuFjG1rUM-Ijm-MFMLIFHQ
# fUH5s2ZLV9bBkDY4dtR6ig
# fUolDsqr21RxYgUErk_tVg
# FUOniCQiM8dYlU8zwVsQEw
# fUOq0mCDfA_agWN49lTYPw
# FusAX7FTQA_1FOcjUDV8Nw
# FuUJOAAPeST0oNT0jbadOA
# Fuycw0lc6ajb5XTJDCQgZg
# fUZyEeQXTO0KRGAOvvbaRw
# Fv3Q5j1ftUzeJ6RR8I79zw
# fV92O-7ZUXUxkVcKxMEp2g
# fvAMn3ZACQSPqlZ6_X5Ckw
# fVBhmUcrIm7hpUu0C0g3Kg
# FVBORT9Sq5m1V5VnvGnB7Q
# fVdeHjYs9QIFD_8RXNt3qg
# fvN6yZPeltdLx3d5fAUKiA
# fvQYgK9dk0VXgacdDJxGZg
# fvxz6uiJXSk-zJofmVGGzw
# fVzGSNApNqOkgHkDd9TIng
# fw4yQyx6FCc4vk2DF04sZQ
# Fw7fSPeRTtiFedUIjAf5-g
# FWcm8fWWtpKDRAD_yHFGDg
# FWeuo3KwURi0yQKUaHwTkA
# fWgunCeP1LRUKKkSrNDOOQ
# fWhK9urlJz7HfIaUiN7iFQ
# FWiI2zx9mXUkvhDZGrmmrA
# fwinIqSN_pqBvqjbE0iRwA
# FwmC002BMdpihYxuu2dNWg
# FwNndItJFNt4xI57H_QNZg
# fWRWaDCdvVvKuGQy_SL9Lg

# %%
# Saving names in a file (the process of the previous cell took 6 hours)

subset_file_train = open('subset_names_train.txt', 'w')
for element in subset_names_train:
    subset_file_train.write(str(element) + '\n')
subset_file_train.close()

# %%
len(subset_names_train)
# Out:
# 5000

# %%
# Read the file where the names of images were saved

loaded_names_train = []
nfile = open('subset_names_train.txt', 'r')
for line in nfile:
    loaded_names_train.append(line[0:line.find('\n')])
nfile.close()

print(len(loaded_names_train))
# Out:
# 5000

# %%
# Copying the image files from the original dataset that matches the names of the saved ones

n = len(loaded_names_train)
for i in range(0, n):
    image_id = loaded_names_train[i]
    source = original_path + 'training/images/{}.jpg'.format(image_id)
    destination = 'Data/train/images/{}.jpg'.format(image_id)
    shutil.copyfile(source, destination)

# %% [markdown]
# ### 1.2 Validation
#
# The same process done in for the training subset will be performed for the validation subset.
#
# We increased the size of the validation subset from **500** images to **1000** images.

# %%
# Getting the names of the image files from the original validation path (Mapillary Vistas)

validation_images_names = os.listdir(original_path + 'validation/images')
n = len(validation_images_names)
for i in range(0, n):
    validation_images_names[i] = validation_images_names[i][0:validation_images_names[i].find('.')]
print(validation_images_names[25])
print(n)
# Out:
# -YfOWQM-geslv541gdpQPQ
# 2000

# %%
# Getting the images that contain billboards on them (validation)

i = 0
size = 1000 # size of the desired subset
subset_names_val = []
while (len(subset_names_val) < size):
    image_id = validation_images_names[i]
    # read in config file
    with open(original_path + 'config.json') as config_file:
        config = json.load(config_file)
        
    labels = config['labels']
    label_dic = {}
    for label_id, label in enumerate(labels):
        label_dic[label['name']] = label_id

    # set up paths for every image
    image_path = original_path + "validation/images/{}.jpg".format(image_id)
    panoptic_path = original_path + "validation/panoptic/{}.png".format(image_id)

    # load images
    base_image = Image.open(image_path)
    panoptic_image = Image.open(panoptic_path)
        
    # PANOPTIC HANDLING

    # read in panoptic file
    with open(original_path + "validation/panoptic/panoptic_2018.json") as panoptic_file:
        panoptic = json.load(panoptic_file)
    
   # convert annotation infos to image_id indexed dictionary
    panoptic_per_image_id = {}
    for annotation in panoptic["annotations"]:
        panoptic_per_image_id[annotation["image_id"]] = annotation
        
    # convert category infos to category_id indexed dictionary
    panoptic_category_per_id = {}
    for category in panoptic["categories"]:
        panoptic_category_per_id[category["id"]] = category
        
    # convert segment infos to segment id indexed dictionary
    example_panoptic = panoptic_per_image_id[image_id]
    example_segments = {}
    for segment_info in example_panoptic["segments_info"]:
        example_segments[segment_info["id"]] = segment_info
    
    panoptic_array = np.array(panoptic_image).astype(np.uint32)
    panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
    panoptic_ids_from_image = np.unique(panoptic_id_array)
    
    for panoptic_id in panoptic_ids_from_image:
        if panoptic_id == 0:
            # void image areas don't have segments
            continue
        segment_info = example_segments[panoptic_id]
        category = panoptic_category_per_id[segment_info["category_id"]]
        
        img_label = label_dic[category['supercategory']]
        if img_label == 35:
            print(image_id)
            subset_names_val.append(image_id)
            break
        example_segments.pop(panoptic_id)
    i += 1
# Out:
# --BJs76vloEaiH-wppzWNA
# -3-MmXdwhyIQhtb4-8NqHQ
# -32tlgoydG0ZCyijh8piZQ
# -4jzRzGfKmQg8RBNlNqnGQ
# -9y4NjcjdoPFMs5wwC7otg
# -BqO16ocxK46wM5W-QCE_A
# -BYnT4s40fJHAlOumPYbyQ
# -C-x3xSPFIEjqbyVC5PRaQ
# -cHw9ug6U5pE2c9H1dHUOg
# -DXgAnuaSe6TtQ9Hbm3G2A
# -F5vhdPopdHyJjiC2hI6xg
# -hUGu_wVAkoTya0Gp1cCsA
# -jGzo9blhVkb-GgmTnYzHg
# -jri_jG7haWRygtOb8FffQ
# -lGfFLqh9n-iBv5fZDykSQ
# -mqVqUNOImM1OzSXoL44rA
# -nBxnPqrlKNcp4oY4U8A5A
# -tpmjcVylShgHq6uKICQhQ
# -uocR-Vc1j8eeDUF3H866w
# -UqWx1Q0an_GDMMJs3bmOw
# -xh1oIBGFpKz0J8nOBbeMA
# -YfOWQM-geslv541gdpQPQ
# -zwvMY-T6zh0_dZf9GW_wA
# -_prubhCd03M0BLOHOGGOA
# 0-g5x1x9t7t6_lmXUPFazw
# 03x1wf0aRT9QaJnkSGCGMg
# 08uTEfTU4TFuM3JIFP2VGQ
# 0B5qssoIEl6LguVQjoRiDQ
# 0Be5dXzrmHWKPlOF65P-kw
# 0daE8mWxlKFT8kLBE5f12w
# 0eS0pdffaI0C3s4IvSbUYA
# 0hGMKuBXemoKzHp7I_hvxg
# 0hMunfM7UARtb1ILfDbD-g
# 0NAkQGTqAfm7LNzziBPBww
# 0Ngc6NLyTxpHwljinEgCew
# 0nQvP02UmANiaFb9Vp9vVg
# 0PkrQqg3IeAtnMH7JWpA0A
# 0R8Zjkw4z7-1xU_GsPPG_w
# 0wcA84wys1Ag1X-_L8PreA
# 0xtR9XkHx-pfm_JEzhq2Ug
# 0ZjIZyAs4I1HBgQOssdXcw
# 0_bg9QV4-OGi7e4hLKfnlQ
# 1-RJMdpt4X1knyrpLYNPAg
# 1-XkVjt5MGb_agybrgv-pQ
# 14NhJEAXlaFN3cYWMBPLEQ
# 1bMLbauZRH1U2aKGiO3Cjw
# 1BQ3gc5lTz4kxxtUtGjDXw
# 1fC8GcJq7-c-frtboRyJzQ
# 1i9NP5fSHTHKwsb5z7CbdQ
# 1isFq_HywLQIw0g4FSA_uQ
# 1IZUxeQDLdZXhJjU1x0DHQ
# 1j4Juh1YSOaMVHD_ddThFg
# 1Lx5fkCA0in5x7OVEn1bAA
# 1N-pndzScB_7D53FekqpIg
# 1PA--U0r9AjcC2IxMw7nJQ
# 1pFw6qQwFQ__QdnYYB7YLA
# 1PHaEr3legyKwNuQJBIzsA
# 1Q7hEw4K52MUqo3W8-ygoA
# 1S5dk82Kz6LuXJed4xXfqA
# 1TjaO64mb73buCdpYfd8Kg
# 1tvtg2B5emazY6j9YHCjoQ
# 1vsiFo2E6GVN7vQJl-kP-A
# 1ZH3JzuxLDhC90fBVdiaCg
# 1zhhrktcVNH36SoqA_3ejw
# 20keVUrq7c8Lx0LiNpbPmg
# 26XtLsA9mmXw5uSSFbIh9Q
# 2BD9x_UONigszuO6AUBbGg
# 2DPJuTp0mSTXXGEsWRL25g
# 2e9PeGNj2wAj2RjSZGj-FA
# 2GRNyL_tZVU17fWLIpZ7yA
# 2GSXJnMNPdqamBUsPJreeQ
# 2h7BIWwhpve1F_-R9JF08Q
# 2hFYojmF0xgS8Bcm7rzQpg
# 2J7RqaXCUclOQrSCwMD0Iw
# 2N-q-1zGT1tqWVQnXdCR0g
# 2PLh06tpv0UV-HPc2IOmtA
# 2SYCjMPdfq8X3v4dGugXwg
# 2t27u86BMd5BD7MuGn3MIA
# 2tcJmerokcX34cwqwHTyvA
# 2TMdzF5LSFnehkHD1PWk5g
# 2Xf-1_EcACysEa437Z21KA
# 2_MHBTsYKK9t_-twwkyKag
# 317HZ5wmNYSX1_-909n1zg
# 33oxNarHDYJU6aAkGvHg1g
# 36a1LOpcxk_ieZim8Mi8Lg
# 3A8BomxNwxuCOuCNGWEV-g
# 3c-42cb03bSKRZTk9xQehg
# 3d3MF34P-Mnex5d5xjSOYw
# 3dDUDmy9HoIFzIJtmt-V9Q
# 3dxMxhqhb65Vwck068j3kA
# 3dZh1N_Gnm4Kpx5Jy0Lc0g
# 3E13VlqqZSWK3sbs4WEnAg
# 3eebGhMDYl-xpu_imGfvZg
# 3GPnabgXOMpS77SSlbcVgw
# 3GtKr4T8GuqDgGpIS5TRKg
# 3IUvad8B-vjJimGWOfeEqg
# 3mDvhJz0Te7yryhj3Z970g
# 3mz6ZPAfbxapSa0j3klqjg
# 3NdPTLGlHZGN4R5avak0iA
# 3Ned3pRUlZ5NcT9qP5b_BA
# 3PVuoGhNNSKzLwAtCZLglg
# 3pyaa2SLKTC47lFIRGmPlg
# 3q1Jjxo0CxZUWMiA-_wr-A
# 3R4wQpEe3ZZUcpWud7gNQw
# 3s28sAnr1WZdCOIYJszxag
# 3SlHCh1JchTszy18NEUkGw
# 3U6wenCWhkHzZjxMeFwaaw
# 3V2N0T5AATp_X3RU-A8G8Q
# 3w4VXK8IPOd2dfey66kk8g
# 3WPUYKcIISLiqKxkq7cw4w
# 3wrUlCL3hhEjb8B1A3spNg
# 3xjmaCC2Nen2KtCkrvVuzw
# 3_f1Ewum_g-gdZ9h-SuKKA
# 4-YgRUZkrqFryYU8b-KxKg
# 42iZxKOcI70Ab-UZ8RNdUg
# 44bjg1MMePUJxz1XAkTBgQ
# 47Qa0EA7zb7SQu5IbDOdLQ
# 47wJIJSNa1zBbrxMEV3HtA
# 48OYxu3iuMtSZungOQE2_A
# 4A0hDHGTBUJXn7YtF5GUqQ
# 4dYoPPW6dRVsgPDDB1PjIg
# 4g3whX-DAUfrhExudoym1A
# 4HjkJ973GRr9dw6cXJ0wWw
# 4iq7AAv9yhZaTAoOIJVorQ
# 4LIDnyTE6-QpiNJNyed6VQ
# 4m0Tw3BXAXNSx5I2e1qCMQ
# 4M5XpMPqn22GnPFbCT1hRA
# 4nKM8EWA3k4xSrEOJPvFBA
# 4OxhA2ih487NT38v5rtpPA
# 4pCxqmy_5TlxvOFH3KGdUw
# 4PpjCXHfoZdPfbvVs-LRGA
# 4q7e4mr4cexToMhlwkJY3g
# 4qt-NFSSchuE6tJw5juVSQ
# 4QTysV22Ql4Q7ginGb2HLw
# 4vWFrAMz2Qn3U_6OKB-CgA
# 4wy5aQrjs0fSJGo_JbMaPg
# 5-B3d4ThV3Lf6BaZcxwE3g
# 5-KT4MzVZ10tXeflxn8Y-Q
# 552L4GU_EgLMi9FMhAgHZg
# 58ob5eyo7EL4TQegRyQGfA
# 59gA66zWDVgSaX4wgWVXug
# 5A-xaZ3A97VK7xkBiDkoLg
# 5auFcBEP0iA-eFVp9gfKig
# 5cB9pgzeH9BusEfyw-J5Gg
# 5EO0WKraJItW3YTXsr8gQg
# 5gEY38kEOGdXzal_RKJpaA
# 5Jt96ZtJ_tpsurXVbWqs_Q
# 5K-DsC4907dopFaYFQJiCw
# 5K1_i38r46HrvLTfSPn_TQ
# 5LRe9RUcFizhbTcuvAbQBg
# 5MMCve0U0BCmDcsYQdWrnw
# 5OIMd5PhCDDz2JdSoJkoOQ
# 5r7rNqd7KRXGjVHjvwTCcw
# 5RHePVMFWAvezhQG09o7_Q
# 5t6YFV2GNAWQwB6spcgWCg
# 5tVUxw_yIzXXlwoI7TAhsw
# 5wQB9OZGTYEw7n2W8Ha5Jg
# 5xqPuHG6QKItjD6wjqR8vw
# 5xXH_FtKsUhNSeOgfjUUqg
# 61pk4tz3PHmfDkc8VBBtsg
# 61WCwTMG0FQctE0bi--lxA
# 63wfL6WBrpMCeKJuWxLz8Q
# 66xF73x2bk4F_rrxrfVqUw
# 68j1Jovb344yg8K_JWMcdQ
# 6ac3I0jHQ_YWdpyNsLSPtg
# 6AmjQLaXDIbwaFH7WJl3Mw
# 6ATF7pfLoBN0zYbcWKTNOw
# 6a_NauuJ0BIKrIxOtxYOUw
# 6b0yCroYvgMImGs_X9k3AQ
# 6DgRYW8VWDeievMCfnVIuw
# 6dnLj3V9_CGV7QqiXB-7Aw
# 6EOHC86CJQkOEOxNgusarw
# 6fAGhRrRBLUAJnxSXuqY_g
# 6GdPaavGAssQA-kAcQCRhA
# 6gmoXorO0manwFMVLWREGA
# 6hJpJqAED-xQ_imYr9obAQ
# 6hYSY9s_Z0wv_qHQc9fuJg
# 6I8hQ7QwJrLsSEjSZnjYzw
# 6KP-F9snLfi2KtIuDbOYAg
# 6lz9dGRNvEz8ih5A7qRUeQ
# 6MPIkgIvaK8gQwonURcdeQ
# 6mYisbYske_m3mDUCes4FA
# 6NdAt8jUKb82E1DWPMBiew
# 6nEF0uC5s9hns4ocblkzeg
# 6PRSG7BGxpfiEi5vMyp3Ow
# 6Q5qs5lKBmzOYh70klva3Q
# 6RkStMlOcq9NI_4_5kroIA
# 6sSAGuGHmAhrjPubRv8MXw
# 6TZ8dFfj2bRsH7vRoxX7Bg
# 6UaGqFikn00j8xkfYf-goQ
# 6UJguLBTFG4Kb6L9p3M2yA
# 6yRNueJzXo-HDYKeDed95g
# 6ySAnDuGCXFu-x5IMu_YvA
# 6yu-IuUr-S8lDxfPNtGULQ
# 70GFUPDrl1edhq8sLI6Zow
# 73NPFfk17jwaM-tQaowyWQ
# 76WAjBl8-xZRn04F-vcMyQ
# 77Z8XE16BSDy-jxiTHSWJQ
# 78WHRGl2_vYCjReXHvUZew
# 7CZQPfqW9t3DHlDgl5k5dQ
# 7durw09kiJWjImmmKf36ag
# 7gqJRt_d0kZBSTpB_Nq9kw
# 7GX8DVGcbajiJfn7xJbpUw
# 7I-mXh1n2_zNrPfjDfEBuQ
# 7i2d77jTiJo6KK5rgoMe9w
# 7JEZ6jmarIB41_FcRSwvCg
# 7jsufwhCbGXTh_Yejm7YcA
# 7kRzgZJIl5kKXyPOlvPuAA
# 7nBSHYjSiJme0T72Cg_Ghg
# 7NgXYiDHp3vyjDs6MMwUsg
# 7nUYQWL1VcraNRvBOpfaOg
# 7o-Zx6Y4-T48JQPwBN7gbg
# 7pH9_XlOaXoG5BInMBIGHQ
# 7QrOGCeWdczVFMk2htRLhw
# 7RqY8SrGbZeuRqjPO7v7pg
# 7tbb7QyCt0rTTfAfqOinCA
# 7vYHUFvU1lth4TJIFS3LVA
# 7XH3J0LCYRW4Ab4x-QHEiw
# 7Y2EDQH4E9SPLX6Zds_0sw
# 7zKUntDt3zAZRDMsSJw9jw
# 80taDgaYfsYjPtxy_3m9aw
# 81vDaf4MrwgcfvH_Srutpg
# 835lsJfwP84UuFtcIsj7LQ
# 83Zw75vYC9JnP9S6Lkxsdg
# 86Jj6sEmJER52uIbC9H0UQ
# 87HbqlvHzXTY5eWZYmEBAg
# 8anx4_eW_MnMjbJcTYSM8A
# 8ddU5qIwDtvKlPOBpPAuUg
# 8FF58wpNZtOO8WjdFASPcg
# 8iVispHQFNzyShJCQbJNjg
# 8J0HTaPRToLkndKi7awLnQ
# 8lOdkWeXD2rvc2SVG5jGjw
# 8lUt1vyw7yCSDYR1rZXaOA
# 8M85EH_RusWxx_8vELahpA
# 8mSNpsnIXhqJjr6V9Gs9tw
# 8mWX7s-AhEloIH0gkxgELg
# 8OPgEjkOGw4eqcQpAGuc7A
# 8PAsXUiyw-bdqMEL5axDVw
# 8quL5ijwnqMl4e6MPw0E7Q
# 8SbwGx-2V0cP97r9AAaxzw
# 8VD7LzivOp-IFj-_2gWmgw
# 8zcfqXT8qYswmxrEOuG7lQ
# 9-pv8Et9zeMkkoS9mfgpCw
# 90u9SPe8inMH8bCetkezSw
# 946z1GCuSZjUn1x2_taDaA
# 95FtpipVu15Q2gKdRRIdpQ
# 98MrRmZXdRLe2qdDPMUqZw
# 9DWQEtNiezLSghZ1vLKFgQ
# 9Gad_3CzbPOlUtgdAa0okQ
# 9I6q-cK0nokuFTfZPeNkCg
# 9JKPTb586fsKQAPawBeziA
# 9kMVDIlK7R_nhO7gGLzCfQ
# 9Lh3SfJQkDQ0vwH1_wrw5A
# 9MyUiRGmbU57gqMAbb5v8Q
# 9N-e6lChoLLfeMN_GXh3NA
# 9R5T3eIGAtzW0iwKY54uYw
# 9u03HtdeKJ11Klu_MTJk6g
# 9vmLvh9pkmsviZfqVuws-Q
# 9V_16-i3N7quFBMwglShUQ
# 9wQDralITa7o-t-ac3_32Q
# 9zXbG7i8rVmIFVR4h3EOXQ
# A-nhP3RuutqijY-O-9zsrA
# A-q1nAJMYAg0vQbGfOk8jQ
# A0c6XJTJc1mSkL7_WcMS0A
# a2-cjwuXmO687YN_vlynhw
# A2E45vl2HX_Jg6Ez3eYKSw
# A30QVEgKuMFMczWmV6LGug
# A3JoYQulMuNyaNZCkSEg2Q
# a4AAMxVgsdb7XpBd6x7PRg
# a4bZYoA2riDDgJPWzXS3kA
# a6uFPg4sM8gclLAiF8t-UQ
# a7EzMTyZgyy8z9f16aiIzQ
# a7o4P1bxgFuYCelgrnNP8Q
# a8KSotT59A4O1lT-UtTvWg
# A9ucM4QDFqX35nbyXqAlXw
# AA0m5FhNrwxRoR3qDy-D6Q
# aAcaQrZy91einjB0af8YFg
# ABER7DOdsvGMQ9Ybz8ghKA
# absn19iaS5F5_kHI6UYwiQ
# aCc6EKeL6RQpletvtbv9gA
# accICj6_m2dPzpX79k8uvg
# AEodz50qZwUPrCsA5tpWig
# aEQC2qt5RDzFgEyxx6_Vzw
# Afk5LVg5hXl3ITK8uBvtjg
# AGxQK4GN_qg5qCl-e0KpWQ
# AhaTeI8N1FY8gItHZJ-lEg
# AHYRvVTD73Q9IIv3m_3Zkg
# aItEAEAV4hB4f56Oj4XFTA
# AJDLKgfDEjp4bx49JIRg7A
# AK3hKgoinuZar7QDjrVuEQ
# AkKpKvU57Td04bZ1mltZUA
# AlJ4BcPGxigZZV_j1nEiMA
# aN9zpqHrwNqpbtoO9ENuZA
# anD3T1dYXpY639iQ_Taazg
# ANnGtxdEZhmATKwsRQIBfg
# ANWMI0iscxD3m8tlKFyQ6g
# ap5787WCiDY807bvK1bYxA
# AQJS2U4eiLALZQtofQCydw
# aQO9K3GrRGfsPZ9pGK1E2Q
# aQsIsFsw6oAapHLjrLuIOg
# Ar4n_0npVlDM9b5w3ymV-Q
# Arf8VmflcYZHWlVs1Tu3YA
# ArYZhd7GjIIPXnUICzgjKw
# ASbiu8iObBT2iXL1LPzjkQ
# aSqVUgt36gddhmJdI1lXNA
# ASZhVgsUTLWj74nfnN09cA
# AU07yidhmL_qakR6Dv7cYg
# aU10HfCKgO4Yc0yY7YlBDg
# AXWWlOPVkVFCFEMM_yCYow
# AydhklH8ffHxg1kN3Z9mXA
# AyMB6Add5VPGOCf4NjcEgQ
# AYWRYnH4_RSTvQ9gL4_3gg
# AZJHdAHIovz_dfI29cg-gA
# AzpT2miuJpghiLLEikt1og
# B-dEl7NUOi0iH4Iy8Bm6fw
# b0K3AVtlhQDOag1sai2JAw
# B5ejGxmls3CalohO48DxQA
# b91fZvSFEVfHTOFou8pHFQ
# b9LHvrZ-xExLXbqR1vrnEg
# b9qrApXKn9omkzlGjxTqgg
# baCdqSF2sP80Kf2J7_jD9Q
# bajmufhNXraol7OMQbVG0g
# baWrPvSayYVqii20wS3HGw
# bbfNQHuYLehPra3l-WZJRg
# bb_Qd6uhG9Puk8Z3mWnkwQ
# bcq29zBixs4OhOBPe1Ta2Q
# bdFCJ8-cpipNckz6rXKH-A
# bdVw3ht5no3Itw5eQVSpzQ
# be7swMgfIbKkaGjpnddlWQ
# bEc2b8MaP6GzNWfUks7gwQ
# beIBxzkR1zQ3DEvXOJ5uOQ
# berhvwFaA32FFLAL4o9kCw
# BESvF2EjrODCxZziAZIkDg
# bEZ9NmSv7LBUIZDNtaZhlg
# BfKp88YxoeTWyNGyD1KPVw
# bgjrIxzXyz-7Hua3_Ayyow
# BHrwBEaSlO4SjJZSAY0Q0Q
# Bi5Bvc-0zNruG-vXPgNklw
# bKN2vqroGiPvIpDWzvEtLQ
# BM3iFbmULVllQQWj2CEUCA
# bMQS3fJJLsHmELpq78xobA
# bN-3nHNZu0bGLJIwyECKmw
# bO5hCtfIywXxVrHdKUkntg
# BoCWkvoYfuHTM13zFWUovA
# bOdZ58N4yFsCMc13W_C5hQ
# BpEAwInYD8re5pmwu0rDIQ
# bpqabUdDEwaw9gVaiRoQUw
# bq6UzH5OrBKIfpZdj5OYAA
# bQs_9fstXdJ26wZ8mPyGGw
# brwKugqKDPgkBEACrhRehg
# bs40et1gJ8RIB7j2mDZb1w
# BSsS9hhzMQM2p1Fry0GpeQ
# bT3l11uB5MJGv5ZTdzozLw
# bt6RTOT7WhWdpki0UiIzsA
# Bu4UC1XSmRUr2YWl33wtIw
# buMJ4HkF_UL0svJPyKqMbA
# bw0t77J7yHv-ASkITLryFw
# bWAXNbYjctScbpl_GXHMAQ
# BWP4YGCaqSRElc9_JZQ-0Q
# bx2Y3cJu09T7LM8uyQ9e2Q
# BXhh-qqP56adAb_SPNnfFg
# BXwmoGtx_jBN3Yi1Qk9pMg
# byskyaa9lIooL257e00VCw
# Bz5-mgMDWk6gMN_gLPwnxg
# bZHp5w3WwghNf1Csgv3Bfg
# B_L8LjGPPavozYu1i4La7A
# c-34l_HLcapVXtlUEyt8iw
# c2bG4N-fWC46PQl6i9w1rA
# C3fao_-9rHFlTCldCc_neQ
# C4quW-KqGLwGsQZ1b7wbrw
# C7dkaoE4Fs_xJc-82mt7Dg
# c8gxiaoGYO8Qccpt6VEdfA
# C8Xyfj2asi5f7pj0Qrjtgw
# C9EH53I9eLpBaPjPVIerDg
# cAcdmuHwbTw9DLUvK__zkg
# CAjAHPaEB0PYNXglida1NA
# Caywm3ZvdyWtu-SA1LRh0A
# cbkG7UrHcNBARMficcbAXg
# CBmLbmdDpYtvT9l8ci6dBw
# cbqGDgTW6QKI4NtokPyvnw
# cc5dEAyQECBFF9MN3MbdZA
# CCDHXNGN2T7LwMys9sp11Q
# cCfJCcHXOYPBxF6SziLqng
# cdCDRU6cLWCJx9hghz3T_w
# cDvtKnuYMm7IXAUpybkkaQ
# CEFcHgV8L6OOssaz-rdyBw
# CFACScKGKv1azVab3ComDA
# CFlfycyyHwUAIJfciovRdw
# cFS8nrEaY2DzE9aj2ema-w
# cgcD6BOK8WCMGLPvfgWqcg
# CKWavXWzmxsBbQZAwKsk1g
# clXXNaBwFCAmfi54g0FnEQ
# cLYWTcAXc7KuN6uTZ5yFxA
# CmIM22rLkCuCUX_VaICE2w
# CMimK2BbqvvP71X_JSKvQA
# CmTphiGKXuhdujTGy20hCQ
# CNjjfRK0bogNdYjx7wxDYw
# co0DZw6kSQuj0Ou7Mi-Y_A
# CoBAkHgeaj5djbvAhayQ1g
# CoMi13trvH0UE03Omj2INQ
# cPPYM-UZsRtBUQYP2E1gGw
# CR6A40IbtMyKfhiHrI-iHg
# CSvkotX3WUL1cL96cMxTGg
# ctsHt5G6K2nqU9kMLX5GQA
# cTu_hIYcK96-c0mnhebXFw
# cU4Q8b-hV1TjaPpqkBmo8Q
# cUPZWAX2n-n-uHfOcSNCPQ
# cviHRBHmCU2OSChVrhWmgQ
# CWB0nnzwsdneEVlT1PEbOg
# cWFqdIVQb2UMRewXvSDJxA
# cWm0JR5KvU8NO7zdTvNaQA
# CYdn7spjYQGeczeQh3nugQ
# cYfse-fKPYPG4AmCjUvqvw
# cz5Jwg2cv77QcCspDzXzow
# CzSyjI5mjGUQvY-Pl85Yrw
# d-pYXRUL6fuXvyBrAfBs9g
# d1uWR2FjSm_nBoLS5jsDTA
# D320WSvRrTn0Iyx0H0l3AQ
# D4ec-L4mCAaVS2ap2u56Zg
# D4J8uMZ4OdmebvfK50aRpA
# D4VY4Gjk8scPkgukVRTStA
# D7GnKzDgKIRydMidHYX-Ew
# D7Hwb87eBBVSSyMZu6yPGQ
# D8Uqu6tYZ0Z9yCK2cCmRQQ
# D94-nKEqaMSL-h2mYzcv2A
# dAcklj-f_HX6bANAVibw7A
# ddUw9OnOEwwejgonja8_wg
# dejslqZtqGZ53SiXTInqug
# Dg28ft2ZtaO4nxO2WmfZqg
# dhMr__VcDjJHTgtLrfMZtQ
# di7SQsqXQMQPJ938CMvxPA
# Dj8rM4gqy2B8F8YrCAqnnQ
# DJX9emTaOwE2R45bWOFtAg
# dLdKXcWdb9O22FhLyptm-A
# dLxMAzJH8MG2HwyYUFnnGA
# dm4y-sOUvmTy4VcAjPuIpA
# DqI-OzKO0ktrrFZ_X7DWbA
# dr2CLWcUwosXjHRXVKkBHA
# dR2vSaDB7Kq1W34ZqTkp9w
# ds6Rswmm9d5R0b4bejDFqg
# DUinAULotalE1ssyzx0CyQ
# duMTX1KAGw5yo1OfGhPyOw
# DvAybfRsiVYeaPGBtQ2eaQ
# DVf4WEF3wUQ8NZFzuQLaBg
# dvHAThmqrmJqEaTe5CpUKw
# dWDcQMFCAXHcy8yGl2qFLQ
# dwKwz1bbltHMDdIhzQ6R5g
# DX6nJZ-lB4o8OofJlb15PQ
# dYCA2F4WF2ZbcXvtpFWpsg
# dyzWTle6XGPRvdZiFqwMLQ
# dZ6ZlLb1OY5LkhrzLOvztQ
# dzelLoP_l5lug9kSW2motA
# e-D0h6BzruogvJgG_3P-xQ
# E00oWA0zsmrvpDmZGxNw_w
# e4V2x_2cCo0gwqKJYjOvNQ
# e5axmycVb37634eerkEeBw
# e5yvzXDniYNqcXZ1OFldPw
# e6ZS57GUlfgphaLk7WGNkQ
# E7RcvV25J0bPB2XMzu3YLg
# E8ijcTzmfp06sBNehG1ZAw
# E9B6brxy7UsbrtnYmpY-xA
# e9ubCj3gfbSin--kmV6yVQ
# eA05VPo9Z6ZKbJwouOoWMw
# EB3lEm2g9MJ99e6jP4cdLw
# ebkcwU75_i2XVKaV06GgQQ
# EBoMwNOLsxUGoVEmEc3AcA
# edia9_s3QMKk_Jd_WVldYQ
# EDS5SbGx1msIiHYxxkfXug
# EDtmMp0z6XaLffEjV5Qafw
# eEVqzbgDv6Zh8ivkmi5cOw
# eeZgKwh-RhpC_1UaM8oX-A
# EfNkxlj-XjXAnNNJZqbz5Q
# EgfueSMjIUhxlPAItyTY8g
# EGpJcTtS3rOaIZtNqsfHgA
# egR-9CDixJE_zgb7mMQ2VQ
# eGre90jefz7x9b_OxlM4nw
# ehDjsybQqaVW8nciVwRLJA
# ehtFt5gDZQ5xfe4CRwOGKw
# eIQCwwpMqzxA_OQCTO4Wcg
# EJVu-YjxsplQJd0EnuUu1w
# ejvvpHQzMIGEScb9nn-UVQ
# EJzWhsNpyh-jSV3QZMqXkg
# elbB2XGfVLZenJe5QYviiw
# emw1XMTEDcwBjtQtWpxaQw
# eNG3Q4Yvz2GvYKMaEAcj6w
# ENVNwtVUmOeFjunk2o4fqA
# ENWcyJGTuHf4o8mYnS6l5g
# eo9Rpj4-DJB00AToc4ixuA
# EOYH5ULSWbrO30m265lF8Q
# epenTGhc74BxGWVkp_90Bg
# Er6jNrmINby7E7rFM48dKQ
# eraEZvcNhtQ5B26hWhw5jg
# ErHMiERfRrCZDL30AgsIcg
# eROJ8aIJjiOrh8qfsbM_Sw
# ES5Lv8Y0yn0te5vFjbN8zw
# eUcJY7TIgJB6ewfHbuELUg
# eV0z2iKroRR7Bav6O7DKuw
# EW3EUD5NDsoo-cmOEliu4Q
# EwHYWvWqJ82jIQr7B0sUcw
# ewi5UPg2X1kdPVSuDYaxqg
# eXw2W3UkYp5tsc1kA9CGHQ
# ey6P6lygMMabQ95tD6zYOQ
# EzqVO5MotnKKUrTxhnoibQ
# F-Zk_X9-a84Tom14YCgdcQ
# F0a-qBNUXh1JUn_8uP-oGg
# F1rWWZI_pxNjQ7FNya_QKg
# f3Xrw5NhLLeUwmD4g3SOzg
# F9flyLvoK3EE3EOHgCq7rw
# FaIdFMEtd9vjqZYgUZqM-w
# fAsCW7xDAvjamZqWIp1J3g
# fb9xEEiS02f2GQg4BnTPIw
# fcNlfAAdErWq-DpMDEhs1Q
# fe8lxoBaIZU-MrKOqgyt5w
# fES_Q-LpcKlmJmK9PxlUdA
# feux0pJ5zA62VtGmW11TEQ
# fFlD3UGGpp_i-3waRzvk-g
# fguCq560uYX2LKir8PANPQ
# fg_-lzaB03U5Yz-PvHnvuQ
# FHZVwBi81W-cEuFxDsn-ZQ
# FII-Ojk9FCDADyjS8O5H2g
# FIPQ_-byAFERw3FIZMQArA
# FipS19xpKP8faliXcKJvrA
# fiRcqW60mMHlzpDHL05VAA
# FizpP_PXlF3sIO-ntAW82A
# Fjd-51Enqu3LXOuJEPMDfA
# Fk5yX163tC-KuT8wxHKIog
# fk8GnF9fHBLY6aMNbiDLew
# FlnZVUZLOb-rlw-QUzJ7lA
# flrgJ7tSO7Q2bFqqvIBDag
# FMIK_4k7HkdNT_ydwXS1Kg
# fO9OE-PSe_AYa914ie5_fA
# Fp31dNDlqMC4LcgG5X_NqQ
# fp6MLwW4imgAmdMKeq_0jQ
# FskI0Pdu5L6dfwx68wFl8w
# FtJy74gRiKdfZOhU5V6k4g
# Ftl_CQ7t4Wkpi2HMTuyrKA
# fVnvGeR2PG_XUZDzU7HUzA
# fvo_hC14KpURz7M895DJoA
# Fvs0ddQyL5xyekEajtcokg
# fx4UAddR3SFxlO07L2WJlg
# FXHYVpCTMwPBnU6CZ2xKUw
# fXYwltFZejCF1SMv96_q7w
# fyaMKHXTQ2DYwANM1Da9LA
# FyC2cimDdAGyRbfhFCr-7g
# FYoB0UGu40k9nKurB8pucw
# fyQOwxNP4PY-ThFgoSG5gw
# F_7J8CM9mPI22gBSx2SmbA
# F_TfkLEgTq8F7OK0swOGuw
# G072Eq6yIZgPwca4onLKrw
# g1m7azN-wt_9-2ptH5TTBQ
# G2S2QdeyL6VWkUTvTLCeTA
# G4tvawHZUd4o4b04XxazNA
# G4umVFD4_18jZD5R_-omSg
# G6FYoewKY6gCBn0laRt5Cw
# g9nZEEBHh9gGO8uGxNmDVQ
# Gb7S9mWp5-x1s2DcfbIdYw
# GBW52gTR1ZL6RSv91xytKA
# GCAKv0TuZ3GEAittAntqbg
# GCBqObaR0kchcWZuCvOzPA
# gCRjMISoBP3FkvKyDDAWSA
# GDS9_Sysn2mOUrJHG05ddA
# GdW7H6tdPVYESFZ5V_OLhQ
# gDXft25HkbZqZAd7r8GV-Q
# gf-GzEaxGFxVOnXzKf8e8A
# gFfZ5yDbjysz5DWiyT1-5Q
# GFGbLiaWRACNUNomWecf_w
# gfrI0l9-FgVq47Wz1U2f_A
# GGUNXO7RgSSoMF68AVH7ig
# gHusXbedQPytazoPz08c5A
# gHWsQgXJBk_jh1gxEdV06g
# gi-O9g2mltNKkMDoyJy79g
# Gi140KgTGQeSX8apmfafHQ
# GiwWuQKUYVpMSMg_-FN1jQ
# gJF0GccOjDtfLDAe9knPRA
# GJKEzVZ24Et-Ya6o5flWBA
# GJQAV2MN9ptVev_zt_zdIw
# gJWhSqwMGaRRTcQ83UwCnQ
# gMeIw-oFy4rZMqSMtLd6Rw
# GmrX8suARzrALn3ZuYxVfA
# GmS_quFXmJhShIaiS8VShA
# Gp0KqhB88_8Jbtarq0f1Dg
# gQBFzyRbQKKEJ4sY0HmPBg
# GrxjXVQXSruxnFWGKKjklw
# gsi8Dfb6BTUkI4_XS67YCw
# gwE_rYYjFG_6X9evK7PgCA
# GWhMU6eRXJwWF7fraKBohg
# gWjAJWETClDo4w_bOAz3Gw
# gwWtTHS-26-3k6l4tVQQrw
# gXi0v3lm7G-1ycscvJd8Gw
# gxp7GIWqgCMJAylVQ_MJ1Q
# gyA-hK6S8bN4wKCXB95Xbw
# GzhESh4gTxL4R8LjQWnIiQ
# h1qGuKxycylQbMPEKi7Dfw
# H1xrFSTcU9rzLNtR-lwARQ
# h3PiE9O7FBjyORaffLaK5A
# h7hOkGw7o5Z1KpQlczN7eA
# h8bi_dThuerTb_6xuevgiw
# h8lxEewlrYeG_2ZHoyVuAw
# Hbf4B4WYjKU6C1Qe2XSoVw
# Hc77RT0jRflFqd1jmMF3Kw
# HCbW6F3-rqsegUK80alJBA
# HDf-dhJVKMHZqpFFbFwe6Q
# he84DQgZ_xHcnx9iGUjPmA
# HEu56h0y0GLnq_eDTfbUdA
# hf2QGmB3ULp0yw7WanicuA
# HfdbDYfrNraywdQzHAH8ow
# Hg1_BkIeiSP7LiyJWL3qdA
# hiroiE-ZtV_KO7v2vjbqWQ
# HkwTheXyYil93Sp0oF2RTQ
# HMPHvE04RN1c21pdN2XUSw
# Hngs3e9MUJscCPUCMuXODQ
# HNmnbSwOLxA2i8hFoY1hIw
# hO0p3Znb1vij-gVXde85GQ
# hOet8tAPYyr3tCrpDcu8YA
# hOUbc7LYK0FA2gk3VCoTyg
# HPVLeunnybTc4F88r9eomw
# HqFEsp45W7w_L4mPKgCkJQ
# Hr8ib4ziIUTOr-V0gqx7HA
# HRsWuDC_kX9JHFJMsqYgng
# HSpullgONm_YYlULm4k68w
# htddmV-UvepimKbYfyZ50Q
# hTJQDf1sHA3aS08qxB5E3Q
# HUrET_t3ezSSJ-BZiMjLfw
# HvCnu3uDr8gpI6QveXukcw
# hVDTKnztlLr_ewwVLb6uRg
# HwBonTfmkfIOANA1O7B2OQ
# Hwd2Jx5kVIlRVO7Gm5yeMg
# HY79tcp-SzNXxB8dSf8tiQ
# hYaHZi16laZGSt5MjKunJw
# Hz6rAoDW16ALgpKD6DnxeA
# i-hqlYwh9cZFmk28LWRHTg
# I1aeEjelUeHXdh25gPvmZA
# I2PhN7ftmK46zYSCDA-_Xw
# I3OJEUCdetnvuPHpGQsOlQ
# I5KCGCImogJHoMEuss4Opw
# i90Z2kT2tPqJSkg8svhndw
# i9lyfI0asmb9sXUxKh7wEw
# IAw8mFmLSerU1TxD9oM3Mw
# iaX1lJsgrun-_5p-dC1GSw
# IBF4NeAjWS64aDsjFRVZzw
# iBQN6CKfcMTNpXGhr5-69w
# id69DZIdnDFMSk8GyY-WSg
# iDoosPDLYWa6rsEZQhnwhg
# ieAyeXIv3VkvyWum-8u49Q
# iERrDeTm4HptA2WdkwGznQ
# Ie_7joIqGLY7TUhEhzLiBw
# ifKRwqutBd7RO2QQGaKMVw
# iFYMMBHhVjrlqkGTbxW-sA
# IHEWRqh4LU29eyEiCxYmcg
# IiHHFeHG04eXdG4k-1lH5Q
# IJgAePfgfx2yvtmc2NojAw
# IjvHpWZvnmL8jFQYDhq-Eg
# IjyvVNRZHxSRAYVHahEcKg
# Ik5C23HH5aeFdc311WYdeg
# iktd_VlvZplCpB4lrezx8Q
# ikYqDAYTbcPtHEonFQRFwA
# IlQDRvfg_HvR3wcIo7aIjA
# imfb5yp6Es55QC5CCRxjIg
# IMKwdhJTInLaops9nbtqwQ
# IMz8rs3LT-U9IFAKUSmLog
# INapYvdMnil5yhtAyLxuSQ
# inSaHpy4Yrk3As0OCa3Sgw
# INzfEz853dXRtqR8RGk-oQ
# IOdmu0rQJwSOvVmNIr-waQ
# iOg0Msffuy602xIuOAWxsg
# IOXKHTTt-dAgrVtMXsUGQA
# ipklT_Os3j_VIyiQSR0fng
# iPp41EgCFNvDKDRox3srNQ
# irTuEwhCHDez_innQChlNw
# IrZFUnMCato-Y-nCxNzHaA
# Is7yzw3LxE1Bn8QSbfF68A
# IsHb1AK2mXmYciB-kwm6tw
# Isv7IHuE4QJWcK5Q5yaRyA
# ItnLD-lx76tudKRBdr3iTA
# ItYo4bawta4jvUBWmwquHQ
# Iu5b_rfCLDcswfUaou1cLQ
# iU9Fvr7Cn05Db0hbktR02g
# iuiCyKf67flbs7By_jNfJg
# iUNJzyH9xzUYdDbJAkod8Q
# IvZqGIDE6Q_1hpGfoZOiRg
# Ix6j0o6FCbRp-c-6XoULSA
# iXQKOdbJy6C5h28pLKm2gg
# Iz8irvLYSOcDrIbWGeKlAQ
# iZCTrEXYXlVWDXxpWWh1vA
# iZOriGL63uLtZ5CB5z8fVA
# izYg9oYbfzQo80PW5V5R-Q
# I_PlLW-qUqSFeZjGqKf0Vw
# j1hsidexhHPN1bNfCtzJ0Q
# j1tUDT6rWC4KH8I3Wczx1A
# j2kS-06IJMIk-jaRuTU9xg
# j3GSOXGG50GDNbvJsWStyQ
# J3iQrPABpe8ahwIwvpr9ag
# J5BFlgXZdSRc_WAWjs8JHw
# J8XOFgi053cBwN0X9EZqiQ
# jAH0bjRWZOYwO_AlOlh07A
# JARwgsAxhLIpv5YnMJgZ_A
# JCRhTyCkThLNFoJolxOS2w
# JeLTvli2LnFbyW6wd-ndAg
# jErjw8O3N8r_5A_faJed2g
# jEUk_wzXO_ft8gCIPp9ddA
# jeytvLNTwyEA5Wyk5D7mMg
# jF7UxUHCKbP91jrwCRJdmQ
# JgGBSsyVmwkCfB75WPiumQ
# jhTAMPdhmZW9xPFLN2y30w
# JIE8dllTDF8HbLoKw6tcYA
# jkoHK5ViF6dCFjXsPfvBcQ
# JKPxehe8swjasUmWAdCeZg
# JL7xOVbLmYPc03xzbH3jmQ
# jNqP-shFuacamGVkM0rTRw
# Jo14ZBlIb_NMh8VNP6MHIQ
# JokkbRyUyuF5ZBHmzkgrdw
# joLasMJEgscBDVBTAdeptg
# jqh8xIPwEZiRmWEwY9ZVaA
# jqMNbLC01AGBFMJyElxLjw
# jrjoyxuv_5J5mK4-R5odxA
# JRvRrXk2JVojKw0jB0pH8w
# jrXktbfXkBl0QangXxQcmw
# JSCTB43EcE3jcrH2kZk8eA
# JSmd7VpS0nXmXob3I-0GBg
# jTHuwAuMdl-50usve0zP_A
# jupx68Mpq0AI7-Kz304LdQ
# juW3wss37XAgPmpKLAHC-w
# JV53UNrvoOxyT2xpAQOIpw
# jvTtbeW6AawFLsfPQAoijg
# JYcWwc0EXi0T5tcwYJwWGg
# jYL7T8WG6dZ-yWZS7PTlgg
# jzW7IO0aja2Ww9aQtiag7Q
# k0Ey_K2TwNo5cSOFY_aXrw
# k4JPOarbzd56FLpbm-AOFw
# k53E4nIRjAdP4Qhf_jL4og
# k5cKiJ0H9z4ltK2Idn7g0Q
# K6Pr4PgQLpywqYE41pScMQ
# k9UCSxm_NtkoQRVNp4Mn2A
# kaw-xWWzKQuUgFdjIv1Zdw
# KBg0KYuwdE5o0fbkXm5fow
# kBLlD8p3UN-jJ0EKMQwD7w
# kCA4mZhQTMahGWqLhh4c1g
# KD86ag1GZDGgldVtMAV1xw
# KDJbc9eWOTpyfLmghj3BjA
# KhkOVyYivfQuiymV2SHYPA
# KIPTtS828jCxZfKdQ2KULw
# KjZXnU33x24D1K9UiCmY5w
# klHF8Cnt3x6rVG4wnOSNsw
# klV2LGDKxRSj37HA_n8eeA
# KlZ3XODVQ4MFjMRyjWLgCw
# kLZi69SEq4eUnQqLUc7Zdw
# KnhdzVvaMLeXMpJvrg4XFQ
# KnM8yd2cabsAlGqxWtCYXA
# KnZ1g2AW_OmV96DDgYzB2g
# Kpuc81vbkJRppwBroR5WOg
# kpyGZtTfNn3Ln_ADb7OOMw
# kqxMTbTPAG4kG1U1i1dPVw
# kReK1GrIyeegBJSwwdoRdA
# KSq23J1ibgw_ufqayMOGPA
# KtKQ7L5qvFVukU_X-f_d7w
# kUlsHgvx7wYmzmYTOOsfaQ
# KvZ1L-oKjh8hPu5ANWm42A
# KX4_R-rXInA8Bna_FpEoTQ
# Kxhg3_Swa-fCuZvKbwbP_Q
# kZ-nKrdildGfw4xUPGoR8A
# kz-TiPxcRh8gXF7MumRfQw
# kZuyRVhQVTZdys4vN-yuig
# KzXO8YJi9jdH0eWNBELAyA
# K_kSd5qjifxFXsBWwlwrqg
# l-xtHUnrD_U17y1xDwqrUw
# l03F0etu3SsIACvSlOssBg
# L0bY5HKnbiU8hi5pYQg7hQ
# l0j2ydbHePkagcblbnUNiQ
# l0rDnEX_sLNVcGehi3xDvw
# L0T0P3Ar3Bfq-h45cJfSqg
# L2olNRKFzF8BY5X9KJQriA
# l2Zi8r7JRWoiS2vjcfHQgg
# L5eWTUqquBIycKcqJC2BtQ
# l5hNKpuH6O9vPXQMmfJisQ
# l6IrgehmSK1pLzVEuLaveg
# L7bHKCkhhBxIBXCKwI8HnA
# L7dIihPKZWPdxjXOEmeJ3g
# L7VasX_9dMuy6jlAgAm8Ww
# L9J2XWzq8igSP1yIcNr2ow
# LCgN1uMGIWihC87xpmqkLQ
# lekBzlV_c1TDPe_JpuscWQ
# lG6FcsMSYLj0JAzN40_ChQ
# LIeUSaRiSWppbHqneGdMZQ
# lIYCcBPlNAhb_kUb9dGhAA
# Lk4SqMCLsBmpDbbtUoJV2g
# LK5D2QOplPLAmkn2GghgOw
# lKbf3ZUrNlZtTHkPaVs5kQ
# lkQ2UPsNjSf-S5a9G6N3Aw
# LM736ey2Gf6bvsSWtIDvNA
# lmB-pOKBFkrga6kpZB839Q
# lN4quv64dqa38srJlhj1WA
# lNQdLz1vzz4Hiii0gv6I0g
# LQhrKoiiOylr9AblI0jWFQ
# LRUHcfZ402gAMIzatyiXVA
# LSvEIFiW3tqMIWnsNhsi4Q
# lSy2hl9A3AFMIZb3HO2Ftg
# LTyHt3UqgEo_esJkK2h1nA
# lu4O0-rC9S8yn5iL-u47EA
# Lumuv8bO0Z30gIhi4efEvA
# Lv4PkQQmn6DZVX6-yXtoJA
# LvNz9YF5sqlVwRYBiNHpuA
# lwspqN_c_t2xKV4p59JTBg
# LxOp9nrXx5lHecwb-G1WVA
# LydCIsQfkzyJ5TLSSBNm5w
# LyrfLKTP4qXYFBKqYBnF1Q
# M0RgIsnTTtNTrcqxTGoXKw
# m2FQ8kyPAM4SsV612cawfg
# M2J_Czzzrs6bjPuqewHgyw
# M8nBEKOU-U897ACYPTzcow
# mAhiSV8rtHHoaOwcmiaKzg
# matatT_eRHwLZcJhUdE7CQ
# maTw_6HagxlDH-LG5x11aw
# matYZ3L4KPZozVdpQskH7w
# mb8EEI9-aQp-dL87Q34n1g
# MbPE1SdjzPspEKXXOf5b3A
# mddJMHEwA8Ensx6QdtiVhQ
# mdlQIo6Y_c62JbiTzrM1NQ
# ME5Y_enkRvyMK940tDeWTw
# MESZD6XZ3G6yg7aNOZzeTw
# MEXSi09FB48fnEAqpXLNGA
# MGCljEDCb-uj1mqitYMLTA
# mggCSE1W_DsgiYLYvG_4NA
# mgnH36676D50_A1iJZEYiQ
# mG_ib-X21kDBwz_EHRZ1Vg
# mHxu_oxJSebpZipilgJFpA
# mIhkPggPzQHmewOIHbgmmg
# MjA1XhWqyQcGz4nkpSEP9Q
# MjETYTEUr9I8H9D7nWdurg
# MJg59vRdRmSVgUFNm0L1Pw
# MM77o7gfyUiWt0MSaq8_EA
# mmig3EtqOjzCir4cnU89bw
# mnOo_qAL6bIqsmdLnF8kOQ
# Mn_JaXwHBmChZvAHpk3mZg
# mOnd4I233MBCL9Gg26jkXw
# MoyEwVctQCvaO6yrt0KN9Q
# mPYQDaGZBn5f25m-_RwZnQ
# MQiqCRa0WEFsCoTxKCuUjA
# mqK4h3FMAZuQa3QE-PGVtg
# MQ_hoXuIGWXkxLDLsNLitw
# mtLrsxuWiWI4Mgw1EnwqWQ
# mTpLasw2fcmOT5_ctNLrYA
# MugNerCyUTF1wkeXeM59_Q
# mURdvO8w-pV8dqsqLntWCQ
# MVRePzjbG5jkCwq2uBGKtA
# MWdJVIXorduOr01iDIn3gg
# mxja_i2y-XJyDZyMh958Tg
# my5kMTpCa8A3YRxCr3q_oA
# mzgRZ4JiE3qma9OfK7TDHA
# mzhrMG9-KkAay5mdKHcwPA
# MZo8_z705dGGgYgDeGFbmw
# N--QwicFknmxTXhk9R-elw
# N0OSpi6wpFvK87qbIF5tvA
# N2K7Exe-rNVYCTLtjheKKw
# N31jfcBPZO6K2kqH_MAH0w
# N4GFZ74VN2mchRjQ4hGyyA
# N59Fehb9BIJQZKd68AVuIg
# n5Qnc7F9m8X5FdkHwrYKMg
# N6JH6pMYosRTHjMT_JOMKg
# N9bSA9lflpyyyEfdXFEn5w
# n9esTAS02_Lm7GwjBzJAEA
# Na6OoKM-4Eo1HFN9wx4TvA
# NaD7JeEjZFSs6B5M-LMHfA
# ncXX3RQd8dk9t7DN1N-2_w
# nDCQXQZmxe8S4eXeDT-G4A
# NDwTw4ezOz2xITPDEkshZA
# NE4B7b303vqGW4QinBRBzg
# neKbW246N5DZxgwA6go_WQ
# NFOcsuvZU4InbBqyQFrWSA
# NFYtcfk-Ad-tkIEoq3_IWA
# Ngqr24mONuMC1dZnrQMywQ
# NhaBrQMYCLxktWdLc-1nYA
# NhbwlGNDD6k82SDDDsK-nw
# NihgCecjGbYOrZ1gDqkSKw
# NjgUXRpPPXBclta6dyTnEQ
# NjyUVGpMrBoi47qHJJy0UQ
# nKTQvA8Wf1xK6x5HXpDbTQ
# NLC87j8cvLQdi9LugGwkDQ
# nLigSWHZqKvIERtwq2JBsQ
# nMYqaj-jhOBvuw2da9cxdg
# nn4Snk3ZkqFQQXktxcY7Sw
# nnWiaePFu6XMjLszP1uDTw
# nOuX7I-3svSMVzBtzokG9g
# NOvl-ZwPsi9CYl6bZaptjw
# nOzXAm2e83P_YiB754phvA
# NP0fezkIujKfevTql41n7g
# npiwM1PkxfkKZKvU4gy25w
# NPpI30p7mWRSkcDK9KfUbw
# NqhJI0cpIYaQqb_1QVhQlg
# nR-M2zUbIWJzatAuy2egrQ
# NSTIs_Ay6U-Z8k6HNzWr4A
# nSy4ROMc7gnntSvvADWfkA
# NSYXA2gzndYv00IxWa3_Hg
# nTf31ekTCIL3fqiUF1hBuA
# nTq_avx_ZPcsOgnX9boy6w
# nUomR5HksfAiOJ4SonasPQ
# NxbIwAB3syRjhMURTxLC2A
# NxPtGt032tyZF2WrZXjOzw
# NyzKCld0HObgzVv4bdnWHg
# nZVWFLeVqh9mFty_pNbGmg
# o1bLKgyhyY6Ar3wWWannkQ
# O3OAFv8gdyr4U7oUYsZilQ
# O5dqRibaFNvVWfRQijtfLQ
# O68NroEyyAzP8sYrD-Ob9A
# o6bYvK_B4pOWpZTN-y0uvg
# O7VZTUCmSfO-0Q3f3Eb5QA
# o9RuLN4Lhv6vWR-Vo0mATA
# O9tNqlwdDGcErhd8c9zeDw
# O9__2AAOv2_2rUApr7xQnw
# oA3tNrosEL9ZUBXvocQDKQ
# OaE9xlPZSw7afmlCaNrsFQ
# OC0P4LlFQsMfyNUO-Z_xoA
# OD8-gu5cOKEU38c6jIuYcQ
# ODbkOs1GqH1WP4Ua1gJdyA
# ogbOuYoAkr0nIs3BmMKF4w
# oGflxuBrUf-ujvVZvznpKw
# OGHqtq67sKIVqNOyP3nGkw
# ohaWXQNlja_oabTa_mBkKg
# oIEH2SzCw66csLuAxG0Vtw
# OJCZor7bH2DWkdTM2lrAiA
# oJn8Gf6AARtDRyUALwKQ7w
# OJzTXH-BDYr_uI4MybQtRw
# OKLraECXxlI8X7aAxCB-ug
# omsS9GxxN8df7XmdUHL0Zw
# OMyvxvZbTExtx3-0unwtnw
# On3SkvmdDaT-onswp1xuOQ
# oN4BV4zY2i6fT_uBBfZi5A
# oNqHQObr71aG-dYaZ6Xdvg
# OnZlSQdCtqZCdoj53AIFag
# oO59tmw_RecOjg0SHHPZlg
# OOmc36ylAGdJo5TbQ5vLUg
# ooV4oevKWXZBybts7vaz8Q
# OpGJytkWwwWThNWNiDPM-Q
# opTbOkdtGaeuvGxH5mGWNw
# OQ2RhepJStiQouSk5ecuKw
# oqB-KEfQjBq6wA9AxZPIng
# OQdRFPg9aKFyTuQl34K7FQ
# or6qWEt_MNF83_IWIY3e8g
# orcuoE2IEwhMNCxSU9dT1A
# osEKwr3fifYv34uBHTfdag
# oSOeklD6vGcTq6X5futMbg
# otfJJmDlSD-PKVkjlivp_Q
# OV8epP3vjYTQ77dGBxZt8Q
# Ovd7xsKEx0-2ZOjj3kaOsA
# oWCF3yBXX-NmmuEl6Oa1YA
# Ox3lRioEl5FwUTxJ-EVKTA
# oXQWhd5WVoouqdU0Y5wvjA
# OYyFv3XcyrSla0sgF6JrEg
# ozZlVnDdMd1IOb3PZbHqqA
# P0mdxz07RBD5np3Z-cLOTg
# P2COoyHFwi_WiFhVn-QcJQ
# P2h7xzLy_qsq4eyAP2iAcw
# P4EiM76FN9SQR2JV-z1IeA
# P4z0IWGnn_XhKbnPv_pyzQ
# p83r0E6-A6_18C32nr4Fpg
# p8a7FnCuGFU2ZX1N-adNUA
# P9H3iT7hZiG1jXuALEO0dQ
# pBgLyPKE60kRflVj47M5Rw
# pcNtClM258dup6gOygQ89g
# PCqunQynaZRXPOfTd-rfcg
# pDQXyKzd7fLTArd-8ASrDg
# Pe2a00nigxXclyOpyN0kZA
# pGch4a8uRdRauNm2DP2XBw
# PGXSf-k026-zNf4Y43r6qA
# phxqXKjHU1iDWxxS4QhrwQ
# pICe4gFgLe3oTuVyVqdv9Q
# pIWMj3KbW-lYQuGw1lMlcQ
# PIwuiRK5KLmLYCwIf1jPTw
# PkWwUel8yolxlOu3UCJKWw
# pM3KQBwnFW5HxaZwKg8SgA
# pm5MiRqn9awF2zULo6rtEQ
# pO28OyoV7uhea8_epCywlw
# pOAxCu1jL9EZXCSS5RBEaQ
# PP6aibVfC9wmwORWfKQn-Q
# pPtiu8k45qGu5iAxDdUkYw
# PPutuGvNKLGW1Z_xYOZnFg
# pR9x9dm8azAKcPv5-PWt4w
# pRD2yHe-TrhydDf-k1oDSA
# pTbVDf5aOHP4g6BoSQotqA
# PU5un8hLzV59wKtpWEKLHg
# PW37z64zkOiioslOkwLu9Q
# pwIX_FS2F4Z85rqpeGXQHg
# pWlvQHb1ozbTdi1liO6WQw
# pwneTZXa01H-RpplizODKg
# pwPtRBoAi-WxS0UjYj-zlw
# PxmqFeA1n_avfakO17JaZg
# pYMR7CXLCahx9QmgDV4UdA
# PySAGiRm8jvK7Kf1s1VutQ
# pZ0SzHWpOJkDahhAEiRVRA
# pZaiHvEPZAAoAmFsxoGnfg
# PzkHc43IoYGEFytmb9dptg
# PzSMOyD70iztojCuK62OIg
# p_abpafjpgfUaYs4kCSF7w
# Q-oavfbiPjjb-UV5hC2XwA
# q-otIFLLO-wCKcLLy63nmg
# Q10sbuD6txwHJCbp1P-grA
# Q17bjyJyCt2KFfj8bGxtsQ
# Q26wimQNy9NCcUCPNiQ5Kw
# q2Fi9lgPl0cLG2Ufq9le9Q
# q3jNNR2fS0oyjBq47TK-YA
# Q4ARY3kgmJkdGQaSHaZB_Q

# %%
# Saving names in a file (the process of the previous cell took 3 hours)

subset_file_val = open('subset_names_val.txt', 'w')
for element in subset_names_val:
    subset_file_val.write(str(element) + '\n')
subset_file_val.close()

# %%
# Read the file where the names of images were saved

loaded_names_val = []
nfile = open('subset_names_val.txt', 'r')
for line in nfile:
    loaded_names_val.append(line[0:line.find('\n')])
nfile.close()

print(len(loaded_names_val))
# Out:
# 1000

# %%
# Copying files that matches our requirements

n = len(subset_names_val)
for i in range(0, n):
    image_id = subset_names_val[i]
    source = original_path + 'validation/images/{}.jpg'.format(image_id)
    destination = 'Data/validation/images/{}.jpg'.format(image_id)
    shutil.copyfile(source, destination)

# %% [markdown]
# ### 1.3 Testing
#
# Testing images do not have panoptic images (segmentation labels which contain the information of bounding boxes). Annotation of billboards has to be done manually.
#
# We increased the size of the testing subset from **500** to **2500** images.
#
# Since this is a testing subset, we do not need to filter images (our model has to be capable of detecting which image has billboards and where, and it case there is not billboard present, the model will explicitly metion that).

# %%
# Getting the names of the image files for testing data

testing_images_names = os.listdir(original_path + 'testing/images')
n = len(testing_images_names)
for i in range(0, n):
    testing_images_names[i] = testing_images_names[i][0:testing_images_names[i].find('.')]
print(testing_images_names[25])
print(n)
# Out:
# -gs02rx26QQIvEew6E5VCQ
# 5000

# %%
# Copying a small version of the testing dataset (including extra images)

n = 2500
for i in range(0, n):
    image_id = testing_images_names[i]
    source = original_path + 'testing/images/{}.jpg'.format(image_id)
    destination = 'Data/testing/images/{}.jpg'.format(image_id)
    shutil.copyfile(source, destination)

# %% [markdown]
# ## 2. Creating labels for testing, validation, and testing subsets
#
# As mentioned earlier, annotations for labels are not explicitly included (in the form of numbers or coordinates), but they are included as segmented images from which it is possible to extract the bounding boxes. The code below is in charge of processing all images and extract the billboards bounding box information and save it in a text file for training the models.
#
# ### 2.1 Training
#
# The code below makes use of the image segmentation information and retrieves the coordinates of the bounding boxes, the information is saved in the YOLO format in a text file.

# %%
# Creating training labels

n = len(os.listdir('Data/train/images'))
for i in range(0, n):
    image_id = loaded_names_train[i]
    # read in config file
    with open(original_path + 'config.json') as config_file:
        config = json.load(config_file)
        
    labels = config['labels']
    label_dic = {}
    for label_id, label in enumerate(labels):
        label_dic[label['name']] = label_id

    # set up paths for every image
    image_path = original_path + "training/images/{}.jpg".format(image_id)
    panoptic_path = original_path + "training/panoptic/{}.png".format(image_id)

    # load images
    base_image = Image.open(image_path)
    panoptic_image = Image.open(panoptic_path)
        
    # PANOPTIC HANDLING

    # read in panoptic file
    with open(original_path + "training/panoptic/panoptic_2018.json") as panoptic_file:
        panoptic = json.load(panoptic_file)
    
   # convert annotation infos to image_id indexed dictionary
    panoptic_per_image_id = {}
    for annotation in panoptic["annotations"]:
        panoptic_per_image_id[annotation["image_id"]] = annotation
        
    # convert category infos to category_id indexed dictionary
    panoptic_category_per_id = {}
    for category in panoptic["categories"]:
        panoptic_category_per_id[category["id"]] = category
        
    # convert segment infos to segment id indexed dictionary
    example_panoptic = panoptic_per_image_id[image_id]
    example_segments = {}
    for segment_info in example_panoptic["segments_info"]:
        example_segments[segment_info["id"]] = segment_info
    
    label_doc = open(train_path + labels_path + '/' + loaded_names_train[i] + '.txt', 'w')
    panoptic_array = np.array(panoptic_image).astype(np.uint32)
    panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
    panoptic_ids_from_image = np.unique(panoptic_id_array)
    
    for panoptic_id in panoptic_ids_from_image:
        if panoptic_id == 0:
            # void image areas don't have segments
            continue
        segment_info = example_segments[panoptic_id]
        category = panoptic_category_per_id[segment_info["category_id"]]
        
        img_label = label_dic[category['supercategory']]
        
        if img_label == 35: # <- To double check all images contain billboards
        
            # Billboard information is stored 
            box_x_left = segment_info['bbox'][0]
            box_y_top = segment_info['bbox'][1]
            box_width = segment_info['bbox'][2]
            box_height = segment_info['bbox'][3]
            img = Image.open(image_path)
            img_width, img_height = img.size

            x_center = (box_x_left + box_width/2)/img_width
            y_center = (box_y_top + box_height/2)/img_height
            width = box_width/img_width
            height = box_height/img_height
            label_doc.write(str(0) + ' ' + str(x_center) + ' ' + str(y_center) + ' ' + str(width) + ' ' + str(height) + '\n')
            img.close()

        example_segments.pop(panoptic_id)
    
    label_doc.close()

# %% [markdown]
# ### 2.2 Validation
#
# The same process is repeated for the validation test.

# %%
# Creating validation labels

n = len(os.listdir('Data/validation/images'))
for i in range(0, n):
    image_id = loaded_names_val[i]
    # read in config file
    with open(original_path + 'config.json') as config_file:
        config = json.load(config_file)
        
    labels = config['labels']
    label_dic = {}
    for label_id, label in enumerate(labels):
        label_dic[label['name']] = label_id

    # set up paths for every image
    image_path = original_path + "validation/images/{}.jpg".format(image_id)
    panoptic_path = original_path + "validation/panoptic/{}.png".format(image_id)

    # load images
    base_image = Image.open(image_path)
    panoptic_image = Image.open(panoptic_path)
        
    # PANOPTIC HANDLING

    # read in panoptic file
    with open(original_path + "validation/panoptic/panoptic_2018.json") as panoptic_file:
        panoptic = json.load(panoptic_file)
    
   # convert annotation infos to image_id indexed dictionary
    panoptic_per_image_id = {}
    for annotation in panoptic["annotations"]:
        panoptic_per_image_id[annotation["image_id"]] = annotation
        
    # convert category infos to category_id indexed dictionary
    panoptic_category_per_id = {}
    for category in panoptic["categories"]:
        panoptic_category_per_id[category["id"]] = category
        
    # convert segment infos to segment id indexed dictionary
    example_panoptic = panoptic_per_image_id[image_id]
    example_segments = {}
    for segment_info in example_panoptic["segments_info"]:
        example_segments[segment_info["id"]] = segment_info
    
    label_doc = open(validation_path + labels_path + '/' + loaded_names_val[i] + '.txt', 'w')
    panoptic_array = np.array(panoptic_image).astype(np.uint32)
    panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
    panoptic_ids_from_image = np.unique(panoptic_id_array)
    
    for panoptic_id in panoptic_ids_from_image:
        if panoptic_id == 0:
            # void image areas don't have segments
            continue
        segment_info = example_segments[panoptic_id]
        category = panoptic_category_per_id[segment_info["category_id"]]
        
        img_label = label_dic[category['supercategory']]
        
        if img_label == 35:
        
            box_x_left = segment_info['bbox'][0]
            box_y_top = segment_info['bbox'][1]
            box_width = segment_info['bbox'][2]
            box_height = segment_info['bbox'][3]
            img = Image.open(image_path)
            img_width, img_height = img.size

            x_center = (box_x_left + box_width/2)/img_width
            y_center = (box_y_top + box_height/2)/img_height
            width = box_width/img_width
            height = box_height/img_height
            label_doc.write(str(0) + ' ' + str(x_center) + ' ' + str(y_center) + ' ' + str(width) + ' ' + str(height) + '\n')
            img.close()

        example_segments.pop(panoptic_id)
    
    label_doc.close()

# %% [markdown]
# ### 2.3 Increasing dataset
#
# Following the comments done in the previous semester, we decided to increase the dataset by including images which do not contain billboards).
#
# #### 2.3.1 Increasing Training Subset
#
# An extra of 1000 images without billboards were added to the training data subset.

# %%
# Getting the ids of images that DO NOT contain billboards on them (training)

i = 0
extra_size = 1000 # size of the desired subset
nobillboard_names_train = []
while (len(nobillboard_names_train) < extra_size):
    image_id = training_images_names[i]
    if image_id not in loaded_names_train:
        # read in config file
        with open(original_path + 'config.json') as config_file:
            config = json.load(config_file)

        labels = config['labels']
        label_dic = {}
        for label_id, label in enumerate(labels):
            label_dic[label['name']] = label_id

        # set up paths for every image
        image_path = original_path + "training/images/{}.jpg".format(image_id)
        panoptic_path = original_path + "training/panoptic/{}.png".format(image_id)

        # load images
        base_image = Image.open(image_path)
        panoptic_image = Image.open(panoptic_path)

        # PANOPTIC HANDLING

        # read in panoptic file
        with open(original_path + "training/panoptic/panoptic_2018.json") as panoptic_file:
            panoptic = json.load(panoptic_file)

       # convert annotation infos to image_id indexed dictionary
        panoptic_per_image_id = {}
        for annotation in panoptic["annotations"]:
            panoptic_per_image_id[annotation["image_id"]] = annotation

        # convert category infos to category_id indexed dictionary
        panoptic_category_per_id = {}
        for category in panoptic["categories"]:
            panoptic_category_per_id[category["id"]] = category

        # convert segment infos to segment id indexed dictionary
        example_panoptic = panoptic_per_image_id[image_id]
        example_segments = {}
        for segment_info in example_panoptic["segments_info"]:
            example_segments[segment_info["id"]] = segment_info

        panoptic_array = np.array(panoptic_image).astype(np.uint32)
        panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
        panoptic_ids_from_image = np.unique(panoptic_id_array)

        found = False
        for panoptic_id in panoptic_ids_from_image:
            if panoptic_id == 0:
                # void image areas don't have segments
                continue
            segment_info = example_segments[panoptic_id]
            category = panoptic_category_per_id[segment_info["category_id"]]

            img_label = label_dic[category['supercategory']]
            if img_label == 35:
                found = True
            example_segments.pop(panoptic_id)
        if found == False: # Adding images that do not contain billboards exclusively
            nobillboard_names_train.append(image_id)
            print(image_id)
        i += 1
    else:
        i += 1
# Out:
# --jRsD9anHdGxv4ZOCQktA
# --NSVcUgfVhFd6uzkqHOOg
# --SWG8TJo7vrbZ_x5YLj6A
# --tczNya4_w5IhU9DeRMHw
# --zBInAo8-NDrBCfvJ4fEw
# -24xIsrQS_XSpHHgmmOB2g
# -5Tar0aE6kVomCLac556dA
# -5_vD3uQLbZa9We0ZRe64g
# -6KIBA7UMZeUpAF-MreNKw
# -8uEGk5o-Mm4J_WrNd-lVg
# -9KGl9SjjCNY1k7e7kZAQw
# -9Rwv8nwRvau53Ravsn3-A
# -A0I13p2EKUmebBd_o1WAw
# -Ae9jTBaJa6ZIG0_a1gKTw
# -b6cxvVDgKKduy1ohAOLiw
# -BXtaV58FRkenRKZro21cQ
# -D7PwwMuQ0K0dH01QKD__g
# -DhrBI2NUhI53j6u9k_adw
# -eGpGmG2YBFiIJKbToWO0g
# -ejK_lQI473xOq4kLFNPdw
# -ElQvytjkvXF3jNYXoe4Og
# -FDKMXaTWSNS5u9Ad2SO2Q
# -FtqiD0037yomyFmsem25w
# -GG2FOy_wmOsX6ImEm1uLA
# -gV4nG-7GAoQOLfuxidvEw
# -gV_IwkfSjb6nsiJD9hulQ
# -HFT-WGo9ftuyGUUm-4zGQ
# -HMM6ZkJJr4Wbdr9YS1MzA
# -J48Mok3W-uXxpG-eCuECQ
# -JmdruPVjc--VbGtTIogRw
# -k9vlupLf7unY_ZtGrivIw
# -koJxu16wZChFAi7BvOxQw
# -La2XLCsqbAJz05JCLflSg
# -LBkw6k6UPWAtdiWs1yV-Q
# -LudG9v6lNCqqxvMp9WMyw
# -Mb8uJ76AJsENmC8H_2Plw
# -MVFdfakzYTZdHvvdSUXcg
# -n0xk449bCVYsk6K1KScKA
# -NDNpoEMRoquHngyABVewg
# -Nm-gZulic8rBJCPVNOzFw
# -nvTzJ-2am0mxQPqnZzZBA
# -NwoP_4ghO8Uipu3Oj2cQw
# -NYCQnAYXLuvk2bKlJWf4w
# -oGaIbSDBcETJXT7GpJq_g
# -oQam8nRcx1ZPK4fUpiaQg
# -PGWvPCItNkYR3f90utJGg
# -rhLRtWHOcO_E3nVy_GxVA
# -rIuceFCk3AAriTwEuwAPQ
# -S1fNJ4q6OHzbhzzIQBroQ
# -u6PJ_fD35FU4GGwYMry2A
# -u_hrTOGrhJ2e6uqav6VBA
# -V5fGAIR2G__XTVqoz8coQ
# -v7b_dUz4S1Kjo85hUAdUw
# -VD3mIPvwRy0y2rDmALxhQ
# -VuAX2dtfk9FPaJVoTE5JA
# -WGjIIQiy4C3-MXHlEuQ3A
# -XbuVbJprvlUDmLVkYEZnw
# -Y2dYP9xLFN8i_ayxtoihw
# -YF7yrS0WkRqW2CUBmSOtw
# -Z0M-3HQwqjLHtrCXdfyxQ
# -zhRCVqHsZIMpUbqVjVRLw
# -ZNpBKL3Ny-v7qwQwjfS3g
# 01K7_mKL1Iw48p79HLKb8g
# 01o_TmhYAKongD0M2R4zbQ
# 025hM-2yEUkg_sNVNSCsQQ
# 03MI6UjcXaQHKK6tEK48rg
# 04QwehzaLPW4Nn0Kco-4rA
# 075afhUYa5gJT5h3zQccfw
# 07uWBP_EQE-psN5x5HbV-w
# 089am4TGngCF4zmjdy7BvA
# 090ExaEksvmZ69F92xpKHA
# 0aA38deY83nWyFxOOFE-vw
# 0AEbshrlRLCbY98l4gsn8A
# 0anRV7-GxEzdqh0f7sRsMg
# 0By96OZxMDE8YIkC_bRzmw
# 0c6ntDp-OroEqPRG3GdSSA
# 0CgLuq2YSXaoeyZHXRrMoQ
# 0CHioC7XWn6OwrISeKAM8Q
# 0dixz7iDaHFiDSOWx_3hPg
# 0DKoy4VasT7jwUwdyrFr4Q
# 0DvctHVEGgeMOT3VT9xsDg
# 0DYvmeaHMF1fvcDrf9zwbg
# 0fRbUP2T37dfE5FO06lLmw
# 0FS6T1M1yy86kTOCDbluvg
# 0Gorezr4O2NfRAHkEfyZZg
# 0ImMgBKkZDtJiYZ4-PN5TA
# 0J3PaH8YrNBL2ar3bGEXcg
# 0jmO7cxBjNwXmi6362zojQ
# 0kC3O9zcOKEu8UNoLVjKBg
# 0ldrFKB0_PJef8eZkLehyA
# 0Lx8T3ZqRmuYJxokVCyuWA
# 0MnG_BYo5DQtVHJD93j4jQ
# 0MvoaXqbynGMHz55vfbFQA
# 0n2uD0oEQAkPP5IDIfv8LA
# 0NfNT0gFH98gSYf3jUJ2sQ
# 0nmm2G4QB5cO_to_nDlD1g
# 0NquXdbXeGCs8rw3XJ2apQ
# 0nuZSeIG1LesHydzYbb2BQ
# 0nWUZ8x8aDdemyfBHn8AAA
# 0oN1X8hMx4tD_07B6HAErQ
# 0oyZr1qierUzY8mMMc8nYQ
# 0qjczUzUIxlvHIznL4cfRA
# 0r6JSdkXKAAD7vKa_FAqZw
# 0RIIRZW6m9YSJsv9s3h6Gw
# 0RTbCrGWgNbm00djay0zgQ
# 0rujw3qZ0gFaipyhAVs6eQ
# 0RZMU0W1gc4CUjH05Dwo_w
# 0sP0YzEkoKmIQyvxQaDe0g
# 0tlXnynYPQKeiImX4UHN9w
# 0TYlzT4htyTcqKVpKgYLFw
# 0U6qCKaSM-O5BorMTsHbOQ
# 0UHaMnGxr18YG_bi69Z3bw
# 0UyLJ4aYU5SvZ-_sU4oocQ
# 0uzp-M7XjMt5rFNJjrLijg
# 0wr7Fc2EC2R4ZDPucrlPgA
# 0wS8ulXqyM5cALgZnOYSVw
# 0WtnR1EYMW5YhTzb7i-Ggg
# 0WU-wtQIx5Jen2NMeQyw1w
# 0WZSw6TYMGgf7CD7YP0xgg
# 0X-O-ujHIdOJ43XQ7zqjrg
# 0XaR5AHxU4aTSDjVXkLqWA
# 0xwQYQNZpjL14kgjpd4aFw
# 0YoIMRbgxy3bX051q69U8w
# 0y_j89GMYnEATZ2KAtUCrA
# 0zK-EFR7LkjjR6r_NF4ICQ
# 0zk_b7xzXVZugRUyu7E2Gg
# 0zy090bBb71pudPWvhvQ2Q
# 1-FjsQS2pNvMwNHyUsC1gQ
# 1-oZ3s9Fyo_8shnuDLX4qg
# 11ebn1vg5xExKHCSGQGUHQ
# 14bDsrThRzeC9MbDAIrsow
# 14kC2G5QMDXaoJEjqyCCFQ
# 156W3rwnsiN47YM6xLlY3A
# 18ofxuk1R3F7kt9iYy_muw
# 18XINxpzSq4hBGlMKkc03Q
# 1AJxMl2fz3OIzolz3A0nww
# 1B52ZBHc8AzLxOqgzcOXrA
# 1djjrUWmHfEUfiT0Jvy8QA
# 1dVGWdk-97vs1wuj5DAIdQ
# 1e6cXLPJ7Co6hFnvh0yjsQ
# 1fsMKVlYg-nOYtsYUcpRuQ
# 1fvQ750eF3tjqmTf_aH4UA
# 1g8ZyAHMYwp7zskyrtqM4w
# 1HHSeUnApa59Snb5Fj617w
# 1hxirTSvLujshHM8_tc5qg
# 1I7k7Zoao2MXoGdWtMx2bg
# 1IwJKPVuMboqNehAssXIGg
# 1jm1jOmJ2xExAcpLDjQ7OQ
# 1Jql_9CBH7fSKpyo95aiJg
# 1jYSWLJkE7G3cvDsGcLRCg
# 1KB2cHkioW68n0sgXiLl4w
# 1kRTBIZtpt_iexwaAVkbdQ
# 1lay7mtYyoeIDF_hdCblVQ
# 1lPMIX0kf8gmdLIGlKWCww
# 1MU81YYl7L1IhFqKj7v-FQ
# 1OEyu7YRPaJZxrvMZsnIDQ
# 1oFuZl1NVAhh5YPdIfoHuw
# 1Og6KcIpk1vPVkfC8auRWA
# 1OrEV0Mk2bpOkxeQlS1hSA
# 1paWmvpewDdGYC1-UXnuEw
# 1PbiIzuHimh_Liqf5uIBVw
# 1PCSzeSXeXu8Fmr_oAJqMw
# 1pd25MlSRYB35vxwwYW06w
# 1pm1OpHm7j5SW84p_RcV7A
# 1pMZimB1336c8dhEXXlXNA
# 1PSy5MMVycVWPxHmji2yYw
# 1py5LeO_9MAh2ffhHlGq9Q
# 1QE42YpA12FL6uWezE-d1w
# 1rEBVRUh3ACRSN370m0PBQ
# 1RO68XGawf739CZqJDYWNw
# 1rvfx5SzkejP3_xd-UIt_w
# 1s3i01A3ZIHFeexfvz-YZg
# 1SH_m3iLObycIe18lKSqqg
# 1sqdH2roDkLB-lHDz48y4A
# 1swAT6tIPhLj7kOJy-tM0Q
# 1tEVbh0pBaPBvW3AhYr2jw
# 1u25o7lHHNhu8peoren_-Q
# 1umxZYBGW1nhTLRV7DRf2Q
# 1vWXCeztNxxhpb8FwESFQg
# 1W2bGdSD7NvfPsHE_XOimw
# 1wEUR7gwJtgtiJtw1YnnSQ
# 1Wk0QXAM4ePOrdvwoL6VIA
# 1WKC2Xj69Mrcr9DB30Z6sw
# 1xIoYnnjCPIQ0ZXwFzgiDQ
# 1xTuWZYV9jFraS-q5crArg
# 1Xww-bLAyTMhFiOy_eGJgg
# 1xzVIpIm-5IGlyYxHugpDw
# 1yiXOGgh3ZpfZ7ahXHA_0w
# 1yMDwo-6iqR5mq6bIpnEbQ
# 1z9oNL-IPAMzj2tFnacKAQ
# 1zAyr0dL8NrgdMqYU-VuZQ
# 1Z_hUaT0GgRPBB0zCryEog
# 1_pV8avhnEtbRY44a-kibg
# 1_yfTd3ZWelcEgVyKC7Fqg
# 2-nBH8NXxGFPCoSk4T_s1g
# 20qL6JwA5me2PnjmkO4AyQ
# 21OVifySzmQVA_fQisuNzA
# 22-yDF9JRJITmkI400QwBA
# 22FBGs-pYZcb72PA9h-8uw
# 22QOeq4TVRocD9bLXdRavA
# 243GxeDcKLwDAs65X4EMqg
# 24i0owrf57zvRPLu7UKh5g
# 26UGxZBNuMk-ualQkbOe7Q
# 27CHiSvw8jP_rbBZF2xMGQ
# 27Hn2MRNMX7XjYcyhdAicw
# 288B04zNAw948wkTtRuTzQ
# 28OslL6xyPxqSDJC40NCDA
# 29mEv7KHF8G-1lCmcBhN6A
# 29QD9R-x9Y2Ppe_zNwQZBQ
# 2a3LGDvhLodT0rRRgG1qqQ
# 2AGQDw8MLDrjRrRthX5J2A
# 2aiXYA9gfmB1oYeQ4QvElw
# 2AmMD1azjpKD-nwE-36Ezg
# 2AQX9bruG-nedNBb2FpT3Q
# 2b4msYy4dXQxzpDq9O2CDQ
# 2BhtJuGZzM8pE49kv7ZP8g
# 2bobqFiz8Pql6gmhFKFGfA
# 2BuMm9ZgzDRT4po0abX1jg
# 2BVCxWq8IhiN7oqRODUGLg
# 2c2sD3mHX4PEnnin18EdHA
# 2CA2TF4yK1N6ZEaWLc7ZOg
# 2CncmhS6blXSxrerDjAF8A
# 2DEiWOAgylwCsJ5oYWnGDA
# 2E5AKX5IUFDbEMMfvxTS3Q
# 2e6izLe7sq4MnBIGksUSPg
# 2EBw0CQVB_4OkErHDzRh0Q
# 2eFODF3MPBqQy3irNOzVyQ
# 2eGvUTBlcH-Mv82_NB5tLw
# 2eq6we5e64JpCcDY6UCpXQ
# 2fApMUJ12FWx3ZNQyBmpBA
# 2fukbtiFiXM2MavTCafYmA
# 2FV_hM8ejxXLOwzczL45oA
# 2gE2GNpvgGfgaKbTSPBTYw
# 2GLmFC6pEUMYnx8uOGdUxA
# 2ha6MLydJ1cYhTCUHK5l8w
# 2HAidpX3vzK4kMOJMwHuTw
# 2hvwN7vJpAinTNxI87CZSA
# 2ijWTy74tmlzHr1n8s4lIg
# 2Iqp_Oo1_XzbIbR_Xkfe8g
# 2J6rFq1aq-6cu2iCwdvQFw
# 2KQMkLhh2Z56pk2AXSn89A
# 2kxSevwJWZEeAqb5jLftPw
# 2LHNsNpByMUjcMmF4L2qbg
# 2LP133n2sZJ_fvba0CtWag
# 2mL9IKgo-dH3jxV8H0qwhQ
# 2Myt3xYZtVx0MU2gDi0i7Q
# 2nJUsW_V6c0MmT0A2ZY-DA
# 2Ouhd7jYxx1co42BkV11Uw
# 2oZW5mcrPGQS1X3Ppy_jxw
# 2PNITrD8z7ymCIESoi0KLw
# 2PRFzOJafHQjToRevnpVhg
# 2qcUmv--pDVFBYtNUxYXIA
# 2QLo_uli00OXtD_sL3B7KA
# 2QWdIqgLtFM-IY3LDy96IA
# 2rabE9KKM-ZU41dlvvU4Hw
# 2RcjclslnT1oWTxBikAQCQ
# 2S8yRQbWRq4ZabKIFM6hdg
# 2sgg2Hh6a5D38x2WIJfj0Q
# 2svsg-Vphsm4Ths5NTJVZA
# 2Ta0ee4vnYRJPoH3Uw5vFQ
# 2TiK7iVTm2g5jZTZP95oUg
# 2tSW5Y3DTQsGrSDvaKDCqg
# 2ttmfiCS1HL75gA8rkGpmA
# 2u2pVjF6pgMRhI5EZieSCQ
# 2UiUlk9K-ibfoMJ5EeSA1A
# 2Vg1fqmkM3eYsX-nMYn0FQ
# 2VleXPzeiEzhCylADT8Ntg
# 2vlh6fMgfwf3DuGYWLf43Q
# 2vYLc32j1p1WJtJPdYF6rg
# 2WNz4z9AmhTvDNCnuZhAgg
# 2wzJrc-ULZv7D4t3-8wVMQ
# 2X4lZ5pEpZf9ENCAxa4CfA
# 2ylSjakDEowZNJz93wmt9w
# 2YNf9XxirX9N9Nk8S5y7xw
# 2yNmHGGCqRaV2nmLD9R7NQ
# 2YpiZwd--dEybJleYOT7yA
# 2YyL-0z-faONutKvivQrug
# 2ZHgkpWpmo8ZSgsGeoI38Q
# 2zTSOh3bH634bkJrM9JY8A
# 2ZvIEPzdbY1OE31dCOXnYQ
# 2_Fnzu8YIZ6zSI348MosAA
# 2_I9ts05iVS1lQPbraxA9A
# 3-8HEj9uvQGnq8c_yCd0EQ
# 3-s6vMqp3qBxDlFDfU58xg
# 33Ejvydx0f7xWvM8lLTEFQ
# 33FhsnJIzx0dagjvfy7GBg
# 33mMQPjGEtaFS_sIwPsBAA
# 340ng3NNNwNzb3ackJpi-g
# 347glN92ioay-CtgPx9H1w
# 34dJgyt8--JBO5l4VAcVPA
# 37LY_zj3AA8YM5ak4NnV4w
# 38i0XbsVe53zbwzyHvyRrg
# 39FHkg5ZmNCokV4koVRi5w
# 39Jtz9IlO6BAO11-zXICEg
# 3Bip9-P7hvtoGAoeM6D-jw
# 3bKjPSkGr__tGIsY_n-o0Q
# 3BPtcVfG1wRlDUKiVLdm_g
# 3bUk1cSKED6OIudc8mPimQ
# 3bYFCjDoKRGBpw91gulvqA
# 3BZ-JgBkiRnjioXsD5DKeQ
# 3c6lcLZfsE1F_6ywdpTGxA
# 3cI9wKJIzmTtdS-pZErxyw
# 3csq7HOX6c2HvZvIGj4-9w
# 3D0T8YjE2XzYV3GKVxoBJA
# 3dBk-SfkqyL4RUU9sfQQxw
# 3DJ1pQgHx3ivj-B7hhG0rQ
# 3EpPT__aHOdJQPQ3BBtCzw
# 3eWzw0YTIpz1Hh3xhUccFw
# 3EXnXZkzOyDpQppjn6gTSw
# 3fO5yaRjz10T2cAqjALXGA
# 3fPgy6SsIT_zgerCxkIw3w
# 3fpjaufhzk82QUj7Te5UfA
# 3FQqX7wPSghdZVX6KYZDOw
# 3fYWbG6MQt2PBBOVqYBgGQ
# 3Gd9pUdcMd2QD6I__jae6Q
# 3ghv48ymPg9vrqIYL4uraQ
# 3GPLX7IyCIFkhxWEkMaT8A
# 3hdkzpP7xvJ5T0doN8GSNg
# 3I7kZvy4Q615IIfzDKwlhQ
# 3IO2TaYMf_EF6aaQLTpYnw
# 3ivFRMbQkcFLUympJvwKNQ
# 3K-7Sitqb6VWKCWgjTNMKg
# 3kv5bGiH20dkq9beX4LxXg
# 3l3NvBBZSzg1hpWZd-99Zw
# 3l80k8nl2QXyptaEcYx4Uw
# 3MAH6b7SyqSstSNGekUATg
# 3MdcI62dlBOGKcqoYbMMBA
# 3miQwPjbMLv_qHL27unpeQ
# 3MrDfRetx9Tpfj46TFXoyw
# 3mw1c-JXt8y1gRfVS_5lhg
# 3n1rwC4IClLxfD07tFvtqA
# 3N5Hj-WV068gui_3N3lbKA
# 3NbAh3vfpDdcbB_YyPE9dA
# 3NgUmRPI1HEYwyXgDCW6AQ
# 3ns3940Fk94nOLyhwEyivw
# 3OdfhZsEMjBBGWYZCd0lJg
# 3ODlK_rdY0Z9C9ZvHUfGRg
# 3OehS-q0McJQX5h0ygYJUg
# 3oODfp3nSdrVumFx9Pi-Rw
# 3Ov2ijg0gQW1rgOGXr9NZQ
# 3pLIYicD6GGUqBvskkVxww
# 3PmXMeQHfvU8wWfw7U7ZeQ
# 3pq-pDqHJ-EUWfDLIgEhsg
# 3pVtda5x2wQxhX-LVFdXAQ
# 3Q3xHydrzdxeRuGCi-UMHw
# 3QeZrnYpMqXofZPZPAji6A
# 3QGrbE-oHh3tWLP4kyenEA
# 3RG2_RB4eZ41KRakBqWc1A
# 3RLe6ePdw4OofgGLOfGYwQ
# 3S0iCiH9v93XbSxz5sIeSw
# 3Sdd2AavEmR9IT1yaO9vPg
# 3sF9DakPVpn3KSb4YOd6lQ
# 3S_QfB8AHCGEx4YEAbTVGA
# 3t0AT4nTYNPJiFOSiJA9dw
# 3tol9yKyV1bTtxBmMgNHYg
# 3tP64wB9wdAgBeC73YGIew
# 3tsu7laemjGwxtIlonab_Q
# 3Tz-rjTFD9hdXy9xsaZnCQ
# 3uEL0FIt91rGX4Jf2Ib64g
# 3UKuFDTK9OZRgBhr7871oA
# 3uLNgOj-4iejrDtGB5HrQQ
# 3ulpkm1Q-Mqi8lSSLLEWUQ
# 3uQlNaY-1en9s7y9Ar8rCA
# 3vhQjI8NQelkS28IyvYH2g
# 3VO01uj77j4vAZeSSICz3w
# 3vpvkSzWWCUvVbIo0Q5P5w
# 3vs2sr7NNAnm43Y32qOggg
# 3WQikHteQyxxyOHWzISvDw
# 3x4Aa27dOmI_orlI7oUxyQ
# 3X6Gg6X16KVIHicDgNTByg
# 3XaFu0oLYnlPvs0jCOAn3g
# 3xJot0WFWYDdjmZnUj-fqg
# 3XQKu6GoVHVJ33Lr4Taiww
# 3YvsinMPpfviEPHrfQoHyw
# 3z0K_SVnUAoOqaXocBm0fw
# 3zliytpAuiRDKIizn7HgWg
# 3ZMT09ZG9bGQb2y8smipgA
# 3_fNH6k2KclGOCnX8sgTgA
# 3_iBHJqqvDguqU2fxT_-9A
# 4-9coGfbA_Tn67Y9gJHdGQ
# 4-Q1zeBVtJsbRwEMIds6BQ
# 40Bb2Y7Eae6C-j7lRGsuiw
# 40k06pvYPOOsDXidUhMLxA
# 40ye4e3WlMSUTklWTEp8dg
# 41hm9XGjH71SiMOWqz9eSQ
# 41oz03GxpDCCxX7JhrcK0A
# 425RYp6cuBSkORPQ569OBQ
# 42ltiq6R1DcjCCBeqTNKLw
# 42mZAlfq3jzGX5IoHTaZSQ
# 42y5FzvZO7fn7OaauBfq5Q
# 436R2pE8mKkGyyCJH1hw7g
# 43hsfeRik88juOn8wuf5-w
# 444TemJ9wVTkl1Hr0OX2DQ
# 44e786MCUhlL0U5s5sDvsw
# 45qQGMGIFqkT88kKplDWIw
# 4729siAEyUQ6URwE37oz3A
# 47VvVp571PWR5PjAMhht0g
# 483XnMwD2kAXSgZ6l0YLiw
# 48sZ5gvwA19QW_rwwPJLmw
# 49khrzHNDYtXKCugEeSqmw
# 49uPurIZ8xh38YxUgnmEWQ
# 4AFnYQ4ubgG5PGLYOpfwrQ
# 4AV4alueY4okMvyhIibeGw
# 4aZPVQTsTzeubc4Nn5W-Qg
# 4BR6X3rsY0isUHD6DtnXgw
# 4bUONk_WnaqNEwoRyM01aA
# 4cDcweQrRuX9KUuvniyoFA
# 4cJSKOf8-esMkDnZqzZklQ
# 4cLak_JLBKevvkJn7dwAhw
# 4CTKzhgfsIpshgsclx55jA
# 4dJUlF0yIABNXB0WVh2cpg
# 4dKBY8RedP96H3NeE3UiPw
# 4doknTEqs4eQnCA8puL6UQ
# 4Ec3mlv5TTFLkdiapdu5HA
# 4eZo1X7MlmUUS-9wB0S0bg
# 4fB3Q374x83bu8Q7tec-CQ
# 4fD38Nxgs6_-URTfn1aq2Q
# 4FfK1apb7rTn2j8X14T6qg
# 4fogD98cmgKfxH1dLjdtzA
# 4FSTsnezHz6BsV-hbTGZ7A
# 4FXWtzKDyxEJlwHMpgMeWw
# 4h-D4r13ViNWvdqZFFFyhw
# 4HCSWTP-k7OrqVj2RzUgfg
# 4Hdc67iSICfaNYtGVaRGOw
# 4heOdBWknMrgW-tu8b1PTw
# 4hJORiX2j_68-3oQ7vhtkA
# 4hVGGvL5RB18jNv_quie7w
# 4HxxMegBJ2Z1CzyiZQPb4g
# 4IdUn5D19-WJ7ysgJO1xhg
# 4IGmCkkVD-AxlzVHAYyYfw
# 4iiQzPoGLHOE-Falk5Z9cQ
# 4J9Ol5sNV4pa0GtX0tluyQ
# 4juDgr2AVILDF2_v005wyQ
# 4JxG_CWP-TwqsJvlhwiD6Q
# 4J_5ndss13PDMZ2SAytVcA
# 4L7wAnlDOJkwI0c__5hpGw
# 4LoKYdyYvZfdr45ZWctchg
# 4M399lKACAkdNJCLLfviyw
# 4m84WKu4Dum6iE6Vk0JFmQ
# 4mGa8h_xmYTbDIwKEeruGQ
# 4muaoPqXAwi8SOvwV-Jf6g
# 4MyhNf8yqn_nrj3UZIMnsw
# 4M_bcf2V2RAbcwpwask3CQ
# 4neqy2dB9gn7d_LJVPdTAQ
# 4NIPQxDN_mZEV0ycDCLFQQ
# 4Njw7L55MDMZZuJ91w5lHg
# 4nKP5k69SIH7iNhaxUt1bQ
# 4NMKmL-b_-LoclLDwhpB9w
# 4NQtWCS6rl37i-q5UrCdhQ
# 4N_h9CMPNm2i5qIVsQyx9w
# 4o6rrwsjhYK8tRRyTPDi1w
# 4oESBYACFZ_o7GGuOgCgGw
# 4OmHKC6Z9xecz76jQkVr0w
# 4P9aK4Z4Ut72qSOOWSLkpQ
# 4plqtFIbbcfzrZ-AX9kaZg
# 4qEVXwyLUtbUcKHxUbAv8g
# 4QGiPSEmPWpCKKsHguPDwg
# 4Qion0y3UHm82II0iYbP4g
# 4r7tp4Tu4nucS-JUj3I1dQ
# 4rdGSfbd3XF7M-ouovnVyQ
# 4rEOHXD8dnJwWUudFrw2wQ
# 4SzMk-FiBDMXTr6uNk96tg
# 4th7kFPWTQIcGipojbLeEA
# 4tYIEZDAlpq09kzeaoz9SA
# 4ucADQgZ1guXXI5w9mPyzg
# 4uGePDd5Y32Uj7Nl7Qej-w
# 4UzISn7eT0IVk2SvyvunAQ
# 4WoyMELltxBg_LI8X7m0_g
# 4WWZFM_d4eEfqE-lChTSpw
# 4XAng4HmgCwdlurA6RAMdw
# 4xAwCsxuuFeUNnhZwHvxCw
# 4xsnVkNxT9Yu4Pq5M0Le5w
# 4xuhjVKC3sY1dLw1gYpeNw
# 4x_EuKHXLKSJ17uSV9C27Q
# 4YRnZtzqkzPYRhwRPjQLRQ
# 4yzUS-zNqbBrfYv3w_KEhQ
# 4Z8rfnFxDMJDh6D6v6KRkQ
# 4_5pVnUuOB2dLarfAHt2HQ
# 4_m7ze1URMmMzKRtJCC6jQ
# 4_XQrBCCpMwbTT814ljtYg
# 5-8RCbf72nOutHwgMtzz6w
# 5-c3o8ZKpDSjtFJgTDhivw
# 50qMQH36R2jlV86Ly6NCqQ
# 512DaHQJudbp3OVEZEHSxA
# 518tcJ3hR-DuR0vXpAy81Q
# 51iCBF5WDed_u2a92qir1w
# 52v7VA6DKjUPgLi3n7xJrg
# 53DydQevhsH-yns2u2hwIA
# 53FCZ--fWAT4JXCCqmZKoA
# 53G4RWFO1C00TCJYP0dDmg
# 53QQSm8F7c3QQhJaLPIc1A
# 54AVjmhus5QzJeZ5ZX8jRA
# 54IkMGDSUV5J6LZX_XsJtw
# 56Tpfme_uptbTX4LuJg_GA
# 56ZbtsBa2dekKU1EjWk5nQ
# 59VMA4Jxr_B7-T7NLotNmg
# 5a1XdkWR-voCLuI5OM2DkQ
# 5a936dBa7Fm2x_CZY0UFSw
# 5AgeAEHP1_qU5T1uYnXiSw
# 5aUc3P4nATqm-SKwFC-fJg
# 5Bajm6UD1iCaOYdm93r37Q
# 5bcflh0YHi-HVtA1PHdvbg
# 5bKnH9X6X5qWM6qb5ZQM8Q
# 5bzCVDcbUOkQzXuNeFY7Pg
# 5B_t1lF8upeHqqZdqMFr8A
# 5C1AUBdltpORut3GMhMnhw
# 5CS2ELIPfJKvrEg7XS86nw
# 5cwbjw-N1nZVFdDbzG1Qvw
# 5d9DROI6I3uF7JWIIrYeOQ
# 5E-IBSF0BRSblm-npUOk2w
# 5e3GMOotPsfqIs516M0otg
# 5esku9AgA7tJFA5zUsz0jQ
# 5ExMWBrBZqUn39gTpDGBuw
# 5EXZJum3E6wP6GLpPzOwYQ
# 5fI8B4worT_MSMTOo5hZaA
# 5Fj8vBxychyvnmGrksY7jA
# 5fjcULYwidsB0b4lm_zb6g
# 5FOhOCDz5-JJPgWephJLOA
# 5fYpHa7nZGVbOiUBen-ldA
# 5G88siC1D7xpa56mWfyU3g
# 5GmwKS1a11POUIYJBO5k2g
# 5gt211Xzf2mysdwDKBjdjA
# 5H9HvQxKlLf7gVlA6mwifw
# 5hPoZNxYKkqz4LP4KqCf5w
# 5HRO8s6T-a2CkevO7z-AOA
# 5IBomyAmZMAsHcsD57LoJA
# 5IO0_gHz98UxyOGjiUGPqA
# 5J6kqvN-GA_mLVntQOzi0Q
# 5j6YKJPE1Jj4v8SRntlIDQ
# 5jFmFFlyPgncQGHJL7H9kA
# 5JfTD__NTBKkTWS6nHXYfg
# 5JmeKjoG4sKb3QGp39ZjoA
# 5K5Otc-9epjg_ZzEkHWNPA
# 5KS5juF5L76PmCNeaq06ew
# 5LBo7wUg2vReJwwr8LyhUA
# 5lfHtu6gjP-xbs50Y1DEyQ
# 5LtZ5VBizsKGFu1tAvHWyA
# 5n5lUIEFv43tKMZfwjQ3Yg
# 5nh5za22KUc0tXxMjrW_tg
# 5njuyDdufE4VNPPjiaNclQ
# 5NMY6TDxEkx8CMo_dm0P7g
# 5nQcTz7hq29Jw-yaB0lfAQ
# 5okbNM3DFIDYlG6gs_VKAg
# 5OTN47W8hUVdlEd6yMSxzg
# 5PG7WbW9GgsvU_lCqbh_iQ
# 5Qd0emTtkGN3R4yO-L5Ocg
# 5Qm7LdwhaJePN4-oWubC8A
# 5QMUu8Viw608-_XuzCw9Wg
# 5qYYMwIQ7NUR3FH0-C7ZkA
# 5r35aLpzDE_FffYP6Eqf3w
# 5ro8Ayuf9Qn8fQVfy3nGBA
# 5S-95-evfY-yAEL9XUeZWA
# 5sjkxCWsG7__f05ago7IUg
# 5sm5ZDcVUh-dAYwc__9-fw
# 5TqR5P3BNVsi0YkWPQ4yOA
# 5TtlmxidZ4ufSvcHw3FG2g
# 5u-DMTd-3YhGYPafoXDRbA
# 5uqBphOJa5PGnzwVuGnBIw
# 5uzx_96laA0A_t7u3vRTyA
# 5wAjRtCNp0tgcF58OIjG7w
# 5wCk5J5sM_QCR2-jATUBmg
# 5Wz8cuV7svJrBBZMEmaHKw
# 5x9AnjPb0fmmrs-WM5ms2g
# 5YCAi4ZnhQ2u3MwcGhNDJg
# 5YiNcVVNLy75ZuR5T1mnGA
# 5yuwU83HfOKkq1Dq5CRLlA
# 5YVFVvsRs7LxLsjbtR5DPw
# 5yXaOF9Uf0wpeBsQUziVOw
# 5Z8aPhWmx6RQfJ2GvZlwSw
# 5ZfBb1cwp2LuXv_ofqMXIQ
# 5_l7uQJMW3B7Bry3PUnNyg
# 6-0aLjQMdbuUm3fq7ZnO8w
# 6-GzAmqscvaEilwGOvORaA
# 6-yqZmkO4guBIJA-aVkPpw
# 61S_ipA6VckLUvOf35qMcg
# 62sdAFJMLfy0RvfD5LqQUw
# 638B1jBPJSMtfJGYk7n9dw
# 63b6ceoynzA33DiVIdTu9Q
# 63PDTfSAB0zKgRcP50_lcA
# 64OfSzoMmqa9uw2e-JfpsQ
# 65RvHV8Z_oxkwvARhoMlMA
# 65Vo7J9RhUlHqGS5vT8FUA
# 66BJlC5ERBbfd8YK2vngOg
# 66x0wPcFiB3O2p6nWAnwJg
# 66z2DX6Z2pWU5n-P8rfD3Q
# 678ZdQYqKCGJGzFb803wdw
# 679ap0rHH5Yf7VIDtz2UuA
# 698ONp0pL3kQoIa0-IA5tg
# 69PE9DtgtsF_5fcs8EOyfA
# 6a96s7CVGkLPle3m2bU5mg
# 6B-wE5JbpejREcrL3RlEug
# 6b-zt1gg3ipO-m0e8lJlYQ
# 6BdqyMuIlQIp4HtFmFjYig
# 6CeIb6tFsaPYD-BbdO4DFA
# 6CgEv4XYpi-pManpHabzaw
# 6cPGYFeLqe5_RSf--Dq8DA
# 6dcFj2Yb9TubW9QMXaaZ1A
# 6DhFYwySYTF_n-CNR_xesw
# 6dKijzDmGLV30FO5Jsk4lQ
# 6e1gn70hj3JhKHHgkPmDow
# 6EGdl3P54kWFbD3UQ9_Trw
# 6eGwBqduurMtIeR4GcJA-w
# 6EmgKA4In5Y-MQBscivM7A
# 6EQvCrRMh6QLJh1rDe3TzA
# 6F3GrKIsFJHL0N_-0d79Xw
# 6fe-t7trGlg2nVmt4KWxvg
# 6feNpkiwqLZ7JLyq6UbJoA
# 6G6nKslBuPv6V84QMiNi_A
# 6ghPVcOBUKW2uLjET-G2vw
# 6GUAERFMBVRkZemflD24FQ
# 6g_0HrVmdfOj8yY8ys2bAg
# 6Hebv4hvDd6IrCBFPeluXw
# 6hTn8EfSedZPWmE4dZwbrA
# 6hz6eGT8wxmkM6n-r4EsFQ
# 6iawu7zHqRzZYX05KCbwWw
# 6igAZkpPOOTvbkwVkBz32g
# 6IJ-XOcBTRfupxVdXr3ftg
# 6In8ez2hPYPgeOkfGa9hNw
# 6IP3y2t5UHUxkOGGV6QRig
# 6IUw7cY-YON4wRgSfjY77w
# 6iwfDd7B8FdxtSQnW0t7zQ
# 6JDiDBf6tuoheCSgJ4toPA
# 6JvEDfekC1fOXTR4woFs6Q
# 6JWS9GgR8Y_qEQUUkUmeJQ
# 6K5RwVf4DJG6MVCqM4_OZA
# 6kDA2EYY2E40SRFdmQz86g
# 6KZnl1hkPREbL4A3ZWuWcQ
# 6lil341DJG1jpldI6bIufQ
# 6MK0c68R7o0hqopdFdqOKQ
# 6nb-KzAO11aqPmnKN1AFWg
# 6OvZlLfHiYV0b8uIiT10lQ
# 6p3mca9buwwR9sT4B2_2tg
# 6pDKNq9J4J8XUbfJjPvc0Q
# 6PiLHFNQd6eP-byigSrhcw
# 6ptC_G961MTlCASM6ZwyuQ
# 6PtJRt-55J48jBgeqeyDfQ
# 6Px5kxNTEoLZplfptB_-TA
# 6rAT_FaPbLFi_CxbwRrBOw
# 6sLIGj2B-IxBc0-lzuEgPg
# 6svi4yX7dZtHU-mTgvzDDw
# 6tBK_1NFGYkH5INkB8Ebxg
# 6TKKmenIVq61AXXapDRY9w
# 6tu_YtXVrrvWJZVJUtWenw
# 6u9nIcVRO7m3gl1TEDGCVA
# 6uolLyxaTCnAo3Gazh1OAQ
# 6uslLqrOQlVF2Pki0a5pUw
# 6VonDZ2pfgQ16eRLu-O66A
# 6Vu5aTpbqxmlavqISyVETA
# 6W5OjIqpMDfPWudZKaxQqg
# 6wXryQ2d_Jdi97j35gFLPw
# 6X6Q10Lyw8-ObDG72dhICw
# 6xiMOqVOqxBlSOVP9G3izA
# 6xLGJYlbYD0GoPewrWAKUA
# 6xPUl1wR7PKaswF_RsVmgw
# 6xpVHx8zzJZtZy63ozt_Vw
# 6Xw4DypoikUbnPz0HLEN8w
# 6y4W4-ZRTmulhi7NUst3_w
# 6y9JJF_KnvaglVzz_TKM4A
# 6yT62uwQcOWylYoRLsLiMQ
# 6yxPKoSb6kedq2UU_A7eiA
# 6ZdR6mgKXoTTXjW49zE86A
# 6zkLzAGofKcb1tnKIyF6wQ
# 6_WtmzzjgzWAYJ3lB0cnzA
# 7-1Ymn-KzexhtR8JVyuPrQ
# 7-gyzleF9pxmczlfRmjF3A
# 70-5QbzGV-e5VLLWPXfHmg
# 70Pv1m9RIxB34Sc9sfpgEA
# 71DodriIMc7u8Qwx7wkv8g
# 71kE6fsaRMZfVga-GFM9JQ
# 71Msb_T0T67tXF4LqO6ZtQ
# 72a64WpXpuc6GOlVwdDyYA
# 72NgTtDivB7TPZFy1OQoxg
# 72oE2wkHtWpg4C4nygPLHw
# 73EqbgwsL4tyhCBIA0xYSA
# 74aa8LHMiDmis_rRQon4fg
# 74brgVKYwrwzB2uB4gbbww
# 75Wyn3WcU2GdILybfyTobQ
# 76m3k3z9sKmFUPU7r68BMQ
# 76Nf0Dmc8R-LPm8tc9kZzA
# 77r5CFYeA3oLMRiSyH0yvQ
# 77Xrqg6nArD0dJVCaFYqzQ
# 78ejU4dx_CRrZzuwWvBTxw
# 7Aao-8jjFaDmJdUiIettpw
# 7aop7FNNzT3iWPN9AtAQAw
# 7auTG5H9urJnc5fjmI1GUQ
# 7B4qnb2kd0RDAE7W9m7wOw
# 7BmdcPDjXHK_nf5QIN2AAw
# 7Bmg5joGnfyZ6_XEcSXYdw
# 7byzJmyz7HQS_mY2g2W4QA
# 7c4AeEq-5TiRSHZtxmsDVQ
# 7clRrU1d9ZGc43LsqLNY-A
# 7cPhRq949kPUP85TBSAxZQ
# 7DXIfZFM9_-GhQ64uD1GHw
# 7dxMzhwdxwGfhLeaszNUug
# 7dzpAz74BOm7fjRNiecMkw
# 7e7rGYJwrmqz1hX3hvXWbg
# 7eQC6cmwye8z3X-3uNkHqQ
# 7fgedPDvXWPv6u92NdJg-g
# 7fwryC9lFAhiV5QliUN3UA
# 7g1whuCLP5WBx2xJgUvQ0A
# 7gCWD1XITC0pNiROR-fCYQ
# 7gJ7vetwm9lWp0IfPs33ZQ
# 7H4_34fB7SszzHBTRP53yA
# 7h8HQkxirNgUw4lpOSDH2w
# 7Ha0ZrdqrnHpSZCeBiPswQ
# 7HaFqouqXWbqAXHy6pJgfQ
# 7Hfz3xOTbjiAHpG9lDaMRw
# 7hhZtNW7IXBax82h8cJ8uw
# 7HQ56BPyv3u-XEMkYRMKlA
# 7IJrGgrOZEv_0c4y56ecJw
# 7iv_IT1yOoP_SQsIlA7a5Q
# 7izM-KCKr_1PvQuRZzO4Xw
# 7KbKznKgPQj0UFZoVXXKPw
# 7kYAI8iVNBfGvThyzkG-EA
# 7kZ61Nqz3U-X4rxkqbQLcA
# 7L-xh3hiZmF_4j9zYsQNfA
# 7Lh9ptt0ryingeFaamoEXQ
# 7lnC-M4bPLV3cnXdhTYM0g
# 7n2vCMgfSgRCPIM1pU0Z2w
# 7NPyt842d9j3FcfGw45tyQ
# 7OC-NYrkwv5-rj-UhAntlg
# 7OcKHOcv6KwUvzY7-NvoDw
# 7OKrlI4wTwdfe2HEIHZNpw
# 7Oz1c-XtyAJA3_nwm2DBGQ
# 7pHXhYqDki29gF3CPRLjtg
# 7Ppge7pEiUY00ZrYoC2NGw
# 7QLZYSBPKlEdJwukm4ompQ
# 7QphQcZZG7SoDIue8FoxWQ
# 7QzfS-7AGysrJEBczkKBpA
# 7R1IoOJdwr1dxUiHBFMNFg
# 7ra3mJiS43cB6baY6Qf6YQ
# 7rYa6scKbeW5wFa_ajk2Qg
# 7SOINT4Tidaksd68SrGTyg
# 7t41lXNxZ5P-B0fFz5uEmQ
# 7T9Wrc_GjqXARIVoQDtCfA
# 7U5xOA0w9WxT3RAOlIc0Iw
# 7U7dvVvQcLAIVh3mrjCJ_A
# 7uMCUCVjgw64M3J6LsSSzQ
# 7un2vpG5-Aq0NxQ6QapQtA
# 7uZjkhhIOrm3w_Bpy2p0DQ
# 7VlD0_D71FHACIHtYI_QdA
# 7WfR4OHGzkeSDYflD-3qrg
# 7wWBjAwc-ZTyyXKusBjbWA
# 7Xd2CWnK4JCYRsfW5h_OHA
# 7xqNGL854zBCxeG6mPeK_Q
# 7Y-VoZgutihhATPVIhsu3Q
# 7yqcp5hJKRsUK7xl49A6Pg
# 7zgCEGUNiY3U0oPid9mE9g
# 7ZwRJolzRtGtonSupFGPMQ
# 8-FbAAG-tuILtdtDuRByjg
# 8-gIRjawRHMTsthYW_VNgw
# 8-hvEEIlGGl1BLMBybT0IQ
# 80aCC-ikBztVNQEGXAKMbQ
# 81e5bRiBnr7C3_lV3slppA
# 82DbRqsEid67wr_-qNaB_Q
# 82kED-EcvmG4Ptj98rcQug
# 8404UtpIF0el5KScR4jMzg
# 84d0yKfr7a_g5BRaoK-5Vg
# 84EYD5chWIu_KsRiR-ucXQ
# 85qkCQWTmcEcTZWB_gKO6Q
# 85xlhm-hpBL6W8YsPj9pNA
# 85ZOwzCzaGJSe7q2pz0BQQ
# 87H51F7PIGsEiDYicH02oA
# 87Hrby9n4kDpOOYhR4mKww
# 88bKhEyyzF0lld6_jSJHLA
# 89A3hd7bX-TaNsAdwZJZjw
# 89AEbYg9WmIiqLwE_jqvNA
# 8ar13V_6c15rK13fXKBElg
# 8bIv8AfoPnASAVwXSArwgQ
# 8bWX13S_jhrzX2m_O2xJIQ
# 8CvaYyTKsEQ6lI8DysjvyQ
# 8DIhvJHkdY2vgnvppGq3Jw
# 8dl0cRBOkN926v2wkdeNXA
# 8dnx9vXxLtgcRkJdLdWE7w
# 8E-xxxtVP-r3EQv_8Pvxsg
# 8E18xz_baCWehxKHlKUoHQ
# 8E1WyZOQ8blrZXWLEyhvKQ
# 8EFZpvfR_BnOdruxcImOJg
# 8EPFsw2wXMBrGmw4-4Kyiw
# 8fiu4MFQAcAuxinzbCEJuA
# 8fS8wXQ0FVl9Uiwylq1L-Q
# 8ggWafheaIwL0GhaF52sqg
# 8ghIwNw7Jfi9ERIYRCGxzg
# 8gU6RLdZEPaI1ZKWmLH2OA
# 8H4PDBcu8f7lblAoryzn8w
# 8h8cQSIojWh0Jb_YxeNFJw
# 8HEKNecNZFedc_WWDu8Dsw
# 8HIEYREVtNobE_cuaZ0UWw
# 8I_rmbcn4jA0RL_IHaIEHw
# 8JITUaWVoz-Iap6XEdjGkA
# 8k4tcuUvz5pm-kRX7Gfi1g
# 8kdJYqpj5OGqKaL6LSvc4w
# 8ki0ngSC8PN9qBtA7urAFw
# 8ku9As1kKHE2dOOFL7eauA
# 8lajtqnWhhQWqOe10TjkMQ
# 8MbsrH90TDuWdsJ5v4vArA
# 8mIgH5n0b3W_MjCluuoTfw
# 8N-ZP9cbEIBYf5RahgByJA
# 8Nc3aqCaHMFglx9ea1zIcQ
# 8nEsbArrdbk2eIMaW4RIBA
# 8NILOiqCktxz-sdq2Y4q2w
# 8NlssGUKlQP5UjOZMve7VA
# 8nLx_NptzyhIZHku_NSGpg
# 8o6ZXhP5e3Jv0ytBE9DpOw
# 8pIpi5zHf2JvoAkmk_WRAg
# 8PpZudf9q1ojxyA8sYtRSQ
# 8QaBMt5M4MHNYFI1EaA-ww
# 8QpYBtpKkc-RRyCT4KY2_Q
# 8rVaf59oa6YYBrF7B0qHzw
# 8s0gkcO9xLVR17x7ZvRwXQ
# 8saWo_gdVgZ2ZK9ZHdvDqQ
# 8sh-McoXOtUHDjGzMGspHg
# 8sqXBqMsJbI9P0ryimj2jw
# 8t8eNGdFalUirnCUh37nNg
# 8TOsQa-UguNueNYqkNd4cw
# 8Uq24nlMSHpISI8U5lcEDw
# 8vFgJScByCZCG3rLBmZQOg
# 8vYzpCqpyyzIPAbm6188wg
# 8W52Z_rLevt1bYgpFl6LZQ
# 8W8S6x3v_DLrXp4Obbxb_A
# 8whOvTb8DR3vgTUhL_Q4LQ
# 8WIf4nTWX4ngm9O7VnblEQ
# 8Wvj1epTdev4J04BDILz8A
# 8xUpzz7aY3EFFvM8cdmTcw
# 8ya8OpM3LGb_wiOfnUf9Xg
# 8ybDO22Nb6jhboWSRIHA2Q
# 8yqaEjtHoKQAcnwD9kjWag
# 8yUq3n1tHQgyCtzEoKu4Pw
# 8Z0fY_TdSaK_0iHW8nb9bQ
# 8zaF1MANlmZo5dCAb2EuBw
# 8zozZmw0s0T_a7igXFKIWg
# 9-mvca-K8HqmYgiI7DZDiQ
# 904JDmC0LrClqdO4fg3gVQ
# 90996eGJWr2gSTUwCOGL1Q
# 91IOwuIMOSrtzJ49zSD53A
# 928X61J9z3FE_U9hWyeKRg
# 966I2dC8ny2qjqYOQCHKjQ
# 97dY23niKU4D5jeg6Xw5_g
# 97hMGO8xVF2ZlTM6zcYY5w
# 97nw28hMMd2ZPLzol2GQjw
# 98G_ONtIw5aQJsvzH_Lg_g
# 98rnstmA6i_zBvHlHrnbqg
# 99LMKPaqiCo3W3Y8vSflvA
# 9a6zwtZm0pp8zbpz_Qjkdw
# 9A8DEosvjCKIHx3jfgp0xg
# 9AAiL3L0SPh0ANryR1hHRw
# 9AGo4Bqzz4Dv6OQ-YiqPIw
# 9AVadORi-w7oDzGKR9NcpA
# 9BPZTMiPmjaOey85JupEWg
# 9BrKuoo_XYnanMznZd7XYA
# 9BV9C2IqpZ8tYY9OuwIhPg
# 9C8y1klXROZ6PIWtqpSvow
# 9cehhhtDJ3ydBB2dAaRWcQ
# 9cH7MfOG4U_ohhjCf--KJA
# 9CxrX7JoIOkGV-dC1ip7Yg
# 9eXNmSQv7V4xyp2m_W64FQ
# 9FihsW2KOwMQuWSxAmKACQ
# 9fSsacqRWMNMx7vNRXZUIg
# 9G3g-2rDZqClnm05qQlsGQ
# 9gHi8Y79lNpte20GqyaVDw
# 9gJF09Y0QAKPINfSGAlq5Q
# 9H2bpaJuiYSu4-3v7GWYcA
# 9i8pA565AuaSY8bNbubWyg
# 9IbLLduq_DJuwJD_01EiBQ
# 9ihoueYJcF997998qtK_9A
# 9Irr8q27kc8Lh6GzsfZ11Q
# 9ITSm456nenlvnGoiekdOA
# 9iyTf6YSbOPG_K4WmKwh6w
# 9jeHRxGfRs1yLJGapgN58Q
# 9JQZlEmeqErPSQSLQVFpoQ
# 9JyGnhxCHD_ZolRaQkegTw
# 9k0xwZfIoIe-vXZk9KQwiQ
# 9kqI_Kevx9b56S85z-TMPg
# 9MelBiklsnDAM35ihbpSxg
# 9mi4KJlz2ZYL4VpSY39BWA
# 9Mn7wOrC1yfys6t9GiDilg
# 9mQNoTqxYIahBxL0uyyJOg
# 9m_UYmaKjFUZhLtkZduVTA
# 9o-5fs9av0VNSE00vU6cKQ
# 9o6fmrIR7HkLaADbs0f9sQ
# 9oEJxEbIAmAuIrY6GvI1Bw
# 9OkqCzUZbA99K3_E_ysJqQ
# 9om5QNVb5xmHqPkMvh5b2g
# 9oU3ExuRdc6liNXqoa2N5Q
# 9OUkWwjloftnRabn8Jboxg
# 9OWvQ7Gr0geKuYZbnfYxpg
# 9plgWHlD1Ha5dOCm1lRuOQ
# 9pR8DumVdGyTii43rU1X5w
# 9PsBKMXU6Rr0cteKhMsUQg
# 9Q8FDZ0w4beG8Hi8DaB-iw
# 9Qh5ePZxrZvmq0jRk_vwTg
# 9qv3pBXxQWVA3dyzzavkxg
# 9rozk3y3fv6RimRScXbdDA
# 9rua68Wb33fupTgSTTyHlQ
# 9Rv8usYYQ8-kfG7aFJYuyA
# 9sEiCXqrbHlz35g7nd9baw
# 9SvFhVtZ9b6qrBN1tRc74g
# 9THaZqeLduwjAVEdfosopw
# 9TlSTADiO4UlAER0nH4bGQ
# 9tXEBtEBlXokwHFHHtKwlQ
# 9UIlYF1KAZ6HXN3jbCuwUA
# 9vs9-Y61SevbBUWCJgwAQA
# 9VWpjWrN3NpkReBXLYVTCQ
# 9WQWX4mNI3-zDyesPDTaIg
# 9x1OFOERwTJdpaJ-aN2hdA
# 9xEYr2RIABaCQsrY_N7eeQ
# 9xQjlayDVuJCQDvK1D7IHA
# 9xxTcKEZ3S8ZB8s6TNG3kA
# 9y27nbPdgwb8IwGI7USmzw
# 9yDdiGeYsNHTpjkqXxAyjw
# 9YFGevAuXNA_cujX_WL8Ig
# 9YYc_iJPqYlWD_pyqf7MFg
# 9zb3SlkGwhY0H-8AhSdsIg
# 9zblsWFWCB-veoZ-W5H0BQ
# 9ZiQTxMCQvp6gpxzLVPFmg
# 9Zo9I6RSD1Q2_K9uquQjBQ
# 9ZOPTMVote7N7L6-cVv6zg
# 9Zq4ExT7yGehpbvNj7dheQ
# 9ZyV9Cl0g1mUDNRPdVoviQ
# 9_c8FIXUAcDTzndsY6glVw
# A0he7jGFnNQjKhOssQHkBw
# A0I9ILPI9c7E0ttN48_tfg
# A0krorFhRa3r4WFeBVV7aQ
# A12Zpx-Ae0QLksP5Wh2-lg
# A1BnpKRkHVfFRdfVSehnxA
# a1DF7VjBYj_LxS9HhmD5UA
# a1Oywc1t6comPePdqrTxPA
# a2AeZJ-45g59NsRZVSGSXQ
# a2oWwrTiBrKUkEgyT7NucA
# a2UIBPlbQN-pvRD99l2Nrg
# a3n-n7P_AxcwYlPKRzJQrQ
# A3ZZYaBLd9-K7VeBp-xKOg
# a4aw3cKSDQbbsm58d2GdTg
# A4kzwnGbNfJwYx-Ht3tJcA
# A4xe-qyAiGTzO7QaswFbZg
# a6bnlF7FuJav-qMg5WDbEQ
# a7pbHUIlVxpe7BhB1mqqHg
# A8-kLG58YAnBZTxiriVbOw
# a80-TbgnAw4glN3QV5XViw
# a8bxxNU-aa1FMtobUHfDQA
# A8gL9nj8Tu1qM5pvPToYiw
# A94wq0HTliR6iBuLMYEToA
# A96ho6nCwydFrjqKqAa12g
# A9FQ-xS1EqM3FaN2j1BrRQ
# a9KKWm1aQOS-6sBBUhuxxA
# A9LUMqUG9ftDeM1AWDDt6w
# a9qArCUisTbHQoxJYK3u_Q
# a9qI5JKP_9IR_6giHhGagg
# a9TX8aVW2dBAWkSpTC6yBA
# A9xKI2sKmedtI_dUa-2PvQ
# Aa1MnhtoGBKhBnVwlMR2lA
# aA9_qomZkVLVKMzbdyzKgw
# aacmfJFk4RCSuOke7-xaAg
# AAEHXQ1L-5t1E4kX9_oqMg
# AAgoqUSlbLxsjhPldCAfGw
# aAiv8iPZ-9eD7DahJ0sgzA
# AanbXvcZXFBCpwR4NBDE8g
# AaOPEdPX0bfAs0_1JYn3fQ
# aazb4cEQiAv0fvlZM9gbOA
# ab4tQaDBpCTvN7-eVHX2uA
# aBBRVvHi6guktBxwyNIvuA
# ABdVJq04c8uILf2Z7y0UtQ
# aBS2cgW0oqih8tPUbkRT5g
# AbuC5O9jo--YhrnPM7srMg
# acC55OsUFIyC4Kx-0Uk31g
# acd6kAtmxwoF0L3K_JQIdw
# ACdxgn6dM7spDt1i7_TCyg
# ACEc5u6p_BO5WNnWSWiKHg
# Acgmd_fS0inNJejK8GaKrA
# ACZMpSYuGzQqr7duclB5sg
# adDdw6rkJ6iUIZdFej81Lg
# aDGgd8XrU8TncdOvz2s-Kw
# AdhQJ6JZQ95tunrgThKaDA
# Adpc7b1Ne-uhGXm75E11ew
# adtYw7lEVilJfFcFGjIkeg
# aE35jawiLYcgotHpaHo05g
# AE6M8wtATVyN_WGmeoQkSw
# AEfpzphjiJ6paQAJFq8DbQ
# aehAX2ag0lWcfOsUknmgYw
# aePUPQcjJjgzkFh-aBkdig
# aF2hfdgdi6nkOBZhVDSbsA
# af3pKOs80tFwGdcI3h_aXQ
# AFD3LzVb_95qSXnfPNjUMw
# AFHGPu-vfjKXe9M4GY8K7w
# AFkWOEKRstfGt8MwC0kICQ
# AfrdkJ4u0zM2iNrR7JM07g
# Aftmhe-Veg_b4GS_Si0jjQ
# AFYIgXkb5d35icnq3rUoVg
# Af_gWKp8-f4ffHcPTI1vQg
# Ag4V9K4cxGXop38a15IXiQ
# AGF-pCYFC20VtpYPSk4FZA
# aGNeydIkWztOdPNpf5OJ8g
# agnZ7_YvhVSsh0PwvMD1Gw
# agUbyraNojbGnnXQdV6Bug
# AGvJIvHH4tOQ4htlt1OfPQ
# agwMuuBN8-Ntz_Khjj1vbg
# ag_jPVdDqk3pgs71bk1ZrQ
# ah5pscCKn6stJ1FGDnHHpg
# aHg7u8O_Mc1TjNy6Ej2BzQ
# ahRD2bxzN4M0_RV974oh_A

# %%
# Saving names in a file (the process of the previous cell took 2 hours)

extra_file_train = open('extra_names_train.txt', 'w')
for element in nobillboard_names_train:
    extra_file_train.write(str(element) + '\n')
extra_file_train.close()
# Out:
# 1000

# %%
# Read the file where the extra names of images were saved

loaded_extranames_train = []
extra_file = open('extra_names_train.txt', 'r')
for line in extra_file:
    loaded_extranames_train.append(line[0:line.find('\n')])
extra_file.close()

#print(new_names == subset_names_train)
print(len(loaded_extranames_train))
# Out:
# 1000

# %%
# Copying files that matches our requirements

n = len(loaded_extranames_train)
for i in range(0, n):
    image_id = loaded_extranames_train[i]
    source = original_path + 'training/images/{}.jpg'.format(image_id)
    destination = 'Data/train/images/{}.jpg'.format(image_id)
    shutil.copyfile(source, destination)

# %% [markdown]
# #### 2.3.2 Increasing validation subset
#
# The same process is repeated.
#
# 200 extra images without billboards were added to the validation subset.

# %%
# Getting the ids of images that DO NOT contain billboards on them (validation)

i = 0
extra_size = 200 # size of the desired subset
nobillboard_names_val = []
while (len(nobillboard_names_val) < extra_size):
    image_id = validation_images_names[i]
    if image_id not in loaded_names_val:
        # read in config file
        with open(original_path + 'config.json') as config_file:
            config = json.load(config_file)

        labels = config['labels']
        label_dic = {}
        for label_id, label in enumerate(labels):
            label_dic[label['name']] = label_id

        # set up paths for every image
        image_path = original_path + "validation/images/{}.jpg".format(image_id)
        panoptic_path = original_path + "validation/panoptic/{}.png".format(image_id)

        # load images
        base_image = Image.open(image_path)
        panoptic_image = Image.open(panoptic_path)

        # PANOPTIC HANDLING

        # read in panoptic file
        with open(original_path + "validation/panoptic/panoptic_2018.json") as panoptic_file:
            panoptic = json.load(panoptic_file)

       # convert annotation infos to image_id indexed dictionary
        panoptic_per_image_id = {}
        for annotation in panoptic["annotations"]:
            panoptic_per_image_id[annotation["image_id"]] = annotation

        # convert category infos to category_id indexed dictionary
        panoptic_category_per_id = {}
        for category in panoptic["categories"]:
            panoptic_category_per_id[category["id"]] = category

        # convert segment infos to segment id indexed dictionary
        example_panoptic = panoptic_per_image_id[image_id]
        example_segments = {}
        for segment_info in example_panoptic["segments_info"]:
            example_segments[segment_info["id"]] = segment_info

        panoptic_array = np.array(panoptic_image).astype(np.uint32)
        panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
        panoptic_ids_from_image = np.unique(panoptic_id_array)

        found = False
        for panoptic_id in panoptic_ids_from_image:
            if panoptic_id == 0:
                # void image areas don't have segments
                continue
            segment_info = example_segments[panoptic_id]
            category = panoptic_category_per_id[segment_info["category_id"]]

            img_label = label_dic[category['supercategory']]
            if img_label == 35:
                found = True
            example_segments.pop(panoptic_id)
        if found == False:
            nobillboard_names_val.append(image_id)
            print(image_id)
        i += 1
    else:
        i += 1
# Out:
# -F-jXLRFKunhfJg4s-62jA
# -gQj6MFElvWSGDLGgrZpmQ
# -OB82zvf2k0rTOxuMEuQGA
# -Ws5_rCy-VI_NsLgFIMBbQ
# 03G8WHFnNfiJR-457i0MWQ
# 03T1YjbnUSumHU5n-iYEzA
# 07kQvxZ_6UZoTPvH3YhiFg
# 0awMSNYMwfdXN1K4sGI8Cw
# 0kMplsNDh3pMAKXPB1AOng
# 0mv_D8kuyuoaxHmOn_8PvA
# 0RAR6R-Dxo-YSXhucEdjxw
# 0VGACHmnzbjqiRs6BQ4ufA
# 1EaLwA9alBSKntjx2w4_Wg
# 1MoFjt8lFydFWvuKu_jOWQ
# 1mu7evLfp_Deoglas9V3Gw
# 1ReO2qYXBTxdHVFn1gF2Ww
# 1sHd0W56n3Jct9zVUcMqqg
# 1THQtCsaZH8PqwA2-Vb9tg
# 1u_XW5RrYKPBy0iWkOub0g
# 1X56RIJI8NLVtXJlRRbbgQ
# 1y7aXjIMHDC4U_gp15_Nhg
# 1YjohJoLyEcJ_Eo2GD4w0Q
# 24--9XvrREjXs5RNbtvLfw
# 2CFMBRBizGbV4mWXMzyrTg
# 2d3hvB1rNaivBLVcSYHREA
# 2dUUdESNqgXC2CW0gHWY7A
# 2ehsE_e72WNQo32Cd2B8jA
# 2gml1pBZB9i5c0WmFp0Lxw
# 2NanO8tyD3DyTMhNl6UXQw
# 2RfwaKn8rVSFH2epy9rJqQ
# 2T2reH82rbd0z8gtmBekzg
# 2Zmmq8u0tDHyuavKnDYDWw
# 3BsjwktSq0pw-LQmogl5YQ
# 3CkIEgqnCS0PbXmx85KmRA
# 3E_wVcJJQNYCdWT53lMlew
# 3imssSXy8mHzcHEHcQi6ag
# 3mvMhGpAEATgBkP7U1e-ew
# 3pO6x_ScawsTIR9vJNpXIw
# 3qb2uglycvCgcK_ma22myQ
# 3QQrUUWoNcLmMhP76AT-TA
# 3qzU13RQZzLHg5ETTfciUA
# 3UwyvoQHgLG9LqmjX7sULA
# 41Pk_r4d00VDbSrAK8jABA
# 46P_SNQCh9OfgyPRsRj6oA
# 49qVkcKefnaqZlSshJLetg
# 4bRbbpXJUG-ztxQXelb7oA
# 4FEksJNGJN_GbljZcB18ig
# 4GgyoCqnDCI67PiA8hOB3A
# 4ixrddIa4DC6l_CanLdx0g
# 4l4zcrVB_vnCAPGWbHOUcw
# 4lHgmnSMO2Tm5wJb1zeVBg
# 4LzX5Cu3sObFjHbcQnP6YA
# 4O_QyB_IabOwAmI2U_3lDw
# 4Tbzy_EgpwS4aOU9ttdmoQ
# 4VMNEgNxRwJWeApm8_Mfxg
# 4WhTJuwrLBw6NCpGbIMQ7g
# 4XNyiO49GE1W6chmXeP3ig
# 4YDL8FghIl1Z9U8g1X29nA
# 53WB4M1PEDlKxX3tozu0ig
# 55HlWJJiqhGYuIq_idCvmg
# 57RX6_BDC8sYop4gU8DpUw
# 5AH2PQBMClceBRpY8QkeCg
# 5Am8IBCrHLkCvu_MubAelw
# 5gPWjcG-qCrBo4KQrUaSmw
# 5S-ns93ghhPGmmS8HRUDtg
# 5sUQlQqNAFOopSCPB8r06A
# 5U--XSSd0taAmhCpSYaMPg
# 5VvE2_6BN3tdBeJOpKxAsA
# 5Xrs4brg56qHfcThaLH2Vw
# 5_z1uo6iMxrrRgdU3nppEw
# 63B8VdNHii23jy9_xCNCXw
# 6a-fGujfGx5UVyFt_pD3Kw
# 6QCP5uPusF7XVyZEDFpNeQ
# 6SAO_-Om3XB4yjv3NFJIYw
# 6VjCwuYEIN3NG-LHhoCOGg
# 6x2rKAIi42pIXowhKP20Xw
# 6_oUifHNyvnxK0Xnj04gKA
# 72fx7KaZe4MQZyG2yCBy9A
# 78ALEOsW1oChAu6j4GJobA
# 7bG7U7WIvfaBhUG5IJU27w
# 7EodH4Z7ROuSsyZZswTiwA
# 7eSmG14jLr49BDbr3wbOFg
# 7FeSEOlT65mVZnlJ07rJ4A
# 7INmSzwOj5Mgj1n3VhQohA
# 7Ka8N_9cpYWVCPetl4e-FA
# 7M_u9BIFVxPFEGmYZASPLA
# 7PXRJKlyeKXfEHTnHoD7tA
# 7sfF1oLkgj7MX8mQclJncA
# 7uyMI0cGShEXKVD9GERm4g
# 7ZYHHsr3uitSnmKAHwQzNg
# 8gDJwDsXmqxaeDOLNe6X3A
# 8gnW4s1-0cfR7dJIHaXI3w
# 8N4d6mOdjRQTK2f-o7jTnw
# 8P4uhRAdKQYnJ8cNobjAQA
# 8QHbniD2kZOzwtzY-_hBYg
# 8wq81mKD44qMmKwPZy0uTQ
# 8_0-AHBG2ZYlpTgmsryG1Q
# 94lRvRGNBLZIbfcgUmcpRQ
# 9AOCJMLVx8waAK4ajsEmCw
# 9eQEuKjdNCT9D6vO-Rjv8Q
# 9L73ruts6J4AUc8Ede7f0g
# 9pJFcg7PL4m9QwVOMivuSg
# a0TJFhNKAixyz8gAm9fONQ
# a56B5auoakHt4c7WSMzplw
# a67XXcNj1rWsU9nrehexaw
# A9JY5pLJafw4JOu4hu3H7w
# aBETx9stJsMP9YBCFkrycw
# Ae2V1llXRzo3JUJQZTHy1Q
# aeSSfNp5y952d0NuExNYTQ
# Ah1NjAqbkAIsuBsNmkxEPg
# akl9UAP1LAwx7mJTGY94qw
# akTFdB0gsS6KEbMAnMuAcg
# anxP0G9HpcflGGscD6vWkg
# APP2rrmItPQDAZflEDt3aQ
# AQlDdV1WMKZzEsJCgqBMAg
# aQr3-kuFHT-cSyyKAnUY8g
# arTk44wORJ4hxJu5ZlpyXw
# As4QBj647llIKoPrZfF2_A
# AtcorvZ_61P2n3ZFJgBTFw
# aWxWwELmVyVhJpPO4yxZdQ
# azMsPSPFoz_70iRiwpA8cg
# aZYPstTk90i_6K8FEQFo_g
# b0OQR0CuV23o5DYXNj8qmQ
# b8LkVdta0t-0IZ5rBRe1Qw
# b8loyXQcGxmnSno_6kzeJg
# BAIyQnyLajvlhQC60P5EdA
# bAPsGDAsC_t4czPE4ZmhuA
# BaPyVtd83CG9fkk9Ayb9NA
# bEKd7F23yVBJvfzjtRBFAg
# bEqeT4wzzrSSGx5_Mh1hNg
# bFqCJNjRzGrK_M_FfV-PDg
# Bipxr4n7D8ATNC6swpdyjQ
# bkjcknY3KXr-F5wUJ976yg
# bltUNZMOltWWPPXvIiM_MQ
# BnA5lOPhqcTIOL_AVd0NLA
# BOhRWGdo7UI6jKJ67rDw8Q
# brDsnkFONJN02V-LCA-n7A
# bvSGJVPKHwU9ApMiF19h_A
# byjEH3Ovs-6--b0z7ZjBAA
# c33c0LCGoXl9P6mFprE1ww
# cADzkSLJUlsMKpB_vRo5dA
# CBlAd5Gw5-aBk3fslpLVUg
# ccd2BvGcueKPnwkA2FYxew
# CH5zpqK6MjYsJ6QNIvD0Eg
# ckaLeD_6XQRk4xuTVa8DxA
# cKk6874RMkZ6R_uSJcll5g
# cNePnyNWVdTqtmPkp2pVCw
# Cp0dLyfwvI3CbpTkF5rzxQ
# cq-e26vIeu1ZscriUqpJVA
# CTqsOVqR40aM9eWYyi6G-Q
# Cus6idMtO9BYIoFlK2cEMw
# CuYeblDEfx_gOfds8-WBwA
# cWDTZQ3xN7G38hMUuJfjRQ
# D-b9O13QXsLAS9oiQf4_aQ
# D0f7Y9e8NXFSBbjEYuUdYw
# d3ghAvxTua9rUlqHUM9vFw
# D6cXkCE002CQwE5x6sDt4w
# D6QbAcPZAiC1L5ojF6k-eA
# dBjAzFogZECt-0JHneqkbw
# DC4ZtI43tcSU9Oad5hr8ag
# dd7uC_JL7JtsWMwgKdY8mw
# DF1-uIARksQuUbJ6qJbJ6Q
# DGmVYOTNyO0NBonQLaG8NQ
# DjYmyJnckqzL7l7MjNFUKg
# DL6RBxuTxAlgVVdAucmd4g
# DLGGWJMiAIE4ObEC103EPw
# DlW3h0sM3UXi0_CSc0y81g
# dQMRwTXKr2UOHG6qmAeRfQ
# DT6tG3glZGxaht7hDYxI3Q
# DThbLpyvFb9M47kw0zBRPQ
# dtsO5O4O4T71lgNsB83-Yg
# DVkpesNIH0cv-rcoIdS4Ng
# dvmKoGfGbOJVBxHcQ1OJ4w
# DvXVREXCs3kdmniS_MicRg
# Dx98mT8n6HQ5JE-u366TNA
# E-kbfzQGyHFgWhX3mGqmfQ
# E1fW9YQ1i6wFQS1MFkH1dg
# e37XVxr8UVBAc1mgmfAJmQ
# EE9qEGmUqmKXznmVQGol5g
# EEJfkWFQFEXv4W3a6vZx5g
# egU_QlAWb53g5cAenua4Cw
# EhFIt4e3gfatVudp3m-r_Q
# eHuIrx7PbbA92NubkxVAjg
# EjDznD81zaxTqTAnxtOooQ
# emMEGDw8CnOM6Nv-sTBcTw
# EnaVzviU4vR_CIDqcaUafg
# EPX44kB0V4tBrZyRkc5WEg
# eqTw3fhG2XZodb3UQd5XIw
# ErfWNgkXYgCmyWYkIrZnUg
# eZCdkacQqGlkmP4GbNICcg
# EZJTbIpLNOfHnw3DvA1NEA
# F-SaJwY8exrIXo37_v8S3w
# f19tTcFApFEnXoMIeLx_VA
# FcipI-0Wf9RK7UYCwHlsxQ
# FCKfIvIsPt9jyFSAHZo48Q
# FDKzMUQdKRR4huVow56AIg
# Fimn6C65kmRy1bO8BdLQzg
# FJEE6dXsBR_Sz8NYmEQ2Rg
# fJEQ907fbOGo8ayyJy80uQ
# fmHX0NYkLPe2ZMvNY1s_GQ

# %%
print(len(nobillboard_names_val))
# Out:
# 200

# %%
# Saving names in a file (the process of the previous cell took 5 hours)

extra_file_val = open('extra_names_val.txt', 'w')
for element in nobillboard_names_val:
    extra_file_val.write(str(element) + '\n')
extra_file_val.close()

# %%
# Read the file where the extra names of images were saved

loaded_extranames_val = []
extra_file = open('extra_names_val.txt', 'r')
for line in extra_file:
    loaded_extranames_val.append(line[0:line.find('\n')])
extra_file.close()

#print(new_names == subset_names_train)
print(len(loaded_extranames_val))
# Out:
# 200

# %%
# Copying files that matches our requirements

n = len(loaded_extranames_val)
for i in range(0, n):
    image_id = loaded_extranames_val[i]
    source = original_path + 'validation/images/{}.jpg'.format(image_id)
    destination = 'Data/validation/images/{}.jpg'.format(image_id)
    shutil.copyfile(source, destination)

# %%
print(len(loaded_extranames_train))
# Out:
# 1000

# %% [markdown]
# ### 2.4 Creating Labels for the Extra Images
#
# This section creates the labels from the images recently added.
#
# **Note:** Obviously, since the images do not contain billboards, no information will be stored in the text files. However, this process must be done to assure the added images do not have billboards and because it is a requirement for training YOLO models.
#
# #### 2.4.1 Extra labels for Training Subset

# %%
# Creating extra training labels

n = len(loaded_extranames_train)
for i in range(0, n):
    image_id = loaded_extranames_train[i]
    # read in config file
    with open(original_path + 'config.json') as config_file:
        config = json.load(config_file)
        
    labels = config['labels']
    label_dic = {}
    for label_id, label in enumerate(labels):
        label_dic[label['name']] = label_id

    # set up paths for every image
    image_path = original_path + "training/images/{}.jpg".format(image_id)
    panoptic_path = original_path + "training/panoptic/{}.png".format(image_id)

    # load images
    base_image = Image.open(image_path)
    panoptic_image = Image.open(panoptic_path)
        
    # PANOPTIC HANDLING

    # read in panoptic file
    with open(original_path + "training/panoptic/panoptic_2018.json") as panoptic_file:
        panoptic = json.load(panoptic_file)
    
   # convert annotation infos to image_id indexed dictionary
    panoptic_per_image_id = {}
    for annotation in panoptic["annotations"]:
        panoptic_per_image_id[annotation["image_id"]] = annotation
        
    # convert category infos to category_id indexed dictionary
    panoptic_category_per_id = {}
    for category in panoptic["categories"]:
        panoptic_category_per_id[category["id"]] = category
        
    # convert segment infos to segment id indexed dictionary
    example_panoptic = panoptic_per_image_id[image_id]
    example_segments = {}
    for segment_info in example_panoptic["segments_info"]:
        example_segments[segment_info["id"]] = segment_info
    
    label_doc = open(train_path + labels_path + '/' + loaded_extranames_train[i] + '.txt', 'w')
    panoptic_array = np.array(panoptic_image).astype(np.uint32)
    panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
    panoptic_ids_from_image = np.unique(panoptic_id_array)
    
    for panoptic_id in panoptic_ids_from_image:
        if panoptic_id == 0:
            # void image areas don't have segments
            continue
        segment_info = example_segments[panoptic_id]
        category = panoptic_category_per_id[segment_info["category_id"]]
        
        img_label = label_dic[category['supercategory']]
        
        if img_label == 35:
        
            box_x_left = segment_info['bbox'][0]
            box_y_top = segment_info['bbox'][1]
            box_width = segment_info['bbox'][2]
            box_height = segment_info['bbox'][3]
            img = Image.open(image_path)
            img_width, img_height = img.size

            x_center = (box_x_left + box_width/2)/img_width
            y_center = (box_y_top + box_height/2)/img_height
            width = box_width/img_width
            height = box_height/img_height
            label_doc.write(str(0) + ' ' + str(x_center) + ' ' + str(y_center) + ' ' + str(width) + ' ' + str(height) + '\n')
            img.close()

        example_segments.pop(panoptic_id)
    
    label_doc.close()

# %%
# Checking all images have its corresponding label

imgs_names = os.listdir("Data/train/images")
lbls_names = os.listdir("Data/train/labels")
problem = False
for i in range(len(imgs_names)):
    if imgs_names[i][:-4] != lbls_names[i][:-4]:
        print("There is a problem with image number: ", i + 1)
        problem = True

if problem == False:
    print("All good")
# Out:
# All good

# %% [markdown]
# #### 2.4.2 Creating Extra Labels for Validation Subset
#
# The process is repeated for the validation subset

# %%
# Creating extra validation labels

n = len(loaded_extranames_val)
for i in range(0, n):
    image_id = loaded_extranames_val[i]
    # read in config file
    with open(original_path + 'config.json') as config_file:
        config = json.load(config_file)
        
    labels = config['labels']
    label_dic = {}
    for label_id, label in enumerate(labels):
        label_dic[label['name']] = label_id

    # set up paths for every image
    image_path = original_path + "validation/images/{}.jpg".format(image_id)
    panoptic_path = original_path + "validation/panoptic/{}.png".format(image_id)

    # load images
    base_image = Image.open(image_path)
    panoptic_image = Image.open(panoptic_path)
        
    # PANOPTIC HANDLING

    # read in panoptic file
    with open(original_path + "validation/panoptic/panoptic_2018.json") as panoptic_file:
        panoptic = json.load(panoptic_file)
    
   # convert annotation infos to image_id indexed dictionary
    panoptic_per_image_id = {}
    for annotation in panoptic["annotations"]:
        panoptic_per_image_id[annotation["image_id"]] = annotation
        
    # convert category infos to category_id indexed dictionary
    panoptic_category_per_id = {}
    for category in panoptic["categories"]:
        panoptic_category_per_id[category["id"]] = category
        
    # convert segment infos to segment id indexed dictionary
    example_panoptic = panoptic_per_image_id[image_id]
    example_segments = {}
    for segment_info in example_panoptic["segments_info"]:
        example_segments[segment_info["id"]] = segment_info
    
    label_doc = open(validation_path + labels_path + '/' + loaded_extranames_val[i] + '.txt', 'w')
    panoptic_array = np.array(panoptic_image).astype(np.uint32)
    panoptic_id_array = panoptic_array[:,:,0] + (2**8)*panoptic_array[:,:,1] + (2**16)*panoptic_array[:,:,2]
    panoptic_ids_from_image = np.unique(panoptic_id_array)
    
    for panoptic_id in panoptic_ids_from_image:
        if panoptic_id == 0:
            # void image areas don't have segments
            continue
        segment_info = example_segments[panoptic_id]
        category = panoptic_category_per_id[segment_info["category_id"]]
        
        img_label = label_dic[category['supercategory']]
        
        if img_label == 35:
        
            box_x_left = segment_info['bbox'][0]
            box_y_top = segment_info['bbox'][1]
            box_width = segment_info['bbox'][2]
            box_height = segment_info['bbox'][3]
            img = Image.open(image_path)
            img_width, img_height = img.size

            x_center = (box_x_left + box_width/2)/img_width
            y_center = (box_y_top + box_height/2)/img_height
            width = box_width/img_width
            height = box_height/img_height
            label_doc.write(str(0) + ' ' + str(x_center) + ' ' + str(y_center) + ' ' + str(width) + ' ' + str(height) + '\n')
            img.close()

        example_segments.pop(panoptic_id)
    
    label_doc.close()

# %%
# Checking all images have its corresponding label

imgs_names = os.listdir("Data/validation/images")
lbls_names = os.listdir("Data/validation/labels")
problem = False
for i in range(len(imgs_names)):
    if imgs_names[i][:-4] != lbls_names[i][:-4]:
        print("There is a problem with image number: ", i + 1)
        problem = True

if problem == False:
    print("All good")
# Out:
# All good

# %% [markdown]
# ### 2.5 Creating Labels for Testing Data
#
# This section was completed after annotating the testing images with Roboflow Annotation Tool.
#
# The purpose of the code below is to check all testing images have their respective labels, and make corrections in case a problem is found.

# %%
# Copying the labels obtained from Roboflow

raw_labels = os.listdir("raw testing labels")
for i in range(len(raw_labels)):
    original_name = raw_labels[i]
    name = original_name.split("_jpg")[0]
    new_name = name + ".txt"
    source = "raw testing labels/{}".format(original_name)
    destination = "Data/testing/labels/{}".format(new_name)
    shutil.copyfile(source, destination)

# %%
# Checking the testing images have their corresponding labels

errors = []
correct_image_name = []
wrong_label_name = []
loaded_testing_images = os.listdir(testing_path + images_path)
testing_labels = os.listdir(testing_path + labels_path)
for i in range(len(loaded_testing_images)):
    if testing_labels[i][:-4] != loaded_testing_images[i][:-4]:
        print("Error in archive: ", i)
        errors.append(i)
        correct_image_name.append(loaded_testing_images[i])
        wrong_label_name.append(testing_labels[i])

#print(correct_image_name)
#print(wrong_label_name)
# Out:
# Error in archive:  33
# Error in archive:  107
# Error in archive:  563
# Error in archive:  581
# Error in archive:  788
# Error in archive:  977
# Error in archive:  979
# Error in archive:  1108
# Error in archive:  1870
# ['-KGpjq3c--Sw0mlw8rZmNw.jpg', '0f_Nk--FNh-RogLRlsKL_Q.jpg', '5_MjVb--4PpKb1Pw1RsuuQ.jpg', '6BPZ9kEX--1sUfa3-iSJ5w.jpg', '8ovcV2zbA733SLWCkBr--w.jpg', 'aijPEVXs--_uhTD-IWwQLw.jpg', 'aj7VincEdaT--QEfKGGXqA.jpg', 'bf--JqMENhi0yeKyhi0jxg.jpg', 'gcFrvCPjHTcE--vOkyI24w.jpg']
# ['-KGpjq3c-Sw0mlw8rZmNw.txt', '0f_Nk-FNh-RogLRlsKL_Q.txt', '5_MjVb-4PpKb1Pw1RsuuQ.txt', '6BPZ9kEX-1sUfa3-iSJ5w.txt', '8ovcV2zbA733SLWCkBr-w.txt', 'aijPEVXs-_uhTD-IWwQLw.txt', 'aj7VincEdaT-QEfKGGXqA.txt', 'bf-JqMENhi0yeKyhi0jxg.txt', 'gcFrvCPjHTcE-vOkyI24w.txt']

# %% [markdown]
# After carefully analyzing the differences, we found out that the names provided by the Annotation tool did not copy exactly the image original names for the following cases:
#
# If images that contained more than one minus symbol "-" were copied as a single "-" sign. For instance, the image original name was "-KGpjq3c--Sw0mlw8rZmNw.jpg" but it was copied as "-KGpjq3c-Sw0mlw8rZmNw.txt". This problem was generated by the Annotation Tool but it is corrected for the affected files as shown below:

# %%
for i in range(len(errors)):
    os.rename(testing_path + labels_path + "/" + wrong_label_name[i], testing_path + labels_path + "/" + correct_image_name[i][:-4] + ".txt")

# %%
# Checking the testing images have their corresponding labels

errors = []
correct_image_name = []
wrong_label_name = []
loaded_testing_images = os.listdir(testing_path + images_path)
testing_labels = os.listdir(testing_path + labels_path)
for i in range(len(loaded_testing_images)):
    if testing_labels[i][:-4] != loaded_testing_images[i][:-4]:
        print("Error in archive: ", i)
        errors.append(i)
        correct_image_name.append(loaded_testing_images[i])
        wrong_label_name.append(testing_labels[i])

if len(errors) == 0:
    print("All good")
# Out:
# All good

# %%
print(raw_labels[33], loaded_testing_images[33], testing_labels[33])
print(raw_labels[107], loaded_testing_images[107], testing_labels[107])
print(raw_labels[563], loaded_testing_images[563], testing_labels[563])
print(raw_labels[581], loaded_testing_images[581], testing_labels[581])
print(raw_labels[788], loaded_testing_images[788], testing_labels[788])
print(raw_labels[977], loaded_testing_images[979], testing_labels[979])
print(raw_labels[1108], loaded_testing_images[1108], testing_labels[1108])
print(raw_labels[1870], loaded_testing_images[1870], testing_labels[1870])
# Out:
# -KGpjq3c-Sw0mlw8rZmNw_jpg.rf.c88a036f4289ed26772c6e1a72d3ea77.txt -KGpjq3c--Sw0mlw8rZmNw.jpg -KGpjq3c-Sw0mlw8rZmNw.txt
# 0f_Nk-FNh-RogLRlsKL_Q_jpg.rf.3d9a2930ff34dcd02ed691fdf277a989.txt 0f_Nk--FNh-RogLRlsKL_Q.jpg 0f_Nk-FNh-RogLRlsKL_Q.txt
# 5_MjVb-4PpKb1Pw1RsuuQ_jpg.rf.5f5fccade55454e2f8fb7273e051b2fe.txt 5_MjVb--4PpKb1Pw1RsuuQ.jpg 5_MjVb-4PpKb1Pw1RsuuQ.txt
# 6BPZ9kEX-1sUfa3-iSJ5w_jpg.rf.c2fb459e73fa79b93825f36729480fb2.txt 6BPZ9kEX--1sUfa3-iSJ5w.jpg 6BPZ9kEX-1sUfa3-iSJ5w.txt
# 8ovcV2zbA733SLWCkBr-w_jpg.rf.60682ba6d34a4fa3ec4960fbdda273ac.txt 8ovcV2zbA733SLWCkBr--w.jpg 8ovcV2zbA733SLWCkBr-w.txt
# aijPEVXs-_uhTD-IWwQLw_jpg.rf.4e70ea66eaf93c60b3c3baa3bc147b8d.txt aj7VincEdaT--QEfKGGXqA.jpg aj7VincEdaT-QEfKGGXqA.txt
# bf-JqMENhi0yeKyhi0jxg_jpg.rf.ae9477d453eb1f2a31bf279376d34a78.txt bf--JqMENhi0yeKyhi0jxg.jpg bf-JqMENhi0yeKyhi0jxg.txt
# gcFrvCPjHTcE-vOkyI24w_jpg.rf.060c4e5c0808bf8b7666641f9ab318a4.txt gcFrvCPjHTcE--vOkyI24w.jpg gcFrvCPjHTcE-vOkyI24w.txt

# %%
print(len(loaded_testing_images[33]), len(testing_labels[33]))
# Out:
# 26 26
